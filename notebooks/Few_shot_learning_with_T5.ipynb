# %% [markdown]
#  **Few shot text generation with T5 Transformer**

# %% [markdown]
# ## 1. Install libraries

# %%
# !pip install transformers==2.9.0
# Out:
# Collecting transformers==2.9.0
#   Downloading transformers-2.9.0-py3-none-any.whl (635 kB)
#      |████████████████████████████████| 635 kB 5.2 MB/s
# Collecting sacremoses
#   Downloading sacremoses-0.0.53.tar.gz (880 kB)
#      |████████████████████████████████| 880 kB 40.6 MB/s
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 36.6 MB/s
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers==2.9.0) (4.64.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers==2.9.0) (2.23.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers==2.9.0) (3.6.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from transformers==2.9.0) (1.21.6)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers==2.9.0) (2019.12.20)
# Collecting tokenizers==0.7.0
#   Downloading tokenizers-0.7.0-cp37-cp37m-manylinux1_x86_64.whl (5.6 MB)
#      |████████████████████████████████| 5.6 MB 23.9 MB/s
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==2.9.0) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==2.9.0) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==2.9.0) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==2.9.0) (2.10)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==2.9.0) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==2.9.0) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==2.9.0) (1.1.0)
# Building wheels for collected packages: sacremoses
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895260 sha256=fd7d27da696047f351eee72cb7e75c26aaf0db548257122f3c09c8e67f66fb07
#   Stored in directory: /root/.cache/pip/wheels/87/39/dd/a83eeef36d0bf98e7a4d1933a4ad2d660295a40613079bafc9
# Successfully built sacremoses
# Installing collected packages: tokenizers, sentencepiece, sacremoses, transformers
# Successfully installed sacremoses-0.0.53 sentencepiece-0.1.96 tokenizers-0.7.0 transformers-2.9.0

# %%
# Check we have a GPU and check the memory size of the GUP
# !nvidia-smi
# Out:
# NVIDIA-SMI has failed because it couldn't communicate with the NVIDIA driver. Make sure that the latest NVIDIA driver is installed and running.

# %% [markdown]
# ## 2. Prepare Model

# %%
import random
import pandas as pd
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader

from transformers import (
    AdamW,
    T5ForConditionalGeneration,
    T5Tokenizer,
    get_linear_schedule_with_warmup
)

def set_seed(seed):
  random.seed(seed)
  np.random.seed(seed)
  torch.manual_seed(seed)

set_seed(42)

# %%
tokenizer = T5Tokenizer.from_pretrained('t5-base')
t5_model = T5ForConditionalGeneration.from_pretrained('t5-base')
# Out:
# Downloading:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.20k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/892M [00:00<?, ?B/s]

# %%
# optimizer
no_decay = ["bias", "LayerNorm.weight"]
optimizer_grouped_parameters = [
    {
        "params": [p for n, p in t5_model.named_parameters() if not any(nd in n for nd in no_decay)],
        "weight_decay": 0.0,
    },
    {
        "params": [p for n, p in t5_model.named_parameters() if any(nd in n for nd in no_decay)],
        "weight_decay": 0.0,
    },
]
optimizer = AdamW(optimizer_grouped_parameters, lr=3e-4, eps=1e-8)

# %%
import re, math, time, sys, copy, random, json
df=pd.read_csv("newcorp.csv")
text_list=[]
label_list=[]
def datasetmaker(x):
    x=json.loads(x)
    for i in range(0,len(x["paragraphs"])):
        for j in range(0,len(x["paragraphs"][i])):
            text_list.append(x["paragraphs"][i][j]["text"])
            label_list.append(x["paragraphs"][i][j]["label"])
df["article_segments"].apply(lambda x:datasetmaker(x))
df_main={"text":text_list,"label":label_list}
df_main=pd.DataFrame(df_main)
len_no_unit=df_main[df_main["label"]=="no-unit"]["text"].apply(lambda x:len(x.split(" ")))
df_main=df_main.loc[(df_main["label"]!="no-unit") | ((df_main["label"]=="no-unit") & (df_main["text"].map(len) > 1)) ]
df_main
def cleanData(df):
    df = df.replace(r'\n','', regex=True)
    df = df_main.replace('\"','', regex=True)
    df = df_main.replace('\/','', regex=True)
    return df

def getJsonFromFrame(df):
    df=cleanData(df)
    result = df.to_json(orient="records")
    df_parsed = json.loads(result)
    return df_parsed

df_main=cleanData(df_main)

r=getJsonFromFrame(df_main)
r
# Out:
# [{'label': 'title',
#   'text': '2015: Beyond Obama, new Congress, we need a revival of the American spirit.'},
#  {'label': 'anecdote',
#   'text': 'In the film, "Girl Interrupted," Winona Ryder plays an 18-year-old who enters a mental institution for what is diagnosed as borderline personality disorder'},
#  {'label': 'anecdote', 'text': 'The year is 1967'},
#  {'label': 'no-unit', 'text': 'and'},
#  {'label': 'anecdote',
#   'text': 'the country is in turmoil over Vietnam and civil rights'},
#  {'label': 'anecdote',
#   'text': 'While lying on her bed one night and watching TV, she sees a news report about a demonstration'},
#  {'label': 'anecdote',
#   'text': 'The narrator says something that might apply to today\'s turmoil:"We live in a time of doubt. The institutions we once trusted no longer seem reliable."'},
#  {'label': 'no-unit', 'text': 'As 2014 ends,'},
#  {'label': 'statistics', 'text': 'the stock market is at record highs'},
#  {'label': 'no-unit', 'text': 'but'},
#  {'label': 'assumption',
#   'text': 'our traditional institutions and self-confidence are in decline'},
#  {'label': 'testimony',
#   'text': 'A Pew Research Center study confirms one trend that has been obvious over several years'},
#  {'label': 'assumption',
#   'text': 'The "typical" American family is no longer typical'},
#  {'label': 'statistics',
#   'text': 'Just 46 percent of American children now live in homes with their married, heterosexual parents'},
#  {'label': 'statistics', 'text': 'Five percent have no parents at home'},
#  {'label': 'testimony',
#   'text': 'They most likely are living with grandparents, says the study'},
#  {'label': 'assumption',
#   'text': 'These startling figures about the decline of the American family contrast with the year 1960'},
#  {'label': 'statistics',
#   'text': 'when 73 percent of American children lived in traditional families'},
#  {'label': 'assumption',
#   'text': 'A major contributor to this trend has been the assault on marriage and other institutions by the Baby Boom generation'},
#  {'label': 'assumption',
#   'text': 'It was that generation that promoted cohabitation, no-fault divorce, hatred of the police(they called them "pigs" then, too) and disdain for the military and America, spawned not just by the Vietnam War but a life of relative ease unknown to their parents'},
#  {'label': 'assumption',
#   'text': 'The culture bomb dropped by the boomers created fallout still being felt today'},
#  {'label': 'assumption',
#   'text': 'The two-plus generations born since the Sixties have been infused with the notion of entitlement, victimhood, envy and greed'},
#  {'label': 'assumption',
#   'text': 'Since the elimination of the draft, young people are no longer expected to serve in the military and so most of them pursue whatever goals they wish with no expectation they should give something back to their country'},
#  {'label': 'assumption',
#   'text': "It's one possible explanation for why we can no longer seem to win wars"},
#  {'label': 'common-ground',
#   'text': 'History warns us what happens when empires refuse to teach known values that strengthen societies and help protect them from enemies intent on their destruction'},
#  {'label': 'anecdote',
#   'text': 'The late British diplomat Sir John Glubb wrote a book called "The Fate of Empires and Search For Survival."'},
#  {'label': 'testimony',
#   'text': 'Glubb noted the average age of empires since the time of ancient Assyria (859-612 B.C ) is 250 years'},
#  {'label': 'testimony',
#   'text': 'Only the Mameluke Empire in Egypt and the Levant (1250-1517) made it as far as 267 years'},
#  {'label': 'assumption',
#   'text': 'America is 238 years old and is exhibiting signs of decline'},
#  {'label': 'testimony',
#   'text': 'All empires begin, writes Glubb, with the age of pioneers, followed by ages of conquest, commerce, affluence, intellect and decadence'},
#  {'label': 'assumption',
#   'text': 'America appears to have reached the age of decadence'},
#  {'label': 'testimony',
#   'text': 'which Glubb defines as marked by "defensiveness, pessimism, materialism, frivolity, an influx of foreigners, the welfare state, (and) a weakening of religion."'},
#  {'label': 'testimony',
#   'text': 'Decadence, he writes,"is due to: Too long a period of wealth and power, selfishness, love of money (and) the loss of a sense of duty."'},
#  {'label': 'assumption',
#   'text': 'Do these not define America at the end of 2014?'},
#  {'label': 'testimony',
#   'text': 'Glubb says the 250-year average of empires has not varied in 3,000 years'},
#  {'label': 'no-unit', 'text': 'but'},
#  {'label': 'testimony',
#   'text': 'we don\' t learn from history because"our studies are brief and prejudiced."'},
#  {'label': 'assumption',
#   'text': "He means they are mostly about one's own country"},
#  {'label': 'assumption',
#   'text': 'It will take more than a new Congress in 2015 and a new president in 2017 to save us from the fate of other empires'},
#  {'label': 'assumption',
#   'text': 'It will take a revival of the American spirit'},
#  {'label': 'no-unit', 'text': 'and'},
#  {'label': 'assumption',
#   'text': 'that can only come through changed attitudes towards our institutions and each other'},
#  {'label': 'title',
#   'text': '2015: Will America continue its slow march toward destruction of liberty?'},
#  {'label': 'anecdote',
#   'text': 'A British author, residing in the United States for the past 30 years, created a small firestorm earlier this week with his candid observations that modern- day Americans have been duped by the government into accepting a European- style march toward socialism'},
#  {'label': 'testimony',
#   'text': "because we fail to appreciate the rich legacy of personal liberty that is everyone's birthright and is expressly articulated in the Declaration of Independence and guaranteed by the U.S  Constitution"},
#  {'label': 'testimony',
#   'text': 'Os Guinness, the author of more than a dozen books defending traditional Judeo-Christian values and Jeffersonian personal liberty, argued that we should embrace individual liberty and personal dignity and reject the "no givens, no rules, no limits" government we now have'},
#  {'label': 'testimony',
#   'text': 'He went on to opine that the government today is not the constitutionally restrained protector of personal freedoms the Framers left us'},
#  {'label': 'testimony',
#   'text': 'but rather has become the wealth-distributing protector of collective interests the Founding Fathers never could have imagined'},
#  {'label': 'assumption', 'text': 'Yet the problem is a deep one'},
#  {'label': 'common-ground',
#   'text': 'The Framers believed in the presumption of liberty'},
#  {'label': 'common-ground',
#   'text': 'which declares that we are free to make personal choices, and the government cannot interfere with our liberties unless we violate the rights of others'},
#  {'label': 'no-unit', 'text': 'Stated differently'},
#  {'label': 'assumption',
#   'text': 'the federal government cannot interfere with our personal choices by writing any law it wants'},
#  {'label': 'assumption',
#   'text': 'it can only regulate behavior or spend money when the Constitution authorizes it to do so'},
#  {'label': 'assumption',
#   'text': 'But for the past 100 years, the federal government has rejected the Madisonian concept that it is limited to the 16 discrete powers the Constitution delegates to it, and has claimed its powers are unlimited, subject only to the express prohibitions in the Constitution'},
#  {'label': 'assumption',
#   'text': 'Even those prohibitions can be gotten around'},
#  {'label': 'assumption',
#   'text': 'since government lawyers have persuaded federal courts to rule that Congress can spend tax dollars or borrowed money on any projects it wishes, whether authorized by the Constitution or not'},
#  {'label': 'assumption',
#   'text': 'The courts even have authorized Congress to use federal tax dollars to bribe the states into enacting laws that Congress is powerless to enact'},
#  {'label': 'no-unit', 'text': 'and'},
#  {'label': 'assumption', 'text': 'Congress has done so'},
#  {'label': 'common-ground',
#   'text': 'The Declaration of Independence defines our personal liberties as inalienable aspects of our humanity'},
#  {'label': 'no-unit', 'text': 'and'},
#  {'label': 'common-ground',
#   'text': 'the Constitution prohibits the government from interfering with those liberties-- like thought, speech, press, association, worship, self-defense, travel, privacy, due process, use of money and private property'},
#  {'label': 'no-unit', 'text': 'to name a few'},
#  {'label': 'common-ground',
#   'text': 'The teaching of these founding documents is that our liberties are natural-- their source is not the government'},
#  {'label': 'no-unit', 'text': '-- and'},
#  {'label': 'common-ground', 'text': 'they are personal, not collective'},
#  {'label': 'common-ground',
#   'text': "We don't need a government permission slip to exercise them"},
#  {'label': 'common-ground',
#   'text': "we don't need to belong to a group to enjoy them"},
#  {'label': 'common-ground',
#   'text': 'they cannot be taken away by a congressional vote or a presidential signature'},
#  {'label': 'common-ground',
#   'text': 'Even though everyone who works for the government takes an oath to uphold the Declaration and the Constitution'},
#  {'label': 'assumption',
#   'text': 'very few are consistent with what they have sworn to do'},
#  {'label': 'assumption',
#   'text': 'We know that because on the transcendental issues of our day -- life, liberty, war and debt -- the leadership of both political parties and the behavior of all modern presidents have revealed a steadfast willingness to write any law and regulate any behavior or permit any evil'},
#  {'label': 'no-unit',
#   'text': ', whether authorized by the Constitution or not.'},
#  {'label': 'other', 'text': 'Take life'},
#  {'label': 'assumption',
#   'text': 'Abortion is the most deadly force in America today'},
#  {'label': 'assumption', 'text': 'Abortions lawfully kill a baby a minute '},
#  {'label': 'no-unit', 'text': '--'},
#  {'label': 'assumption',
#   'text': "that's 1.1 million babies a year and 45,000,000 killed since the Supreme Court issued its Roe v  Wade decision in 1973"},
#  {'label': 'assumption',
#   'text': 'A simple one-line statute --"The fetus in the womb is a legal person"-- could have been enacted by a simple majority vote in Congress and signed into law by any of our so-called pro-life presidents, thus stopping the slaughter'},
#  {'label': 'common-ground', 'text': 'It never happened'},
#  {'label': 'other', 'text': 'Take liberty'},
#  {'label': 'assumption',
#   'text': 'Both parties support the Patriot Act and the secret FISA apparatus'},
#  {'label': 'assumption',
#   'text': 'which together invade privacy, infringe upon free speech, permit federal agents to write their own search warrants and allow domestic spying on all of us all the time'},
#  {'label': 'assumption',
#   'text': 'This demonstrates that our political leaders do not believe that our rights are inalienable, but can be interfered with and regulated by them'},
#  {'label': 'assumption',
#   'text': 'They have written laws that literally permit federal agents to do the very acts the Constitution was written to prohibit'},
#  {'label': 'other', 'text': 'Take the lethal combination of war and debt'},
#  {'label': 'assumption',
#   'text': 'Both parties support perpetual war and perpetual debt'},
#  {'label': 'assumption',
#   'text': 'The leadership of both parties has permitted every modern president to kill whomever he pleases in foreign countries without lawful declarations of war and to do so by going into a $17 trillion hole of debt, with no end in sight'},
#  {'label': 'assumption',
#   'text': 'Today, 20 cents of every tax dollar collected goes to interest on pre-existing government debt'},
#  {'label': 'assumption',
#   'text': "Today's taxpayers are still paying interest on the $30 billion Woodrow Wilson borrowed to finance World War I in 1917"},
#  {'label': 'assumption', 'text': 'The British author is correct'},
#  {'label': 'assumption',
#   'text': 'Unless we have a radical change in the direction of government -- its size, cost, focus, intrusiveness and rejection of first principles -- and unless we elect people to the government who truly believe the Declaration and the Constitution mean what they say, we will continue our march toward the federal destruction of the presumption of liberty'},
#  {'label': 'assumption', 'text': 'It is a slow march, but a steady one'},
#  {'label': 'title',
#   'text': '2015: Will new Congress get serious about Putin, Russia?'},
#  {'label': 'testimony',
#   'text': '"The bear never asks permission," remarked Vladmir Putin on a TV promo for his annual news conference'},
#  {'label': 'other', 'text': 'Yes, we know'},
#  {'label': 'assumption',
#   'text': "The Russians haven't stopped their aggressive posturing after annexing Crimea--not by a long-shot"},
#  {'label': 'anecdote',
#   'text': 'In early December there was another near miss between a Russian military jet with its transponders turned off and a commercial airliner just south of Sweden'},
#  {'label': 'testimony',
#   'text': 'This adds to the list of over 40 serious incidents involving Russia and NATO countries in the last 8 months, as detailed in a report by a British think tank called the European Leadership Network'},
#  {'label': 'assumption',
#   'text': 'President Obama has so far remained unwilling to do little more than levy pin- prick sanctions against specific Russian individuals'},
#  {'label': 'no-unit', 'text': 'but'},
#  {'label': 'assumption',
#   'text': "that doesn't mean Congress is sitting still"},
#  {'label': 'assumption',
#   'text': 'Republicans have continued to show a willingness to get tough with Russia to actually deter it'},
#  {'label': 'anecdote',
#   'text': 'And now the New Year ushers in a Republican majority in the Senate, and a freshly motivated Republican House'},
#  {'label': 'anecdote',
#   'text': 'Several Senators have argued the U.S  should impose much tougher sanctions on whole sectors of the Russian economy, provide significant arms to Ukraine and NATO allies in the region, and should go back to an emphasis on building out missile defense in Europe'},
#  {'label': 'common-ground',
#   'text': 'Moscow has long opposed U.S  missile defense in countries that were once forcibly a part of the Soviet Union'},
#  {'label': 'anecdote',
#   'text': 'Recall the now infamous abandonment by President Obama of the Bush plan to deploy 10 large interceptors in Poland in an effort to appease Russia'},
#  {'label': 'assumption',
#   'text': 'Those same interceptors might not be deployed'},
#  {'label': 'no-unit', 'text': 'but'},
#  {'label': 'assumption',
#   'text': 'the current and more modest plans to build up defenses, could be adapted'},
#  {'label': 'testimony',
#   'text': 'Congressman Mike Tuner, R-Ohio, said in a statement released on December 18, "Given Russia\'s increased aggression toward the West and Iran\\\'s stubbornness toward its nuclear program, we must ensure a robust BMD capability in Europe'},
#  {'label': 'testimony',
#   'text': 'Russia is clearly now a threat to the West."'},
#  {'label': 'common-ground',
#   'text': 'For years the U.S  has insisted that homeland missile defense systems will not be targeted at Russian assets in order to maintain a "strategic balance" between the former Cold War foes'},
#  {'label': 'testimony',
#   'text': 'This remains the position of the U.S as laid out in a 2010 policy document called the Ballistic Missile Defense Review (BMDR)'},
#  {'label': 'common-ground', 'text': 'It is not, however, codified in law'},
#  {'label': 'no-unit', 'text': 'And'},
#  {'label': 'anecdote',
#   'text': 'since the U.S  began deploying more missile defense systems abroad to protect allies and U.S  troops from Iranian missiles, officials have made the case that they were not defending against the shorter range Russian systems'},
#  {'label': 'no-unit', 'text': 'But'},
#  {'label': 'assumption', 'text': 'this may change'},
#  {'label': 'no-unit', 'text': 'and'},
#  {'label': 'assumption',
#   'text': 'if it does, it will be the fault of the Russian government, and to the credit of American officials who are paying close attention'},
#  {'label': 'no-unit', 'text': 'Unconvinced'},
#  {'label': 'no-unit', 'text': 'that the U.S  is not threatening its military'},
#  {'label': 'assumption',
#   'text': 'Russia has moved forward with an aggressive plan to improve in quality and quantity its offensive missile forces and continues to threaten its neighbors (U.S  allies) with them, even threatening to use--preemptively--nuclear weapons'},
#  {'label': 'assumption',
#   'text': 'The revelations that Russia has been in violation of the INF Treaty has also ushered in some bipartisan agreement that perhaps the U.S  should rethink its position regarding missile defense and Russia'},
#  {'label': 'anecdote',
#   'text': 'Democratic Senator Joe Donnelly, R-Ind , raised the issue of speeding up and strengthening U.S  missile defense in Europe in the context of Russian aggression during an April 2, 2014 Senate hearing'},
#  {'label': 'anecdote',
#   'text': 'In the recent omnibus bill Congress approved $20 million to do just that -- speed up the deployment of the European Phased Adaptive Approach-- a missile defense plan to deploy missile defense assets in Europe to protect against the regional Iranian threats'},
#  {'label': 'assumption',
#   'text': 'Between the failure of the infamous "Iran deal" to curb Iranian missile development and Russia\'s continued aggression in the region, this makes perfect sense and is good policy'},
#  {'label': 'testimony',
#   'text': 'In a recent trip to Eastern Europe, the Chairman of the House Strategic Forces Subcommittee, Congressman Mike Rogers, R-Ala , stated that the interceptors in Europe could be made to defend against some Russian threats'},
#  {'label': 'no-unit', 'text': 'As'},
#  {'label': 'no-unit', 'text': 'one can imagine'},
#  {'label': 'assumption',
#   'text': "this didn't thrill the Russians--but short of American decline, what does?"},
#  {'label': 'testimony',
#   'text': 'Russian Foreign Ministry spokesman Alexander Lukashevich said in a statement,"Hence, the U.S  lawmaker confirmed the justifiability of concerns having been aired by Moscow for a long time that the missile shield being developed by the U.S  is intended solely for the purposes officially declared by Washington."'},
#  {'label': 'assumption',
#   'text': 'If the U.S  does configure systems to protect its allies against Russian missiles, it is because it will be because Uncle Sam finally stopped "asking permission" and decided to get serious about deterring "the bear."'},
#  {'label': 'title',
#   'text': '? 300 for a job reference is the latest outrage in the exploitation of interns.'},
#  {'label': 'no-unit', 'text': 'If'},
#  {'label': 'assumption',
#   'text': 'there were an award for scummiest business practice'},
#  {'label': 'assumption',
#   'text': 'refusing to pay interns would get many a vote'},
#  {'label': 'anecdote',
#   'text': 'But Jan Mortier, who until a year ago ran a "junior associates" programme through his thinktank Civitatis International, has upped the stakes by charging former interns(or trainees, as he prefers to think of them) a ? 300 fee for an employment reference'},
#  {'label': 'assumption',
#   'text': 'Is charging someone for a reference after refusing to pay them as scummy as it gets? Sadly not'},
#  {'label': 'assumption', 'text': 'Young people are lucky'},
#  {'label': 'no-unit', 'text': 'if'},
#  {'label': 'assumption',
#   'text': 'unpaid work is the worst deal they are offered'},
#  {'label': 'assumption',
#   'text': 'although the "junior associates" programme was advertised on Internwise, the three-month programme cost more than? 1,600'},
#  {'label': 'testimony',
#   'text': '(Mortier insists it was a training course, not an internship.)'},
#  {'label': 'no-unit', 'text': 'And the winner is '},
#  {'label': 'no-unit', 'text': '...'},
#  {'label': 'assumption',
#   'text': 'But how on Earth did Mortier think he could get away with charging for references, never mind the extortionate fee of? 300?'},
#  {'label': 'assumption',
#   'text': 'His market is ambitious but terrified young people who are overqualified and unemployed'},
#  {'label': 'no-unit', 'text': '- and'},
#  {'label': 'assumption',
#   'text': 'there is easy money to be made from them, for three reasons'},
#  {'label': 'assumption',
#   'text': "First, they've been sent the message that they're of little value to the economy"},
#  {'label': 'assumption',
#   'text': 'Government and businesses have spent the entire economic crisis suggesting that young people lack employable skills'},
#  {'label': 'assumption',
#   'text': 'Repeated references to these elusive skills rarely lead to any kind of specific mention of what they are- or an investigation into why schools and universities stopped teaching them just as the economy collapsed'},
#  {'label': 'no-unit', 'text': 'If'},
#  {'label': 'assumption',
#   'text': "you've spent your life in education only to be called unemployable"},
#  {'label': 'assumption',
#   'text': "the idea that you'd have to pay someone to say nice things about you doesn't seem so far-fetched"},
#  {'label': 'no-unit', 'text': 'Second'},
#  {'label': 'assumption',
#   'text': 'while young people as a group tend not to have much money sloshing around'},
#  {'label': 'assumption',
#   'text': 'their parents and grandparents are supposedly doing OK'},
#  {'label': 'assumption',
#   'text': "People wanting what's best for their kids leads easily to the coughing-up of cash"},
#  {'label': 'no-unit', 'text': 'Third'},
#  {'label': 'assumption',
#   'text': "when it comes to looking for a job, young people are so used to mounting hindrances that you can stick on another like an extra bottle on a drunk's bar tab"},
#  {'label': 'assumption',
#   'text': 'Legend has it that people used to get a job by seeing one they wanted, and applying'},
#  {'label': 'assumption',
#   'text': 'then came the time when they needed qualifications to get the same job'},
#  {'label': 'assumption', 'text': 'then they needed better qualifications'},
#  {'label': 'assumption',
#   'text': 'then they would have to do an unpaid internship'},
#  {'label': 'assumption',
#   'text': "then to prove it wasn't all a fluke they'd have to get qualifications and do an internship"},
#  {'label': 'testimony',
#   'text': 'Now, Civitatis would have you believe that if you attend its summer school you "will gain the advantage over others for internship (sic)"'},
#  {'label': 'no-unit', 'text': 'So,'},
#  {'label': 'anecdote', 'text': '300 for a reference?'},
#  {'label': 'other', 'text': 'Stick it on the bill'},
#  {'label': 'assumption',
#   'text': "But the damage caused by charging for references isn't limited to the spineless gouging of money from naive young people trying to get their first job"},
#  {'label': 'assumption',
#   'text': 'A reference is immediately invalid once money changes hands'},
#  {'label': 'common-ground',
#   'text': "The value of a reference lies in the assumption that it's an honest comment on a person's job performance or character"},
#  {'label': 'assumption',
#   'text': 'The price tag Mortier has attached isn\'t, as he claims, a "fair administrative fee"'},
#  {'label': 'assumption',
#   'text': "It's enough to make a pocket bulge, and certainly enough to be considered a bribe"},
#  {'label': 'assumption',
#   'text': 'no one pays? 300 to be damned with faint praise'},
#  {'label': 'assumption',
#   'text': "Anyone reading a reference signed by Mortier knows he's been paid hundreds for whatever he's written"},
#  {'label': 'no-unit', 'text': 'so'},
#  {'label': 'assumption', 'text': 'it will ring hollow'},
#  {'label': 'assumption',
#   'text': 'Getting a job with worthless education and months-long application processes is already hard enough'},
#  {'label': 'no-unit', 'text': 'If'},
#  {'label': 'assumption', 'text': 'this idea catches on'},
#  {'label': 'assumption',
#   'text': 'references as a measure of a potential candidate will be as devalued as our degrees'},
#  {'label': 'title', 'text': 'Afghanistan at crucial juncture.'},
#  {'label': 'anecdote',
#   'text': 'On Thursday, the so-called London Conference on Afghanistan will convene'},
#  {'label': 'assumption',
#   'text': 'Of all the high-profile international conferences that have been held on Afghanistan over the years- in Bonn, Tokyo, and Istanbul - this comes at a crucial juncture'},
#  {'label': 'anecdote',
#   'text': 'At the end of October, British forces lowered the flag at Camp Bastion - from where they had engaged in the most intense fighting the British army had seen since the Falklands War- and handed over the base to Afghan forces'},
#  {'label': 'anecdote',
#   'text': 'Just over a month later, the Taliban mounted a 14-hour attack on the very same site, killing six Afghan soldiers'},
#  {'label': 'anecdote',
#   'text': 'To the north, in the capital Kabul, insurgents have pulled off a dozen attacks in the space of the last few weeks, striking at diplomats, NGOs, and US contractors'},
#  {'label': 'assumption',
#   'text': 'What explains this spate of violence, and is it a portent for the future of Afghanistan?'},
#  {'label': 'anecdote',
#   'text': "The International Security Assistance Force (ISAF), a US-led group that includes NATO members and others, winds up its mission on New Year's Eve"},
#  {'label': 'anecdote',
#   'text': 'A slimmed-down force of 12,000 foreign troops - mostly American - will stay behind'},
#  {'label': 'no-unit', 'text': 'and'},
#  {'label': 'anecdote',
#   'text': 'US President Barack Obama has authorised the US contingent to continue supporting Afghan National Security Forces (ANSF) throughout 2015, with all of these forces scheduled to leave by the end of 2016'},
#  {'label': 'assumption',
#   'text': 'The US is not, therefore, leaving Afghanistan in the abrupt manner than it left Iraq in 2011'},
#  {'label': 'assumption', 'text': 'But this is a time of dramatic change'},
#  {'label': 'no-unit', 'text': 'Drastic effects on casualties'},
#  {'label': 'assumption',
#   'text': 'For one thing, the ANSF are doing much of the fighting themselves, with drastic effects on casualties'},
#  {'label': 'statistics',
#   'text': 'over 9,000 Afghan troops have died since 2013, four times greater than the entire American death toll since 2001'},
#  {'label': 'statistics',
#   'text': 'Afghan police officers are suffering especially badly, with thousands being killed every month'},
#  {'label': 'anecdote',
#   'text': "At the political level, a new government of national unity, led by President Ashraf Ghani and Chief Executive Abdullah Abdullah, has taken charge after Hamid Karzai's departure"},
#  {'label': 'anecdote',
#   'text': "Ghani is already reported to have opened backchannel talks with the Taliban, visiting both Pakistan and Beijing to seek their help in this effort, cancelling an earlier arms request from India, and even making a highly unorthodox visit to Pakistan's army headquarters, in recognition of Pakistan's long-standing support for the insurgents"},
#  {'label': 'assumption',
#   'text': 'On the ground, the overall picture is mixed'},
#  {'label': 'statistics',
#   'text': 'This year, Taliban-initiated attacks are reported to have fallen by 25 percent'},
#  {'label': 'no-unit', 'text': 'and'},
#  {'label': 'statistics',
#   'text': 'ANSF mounted offensives four to five times more frequently than last year'},
#  {'label': 'no-unit', 'text': 'At the same time'},
#  {'label': 'testimony',
#   'text': 'as political scientist Jason Lyall observed, the recently-concluded fighting season - from April to October - "witnessed the appearance of large Taliban units on the battlefield" for the first time, with a tenth of all Afghan districts seeing "at least one major Taliban offensive"'},
#  {'label': 'testimony',
#   'text': 'Lyall also notes reports of over 1,000 insurgents on the battlefield,"numbers not seen since the Taliban\'s original push to capture Kabul during the 1992-96 civil war"'},
#  {'label': 'assumption',
#   'text': 'While we should take these reports with a pinch of salt'},
#  {'label': 'testimony',
#   'text': 'NATO commanders accuse their Afghan counterparts of exaggerating'},
#  {'label': 'assumption', 'text': 'they do point to a simple, stark fact'},
#  {'label': 'assumption', 'text': 'The insurgency is far from broken'},
#  {'label': 'no-unit', 'text': 'and'},
#  {'label': 'assumption',
#   'text': 'it will be able to pressure the Afghan state for years to come'},
#  {'label': 'assumption',
#   'text': 'In this context, the wave of insurgent attacks might be explained in several ways'},
#  {'label': 'no-unit', 'text': 'First'},
#  {'label': 'assumption',
#   'text': ', these attacks might be intended to drive a wedge between the Afghan government and its foreign patrons, encouraging the latter to abandon their allies more quickly'},
#  {'label': 'testimony',
#   'text': 'As a Taliban spokesman put it bluntly:"Our objective is to force the foreigners to flee Kabul. Before, the foreigners were visible in the provinces. Now that they have limited more of their activities to Kabul, we have also gone to Kabul to target them there."'},
#  {'label': 'assumption', 'text': 'To some extent, this has worked'},
#  {'label': 'anecdote',
#   'text': 'Many aid agencies have pulled out their staff, and restricted their movements'},
#  {'label': 'no-unit', 'text': 'Tarnished credibility'},
#  {'label': 'no-unit', 'text': 'Second'},
#  {'label': 'assumption',
#   'text': " the insurgents failed to seriously disrupt either round of this year's Afghan elections, as they had vowed to do, leaving their credibility somewhat tarnished"},
#  {'label': 'assumption',
#   'text': 'Prominent attacks - publicised with videos - redress this issue, and project strength at the end of a fighting season'},
#  {'label': 'assumption',
#   'text': "They might also be ways of strengthening the insurgency's bargaining position in advance of any peace talks that gain momentum over the next year"},
#  {'label': 'no-unit', 'text': 'Third'},
#  {'label': 'assumption', 'text': 'the insurgency is not a monolith'},
#  {'label': 'no-unit', 'text': 'and'},
#  {'label': 'assumption',
#   'text': 'different parts of the Taliban might be responsible for different attacks'},
#  {'label': 'assumption',
#   'text': 'The Haqqani Network, a semi- autonomous group with close ties to Pakistani intelligence, has proven most effective at projecting suicide bombings into Kabul'},
#  {'label': 'anecdote',
#   'text': 'The Haqqanis were blamed for the most deadly atrocity of the past month, the bombing of a volleyball game in which over 50 Afghans were killed'},
#  {'label': 'assumption',
#   'text': 'In the past, moves towards dialogue between the Afghan government and the Taliban have been met with carefully targeted attacks intended less to strengthen bargaining positions than to disrupt such talks altogether'},
#  {'label': 'no-unit', 'text': 'Whatever'},
#  {'label': 'no-unit', 'text': 'the explanation'},
#  {'label': 'assumption', 'text': 'Afghanistan faces an extremely test period'},
#  {'label': 'assumption',
#   'text': 'Although the presence of US forces provides a safety net throughout next year'},
#  {'label': 'assumption', 'text': 'things look more precarious after that'},
#  {'label': 'common-ground',
#   'text': 'International funding commitments for Afghanistan currently run to 2017'},
#  {'label': 'assumption',
#   'text': 'but that timeline had assumed the insurgency would lose steam by then, allowing ANSF to slim down'},
#  {'label': 'no-unit', 'text': 'If'},
#  {'label': 'assumption', 'text': "that isn't possible"},
#  {'label': 'assumption',
#   'text': 'the annual $4-6bn bill for the security forces is simply unsustainable'},
#  {'label': 'assumption',
#   'text': "This week's London Conference is an opportunity to secure much greater contributions from regional powers"},
#  {'label': 'assumption',
#   'text': 'who have the most at stake if Afghanistan does fall apart once more'},
#  {'label': 'anecdote',
#   'text': "China is, for instance, one of the world's largest economies, a direct neighbour of Afghanistan, and a significant investor there"},
#  {'label': 'no-unit', 'text': 'But'},
#  {'label': 'no-unit', 'text': 'if'},
#  {'label': 'assumption',
#   'text': 'Beijing is unwilling to offer more than a meagre $327m - nearly half the amount Iran pledged in 2012, and far less than Japan or the EU'},
#  {'label': 'no-unit', 'text': '- then'},
#  {'label': 'assumption',
#   'text': 'how are western governments, with their attention directed to threats from Russia and ISIL, supposed to persuade their own public that, after a decade of war, Afghanistan must stay on financial life-support?'},
#  {'label': 'title', 'text': "Afghanistan conference won't rock the boat."},
#  {'label': 'testimony',
#   'text': '"The London Conference on Afghanistan will provide an opportunity for the government of Afghanistan to set out its commitment to reform," states the UK government\'s official webpage of the upcoming meeting between the new Afghan government and its international donors'},
#  {'label': 'testimony',
#   'text': 'The conference is also an opportunity for the international community "to reaffirm its long-term commitment to supporting Afghanistan\'s peaceful development"'},
#  {'label': 'assumption',
#   'text': 'Despite the media hype, the London Conference is nothing more than a routine reunion, set by the 2012 Tokyo Mutual Accountability Framework (TMAF)'},
#  {'label': 'anecdote',
#   'text': 'As part of the agreement, donors pledged support and the Afghan government promised to implement reforms and curb corruption'},
#  {'label': 'anecdote',
#   'text': "The upcoming meeting in the British capital, therefore, is the first in a series of exchanges that will be held every two years, at the ministerial level, between the Afghan and donor governments to assess progress and check TMAF's benchmarks"},
#  {'label': 'no-unit', 'text': 'Still'},
#  {'label': 'assumption',
#   'text': ' the December 4 conference has the potential to ease Afghanistan into a stable and increasingly self-sufficient future and render it a reliable global partner for ensuring peace and stability in the region and beyond'},
#  {'label': 'assumption',
#   'text': 'To utilise this opportunity as more than a routine progress assessment requires a fundamental shift of attitude on both sides'},
#  {'label': 'assumption',
#   'text': 'Lack of concrete success in the military, economic development and governance efforts in post- Taliban Afghanistan needs to be sincerely examined'},
#  {'label': 'no-unit', 'text': 'and'},
#  {'label': 'assumption', 'text': 'adjustments need to be made'},
#  {'label': 'assumption',
#   'text': "There is multitude of examples in the international community's flawed, if not disingenuous, aid programmes and their monitoring in Afghanistan"},
#  {'label': 'anecdote',
#   'text': 'I was hired by a US consultancy firm to map out the field and offer recommendations for the design of a multimillion dollar governance project'},
#  {'label': 'anecdote',
#   'text': 'My report and recommendations, it turned out, were too radical'},
#  {'label': 'anecdote',
#   'text': '"We expected recommendations for cosmetic changes to the ongoing programmes," I was told'},
#  {'label': 'anecdote',
#   'text': '"The donor agency does not want to rock the boat."'},
#  {'label': 'anecdote',
#   'text': 'On another occasion, I was interviewed by a European consultant for his assessment of the first phase of a programme that had consistently been showcased as a "success story" by donors and the Afghan government'},
#  {'label': 'anecdote',
#   'text': 'In his three-day field trip to Kabul, he had held meetings with three embassies, the UN, the Afghan head of the implementing agency and me'},
#  {'label': 'anecdote',
#   'text': 'Eagerly, I began to point to the flaws of the programme and offered suggestions for improvement'},
#  {'label': 'anecdote', 'text': 'I also offered assistance for site visits'},
#  {'label': 'anecdote',
#   'text': '"Do n\'t waste your time and mine," the septuagenarian consultant told me'},
#  {'label': 'anecdote',
#   'text': '"The donor agency expects a rosy report highlighting only the positive."'},
#  {'label': 'anecdote',
#   'text': 'He further clarified that the decision to fund the second phase had already been made and it had more to do with international aid politics, than development logic'},
#  {'label': 'common-ground',
#   'text': 'Numbers provide an easy way to illustrate success'},
#  {'label': 'assumption',
#   'text': 'especially when seeking international aid budget approval from legislative bodies'},
#  {'label': 'assumption',
#   'text': "While figures indicating Afghanistan's progress towards development are impressive and could not have been achieved without generous international assistance"},
#  {'label': 'assumption',
#   'text': 'they conceal a lack of attention to quality'},
#  {'label': 'statistics',
#   'text': 'About 8 million Afghan children - including over 2.5 million girls - are now in school'},
#  {'label': 'anecdote',
#   'text': 'This is a figure cited regularly as an indication that the programmes are yielding tangible results'},
#  {'label': 'assumption',
#   'text': 'The fact that most of them graduate only half-literate is never revealed'},
#  {'label': 'assumption', 'text': "Here's another feel-good figure"},
#  {'label': 'statistics',
#   'text': 'More than 60 percent of the Afghan population now has access to healthcare facilities'},
#  {'label': 'assumption',
#   'text': 'The fact that some of those facilities have only received a checkmark because merely a building was constructed and many are staffed only with a nurse, have no diagnostic technology and have terribly anaemic pharmaceutical offerings is often ignored'},
#  {'label': 'assumption',
#   'text': "Much has been written about the fact that a hefty portion of the aid money goes back to donor countries because of the donors' insistence to award contracts to their own citizens"},
#  {'label': 'anecdote', 'text': 'The contracts move hand to hand'},
#  {'label': 'no-unit', 'text': 'and'},
#  {'label': 'anecdote',
#   'text': 'finally local non-governmental agencies are hired to implement projects'},
#  {'label': 'no-unit', 'text': 'At this point'},
#  {'label': 'assumption',
#   'text': 'while at best one-quarter of the original funds remains to be spent on the actual project, quality is grossly compromised'},
#  {'label': 'no-unit', 'text': 'and'},
#  {'label': 'assumption',
#   'text': 'monitoring becomes either too complex or irrelevant'},
#  {'label': 'assumption',
#   'text': 'The international community has also created an indigenous vehicle for channelling portions of its assistance'},
#  {'label': 'assumption',
#   'text': 'Under the guise of "civil society", hundreds of Afghan NGOs have been established since 2002'},
#  {'label': 'assumption',
#   'text': "This artificial civil society's lifeline is the donor community in Kabul"},
#  {'label': 'assumption',
#   'text': "Projects and funds are handed to them for implementation and as the closing of fiscal year in donor capitals approaches, generosity in disbursing funds, irrespective of the projects' logic, utility and cost increases"},
#  {'label': 'no-unit', 'text': 'Where'},
#  {'label': 'no-unit', 'text': 'the funds go'},
#  {'label': 'assumption',
#   'text': 'Granted that when international aid began to pour in, the Afghan state had very small, if any, capacity to absorb and spend it'},
#  {'label': 'no-unit', 'text': 'However'},
#  {'label': 'assumption',
#   'text': ' after 13 years and millions of dollars spent on public sector capacity building, the bulk of the funds continue to be spent directly by donors'},
#  {'label': 'no-unit', 'text': 'and'},
#  {'label': 'statistics',
#   'text': 'only a little over 20 percent is given to the Afghan government'},
#  {'label': 'assumption',
#   'text': 'The parallel system and structures offering higher salaries paid in US dollars have lured much of the skilled Afghan human resources'},
#  {'label': 'assumption',
#   'text': 'The Afghan administration, thus, has to be grateful to donors for funding training workshops, while in the end, loses its best trained personnel to international organisations, consulting firms and embassies'},
#  {'label': 'anecdote',
#   'text': "It is often said that rampant Afghan corruption and lack of capacity would result in misuse and waste of donors' funds"},
#  {'label': 'statistics',
#   'text': 'A mere review of reports published by the US oversight agency, Special Inspector General for Afghanistan Reconstruction (SIGAR), reveals the depth and extent of waste, fraud and abuse of the direct US aid to Afghanistan just in reconstruction projects'},
#  {'label': 'assumption',
#   'text': "Similar monitoring of most donors' direct aid will, no doubt, highlight comparable corruption and waste"},
#  {'label': 'assumption',
#   'text': 'The government of former President Hamid Karzai admittedly failed to launch a genuine fight against corruption'},
#  {'label': 'assumption',
#   'text': 'Lack of capacity for a governance vision that would make optimum use of international aid was also a defect of the previous leadership'},
#  {'label': 'assumption',
#   'text': 'High-level appointments were based not on competence and commitment of individuals, but rather on political affiliations and compromises on the one hand, and submissiveness of a handful of "yes sir" entities on the other'},
#  {'label': 'no-unit', 'text': 'Thus'},
#  {'label': 'assumption',
#   'text': ' both sides - donors and the Afghan government - went on for a decade playing a futile blame game'},
#  {'label': 'assumption',
#   'text': 'each accusing the other of corruption and insincerity'},
#  {'label': 'no-unit', 'text': 'Now'},
#  {'label': 'assumption',
#   'text': " on the eve of the London Conference, a new page has turned in Afghanistan's leadership and governance"},
#  {'label': 'assumption',
#   'text': 'The level of optimism among ordinary Afghans is only comparable to the euphoria of the first weeks following the fall of the Taliban regime'},
#  {'label': 'assumption',
#   'text': 'This renewed domestic hope and confidence in the new leadership must not be let to deflate'},
#  {'label': 'anecdote',
#   'text': 'Although the new administration has not yet launched its overhauling programme'},
#  {'label': 'assumption',
#   'text': "President Ashraf Ghani's vision and capacity is well known"},
#  {'label': 'assumption',
#   'text': 'Donors at the London Conference must seize the chance and afford him confidence'},
#  {'label': 'assumption',
#   'text': 'They must also adapt a fundamentally new approach to dispensing their generous assistance to Afghanistan'},
#  {'label': 'assumption',
#   'text': 'A significant funnelling of international aid through the Afghan government (with oversight and accountability benchmarks), a shift of emphasis from quantity to quality, with particular focus on raising the quality of education and finally, a sincere commitment from both sides to the establishment of rule of law will ensure the stability and eventual self-reliance of Afghanistan'},
#  {'label': 'title', 'text': 'Is Afghanistan ready for the drawdown?'},
#  {'label': 'anecdote',
#   'text': 'After 13 years of the International Security Assistance Force (ISAF), the United States and a number of its NATO partners will start the Resolute Support Mission in Afghanistan'},
#  {'label': 'anecdote',
#   'text': 'The number of NATO and US forces is reduced from 140,000 to 13,500 - most of them American- starting January 1'},
#  {'label': 'anecdote',
#   'text': 'How will the new national unity government in Kabul weather the NATO drawdown, despite a resilient insurgency and intensified fighting?'},
#  {'label': 'assumption',
#   'text': 'There has been much speculation about the security transition in 2014 in Afghanistan'},
#  {'label': 'anecdote',
#   'text': 'In 2012, I wrote an Oped for the New York Times, warning that "Kabul risks political meltdown"'},
#  {'label': 'testimony',
#   'text': 'Many other analysts have also predicted a sombre year, particularly after the refusal of former President Hamid Karzai to sign the Bilateral Security Agreement (BSA) with the US'},
#  {'label': 'no-unit', 'text': 'However'},
#  {'label': 'assumption',
#   'text': ' for the time being, we were all proved wrong as the democratic process that began at the Bonn Conference in 2001, survived'},
#  {'label': 'no-unit', 'text': 'and'},
#  {'label': 'assumption',
#   'text': 'the country was saved from the brink of a new civil war'},
#  {'label': 'assumption',
#   'text': "Indeed we have achieved important strategic gains in the last few months, starting with the landmark peaceful transfer of political power from one democratically elected leader to another, for the first time in Afghanistan's history"},
#  {'label': 'assumption',
#   'text': 'This milestone was made possible by the will of ordinary Afghan people'},
#  {'label': 'anecdote',
#   'text': 'who twice braved the threat of violence imposed by the Taliban and came out en masse, voting for their candidates of choice'},
#  {'label': 'assumption',
#   'text': 'Meanwhile, the Taliban has tried hard to undermine the electoral process'},
#  {'label': 'assumption',
#   'text': 'By confronting Afghan security forces in 16 different provinces, they wanted to gain significant territory'},
#  {'label': 'assumption',
#   'text': 'thus declaring themselves as an alternative governing force in the country'},
#  {'label': 'no-unit', 'text': 'Nevertheless'},
#  {'label': 'assumption',
#   'text': ' the Afghan security forces have been able to hold ground and push back the insurgent offensives in almost all fronts'},
#  {'label': 'assumption',
#   'text': 'which has became a source of pride for the Afghan government and people'},
#  {'label': 'assumption',
#   'text': 'This proved wrong skeptics who doubted the capacity of the Afghan security forces to defend their country'},
#  {'label': 'anecdote',
#   'text': 'which has taken responsibility for security in many provinces since the start of the security transition in 2012'},
#  {'label': 'anecdote',
#   'text': 'Following the inauguration of President Ashraf Ghani and Chief Executive Officer (CEO) Abdullah Abdullah, the BSA was immediately signed, approved by an overwhelming majority of Afghan Members of Parliament'},
#  {'label': 'assumption',
#   'text': 'In addition to the BSA, the signing of the Status of Force Agreement (SOFA) between NATO and the new Afghan government has created a new momentum in the country, while ensuring continued military and financial assistance for the new government'},
#  {'label': 'assumption',
#   'text': 'This has inherited an economic crisis, characterised by a fiscal gap resulting from the failures of the previous government'},
#  {'label': 'assumption',
#   'text': "Afghanistan's strategic gains are still contingent upon two important factors"},
#  {'label': 'assumption',
#   'text': 'Firstly, there must be continued NATO support for the Afghan security forces'},
#  {'label': 'assumption',
#   'text': 'This is done by building the capacity of the forces; providing adequate resources such as fire power and particularly air power; assisting in intelligence gathering; and logistics support'},
#  {'label': 'assumption',
#   'text': 'Without the technical and financial support from the US and NATO countries, the Afghan security forces will not be able to sustain a high rate of casualties against the Taliban'},
#  {'label': 'statistics',
#   'text': 'For instance in 2014, an additional 5,000 members of the Afghan security forces were killed either in direct fighting against the Taliban or because of terrorist attacks such as suicide and road side bombings'},
#  {'label': 'assumption',
#   'text': 'Secondly, the government has the capacity to reform the security intuitions in order to reduce the level of corruption and eliminate political influence exercised by important power brokers'},
#  {'label': 'assumption',
#   'text': "The financing of the Afghan security forces are beyond the Afghan government's resources and is totally dependent on donors' contribution"},
#  {'label': 'assumption',
#   'text': 'The government could make significant contributions by reducing costs'},
#  {'label': 'assumption',
#   'text': 'This could be done through reducing corruption and improving management'},
#  {'label': 'no-unit', 'text': 'Meanwhile'},
# ...
#  {'label': 'testimony',
#   'text': 'while civil society organisations question the use of agricultural land to produce grains to feed machines rather than people'},
#  {'label': 'no-unit', 'text': 'Still'},
#  {'label': 'assumption', 'text': ' there are signs of hope'},
#  {'label': 'anecdote',
#   'text': 'On December 3, the Argentinean Senate approved tax incentives for the generation of electricity from renewable energy sources'},
#  {'label': 'assumption',
#   'text': 'The Chamber of Deputies is likely to make it law next year'},
#  {'label': 'assumption',
#   'text': "But in light of Argentina's environmental record, there is clearly a lot of work yet to be done and many more laws and policies to be implemented"},
#  {'label': 'title', 'text': "Armenia can't count on Russia any more."},
#  {'label': 'assumption',
#   'text': 'For Armenia, its role as a reliable partner and ally of Russia has never faced any real challenge'},
#  {'label': 'assumption',
#   'text': 'Much of this reliance on Russia stems from essential security and economic concerns'},
#  {'label': 'assumption',
#   'text': 'Armenia\'s security reliance on Russia is driven by a virtual state of war with neighbouring Azerbaijan, rooted in the Nagorno-Karabakh conflict, only exacerbated by the absence of "normal" diplomatic relations and closed border with Turkey'},
#  {'label': 'assumption',
#   'text': 'And with the Turkish refusal to recognise the Armenian genocide, this threat perception is only magnified'},
#  {'label': 'assumption',
#   'text': 'For small, landlocked Armenia, a strategic alliance with Russia is generally accepted as essential in the face of such inherent insecurity'},
#  {'label': 'assumption',
#   'text': 'And beyond an imperative of security, Armenia also depends on Russia as a crucial source of remittances, or money sent home by large numbers of Armenians living and working in Russia'},
#  {'label': 'no-unit', 'text': 'Yet'},
#  {'label': 'assumption',
#   'text': ' there is a surprisingly intense debate now under way within Armenia that seriously questions these fundamental pillars of the Armenian-Russian relationship'},
#  {'label': 'no-unit', 'text': 'New challenge'},
#  {'label': 'assumption',
#   'text': "More specifically, this new challenge to Armenia's traditional reliance on Russia is driven by two significant factors: tragedy and timing"},
#  {'label': 'assumption', 'text': 'A tragedy first triggered this turnabout'},
#  {'label': 'anecdote',
#   'text': 'when a rogue Russian soldier killed an entire Armenian family, save for a six-month-old infant'},
#  {'label': 'anecdote',
#   'text': 'who later died of his stab wounds, in Gyumri, Armenia'},
#  {'label': 'common-ground',
#   'text': "Gyumri is the country's second-largest city and the host of the Russian military base"},
#  {'label': 'anecdote',
#   'text': 'That senseless act of random violence in the early morning hours of January 12, sparked an immediate and spontaneous outpouring of grief and mourning'},
#  {'label': 'assumption',
#   'text': 'But the initial shock and grief quickly turned to outrage'},
#  {'label': 'no-unit', 'text': 'as'},
#  {'label': 'assumption',
#   'text': 'Russian military officials seemed to take charge of the case with a heavy-handed disdain and disregard for local sensitivities'},
#  {'label': 'assumption',
#   'text': 'That perception was only deepened when Armenian officials were slow to respond or react'},
#  {'label': 'assumption',
#   'text': 'It was this mishandling of the tragedy, even more than the murder itself, that then triggered a series of demonstrations and protests by local Armenians in Gyumri'},
#  {'label': 'anecdote',
#   'text': 'Fearing that the Russian conscript would be moved from his detention within the Russian base and likely returned to Moscow, local residents demanded that the self-confessed soldier be turned over to Armenian authorities'},
#  {'label': 'no-unit', 'text': 'Calming tensions'},
#  {'label': 'anecdote',
#   'text': 'For its part, local Armenian officials and the prosecutor general scurried to calm tensions by first announcing that Armenian investigators were actively participating in the interrogation of the soldier, and then, once that did little to appease the protesters, vowed that the soldier would be tried in Armenia'},
#  {'label': 'assumption',
#   'text': "Amid the Armenian officials' wrangling over the legal process of the case, the absence of any higher level Armenian officials, and the failure of the Armenian president to declare a day of mourning or even make a statement, only escalated the tension"},
#  {'label': 'anecdote',
#   'text': 'And days later, no Armenian official attended the funeral of the murdered family'},
#  {'label': 'anecdote',
#   'text': 'thereby triggering a fresh wave of indignant protests in the city, that later spread to the capital, Yerevan'},
#  {'label': 'anecdote',
#   'text': 'The protests soon moved to the Russian consulate in Gyumri before culminating in a march on the Russian base'},
#  {'label': 'anecdote',
#   'text': 'as protesters broke through a police cordon to enter the base itself'},
#  {'label': 'no-unit', 'text': 'Yet'},
#  {'label': 'assumption',
#   'text': ' there is a deeper context to this public anger'},
#  {'label': 'no-unit', 'text': 'In fact'},
#  {'label': 'assumption',
#   'text': ' that family is only the latest victim in murders and shootings by Russian servicemen stationed at the Russian military base'},
#  {'label': 'anecdote',
#   'text': 'In 1999, two drunk Russian soldiers opened fire on a local market in the city, killing two and injuring dozens of others'},
#  {'label': 'anecdote',
#   'text': 'And in 2013, two children were killed by unexploded ordnance on an unguarded tank firing range on the premises of the Russian base'},
#  {'label': 'no-unit', 'text': 'Bad timing'},
#  {'label': 'assumption',
#   'text': 'Against this backdrop, the tragedy has also raised renewed questions of base security, with outrage that the armed soldier who reportedly deserted his post triggered no notice or alarm by Russian military personnel at the base'},
#  {'label': 'assumption',
#   'text': 'Although this tragedy has prompted a new challenge to Armenian-Russian relations'},
#  {'label': 'assumption',
#   'text': 'it is also exacerbated by a second factor, timing'},
#  {'label': 'assumption',
#   'text': 'The timing of this tragedy could not be much worse, for several reasons'},
#  {'label': 'no-unit', 'text': 'First'},
#  {'label': 'anecdote',
#   'text': ' in 2013, in what many perceived as Russian pressure on its so-called "strategic partner", Armenia was forced to scrap its planned free trade deal with the European Union in favour of joining the Russian-led Eurasian Union'},
#  {'label': 'no-unit', 'text': 'Second'},
#  {'label': 'assumption',
#   'text': ' a steady supply of arms and advanced weapons systems to Azerbaijan from Russia has sowed further distrust'},
#  {'label': 'assumption',
#   'text': 'And most recently, the negative impact on the Armenian economy from western sanctions imposed on Russia, evident in a sudden depreciation of the Armenian currency and reflected in a steep decline in remittances, has only revealed the asymmetry and lack of parity in Armenia\'s "partnership" with Russia'},
#  {'label': 'assumption',
#   'text': "It seems clear that this unexpected challenge to Armenia's reliance on Russia will not dissipate any time soon"},
#  {'label': 'title', 'text': 'The asphyxiated politics of the Muslim world.'},
#  {'label': 'no-unit', 'text': 'With'},
#  {'label': 'assumption',
#   'text': 'ISIL spurring negative media for the past six months and other violent groups competing not far behind in evil acts'},
#  {'label': 'assumption',
#   'text': 'Muslims everywhere have been licking their wounds in recent times'},
#  {'label': 'assumption', 'text': '2014 has been worse'},
#  {'label': 'no-unit', 'text': 'and'},
#  {'label': 'assumption', 'text': 'the crises are worsening'},
#  {'label': 'assumption',
#   'text': 'Will the Muslim world be able to pull itself up from this low or enter into long-term anarchy?'},
#  {'label': 'assumption',
#   'text': 'The fundamental reason behind this shameful situation in many Muslim countries is clearly the failure of political leadership, exacerbated by the sheepish role of the religious scholars and an absence of a strong civil society'},
#  {'label': 'assumption', 'text': 'Islam is still central to Muslim life'},
#  {'label': 'assumption',
#   'text': 'it once shaped Muslims into a successful global community - an "ummah" of purpose - with a few core beliefs, values and deeds for the good of all'},
#  {'label': 'assumption',
#   'text': 'In spite of many pitfalls, sometimes big, Muslims succeeded in building a civilisation that upheld universal human values, blended with the Islamic principles of pluralism'},
#  {'label': 'no-unit', 'text': 'Unpleasant state of affairs'},
#  {'label': 'no-unit', 'text': 'But'},
#  {'label': 'assumption',
#   'text': ' with an increasing knowledge deficit over centuries, the Muslim social and spiritual capitals were dwindling'},
#  {'label': 'assumption',
#   'text': 'As their individual life was losing the spark of faith and positive action, their public life or political leadership was taken over by people of lower moral clarity and spiritual strength'},
#  {'label': 'assumption',
#   'text': 'Much of the world of Islam is now riddled with political strangulation, economic mismanagement and social division'},
#  {'label': 'assumption',
#   'text': 'The post-colonial breed of corrupt, incompetent and often repressive rulers - having little regard for the ordinary people and their human rights or respect for the rule of law - have made their countries ungovernable'},
#  {'label': 'assumption',
#   'text': 'Some are no better than the Soviet-era communist rulers'},
#  {'label': 'assumption',
#   'text': 'Failed politics has widened the rift between political camps, particularly between secularists and Islamists, in some countries'},
#  {'label': 'assumption',
#   'text': 'This has worsened the social divide, with increased intolerance and violence'},
#  {'label': 'assumption',
#   'text': 'All this is impacting negatively on the nascent Muslim minority communities in the West'},
#  {'label': 'assumption',
#   'text': 'The collapse of politics in Iraq and Syria in recent years set off a ruthless proxy war in these historic lands, with the destruction of infrastructure and an unprecedented refugee crisis'},
#  {'label': 'assumption',
#   'text': 'The rise of ISIL and its alluring attraction of young recruits from around the world, including from Muslim minority countries, has raised global Islamophobia to a new level'},
#  {'label': 'common-ground',
#   'text': 'Politicians are meant to act in the interests of their people'},
#  {'label': 'assumption',
#   'text': 'It is not only their civic duty but for a Muslim politician it is their Islamic obligation as well'},
#  {'label': 'assumption',
#   'text': 'No matter what their background is, they should work with fellow politicians with grace and a team ethos - as co-citizens and co-religionists, not as enemies to one another'},
#  {'label': 'assumption',
#   'text': 'This is not too big of a demand in the 21st century'},
#  {'label': 'assumption',
#   'text': 'The overwhelming majority of Muslims across the world are ordinary hardworking people, with love for their land and religion'},
#  {'label': 'assumption',
#   'text': 'They hate extremism and violence, whether political or religious'},
#  {'label': 'assumption',
#   'text': 'They expect some competency and humility from their social and political leaders'},
#  {'label': 'no-unit', 'text': 'A call for a truce between'},
#  {'label': 'no-unit', 'text': 'opposing political forces'},
#  {'label': 'assumption',
#   'text': 'But in much of the Muslim world this is not the case presently'},
#  {'label': 'assumption', 'text': "politics has become an Achilles' heel"},
#  {'label': 'assumption',
#   'text': 'This legacy may go back to their dark days under colonial "divide and rule"'},
#  {'label': 'no-unit', 'text': 'but'},
#  {'label': 'assumption', 'text': 'this can no longer be an excuse'},
#  {'label': 'assumption',
#   'text': 'It is shocking that some Arab countries have degenerated into bloodletting between people of the same history and religion that made them great'},
#  {'label': 'assumption',
#   'text': 'They are on the verge of regressing to the days of pre-Islamic "jahiliya" (ignorance)'},
#  {'label': 'assumption',
#   'text': 'Aside from the influence of unhelpful global politics, the root cause lies in the failure of their own political and religious leaders'},
#  {'label': 'no-unit', 'text': 'Unless'},
#  {'label': 'assumption',
#   'text': "Muslim politicians and civic leaders come to their senses and adopt people-oriented principled politics, improve their accountability and regard themselves as people's servants"},
#  {'label': 'assumption', 'text': 'the situation is going to get worse'},
#  {'label': 'assumption', 'text': 'The current blame game is meaningless'},
#  {'label': 'assumption',
#   'text': 'Politicians do have a higher degree of responsibility to bring a nation out of the political mess'},
#  {'label': 'no-unit', 'text': 'but'},
#  {'label': 'assumption',
#   'text': 'one should not forget that they originate from the society and carry its values, norms and culture'},
#  {'label': 'assumption',
#   'text': 'The whole society must now come to its senses and stand up against this self-annihilation'},
#  {'label': 'assumption',
#   'text': 'The bloodletting between diehard secularists and inexperienced hard-line Islamists in some countries is a boon to entrenched dictators to dig their heels and hegemonic powers to milk national wealth'},
#  {'label': 'assumption',
#   'text': 'Islam is indeed very broad and has the ability to accommodate anyone and everyone'},
#  {'label': 'assumption',
#   'text': 'So, the difference between a Muslim secularist and an Islamist is a matter of degree'},
#  {'label': 'assumption',
#   'text': 'This is being blown up by people of ulterior motives and must be challenged'},
#  {'label': 'assumption',
#   'text': 'Secularists have been in power in much of the Muslim world for decades'},
#  {'label': 'no-unit', 'text': 'and'},
#  {'label': 'assumption',
#   'text': 'they do not want to bow out without a fight'},
#  {'label': 'assumption', 'text': 'Islamists want to unseat them'},
#  {'label': 'assumption',
#   'text': 'but lack the political experience in running the affairs of modern statecraft'},
#  {'label': 'assumption',
#   'text': 'Behind the furore, a democratic deficit and lack of confidence are big issues for many politicians'},
#  {'label': 'assumption', 'text': 'The demons must be slain'},
#  {'label': 'assumption',
#   'text': 'Wise individuals, senior citizens and authoritative institutions should raise their voice of sanity and help set the national conversation among politicians'},
#  {'label': 'assumption',
#   'text': 'Secularists should accept the social reality that there are Islamists in their midst'},
#  {'label': 'no-unit', 'text': 'on the other hand'},
#  {'label': 'assumption', 'text': ' Islamists will also do better'},
#  {'label': 'no-unit', 'text': 'if'},
#  {'label': 'assumption',
#   'text': 'they recognise that secularism is part of modern reality'},
#  {'label': 'common-ground',
#   'text': 'Both groups consist of human beings and cannot be exterminated'},
#  {'label': 'no-unit', 'text': "'Live and let live'"},
#  {'label': 'assumption',
#   'text': 'There is no short-cut to end the chronic and acute political crisis in the Muslim world'},
#  {'label': 'assumption',
#   'text': 'But it is vital all political groups work on the basis of existing socio-political realities and find ways to reconcile with the principle of"live and let live"'},
#  {'label': 'assumption',
#   'text': 'Sensible and moderate people from various political camps should sit together, informally and formally, and find a pragmatic political framework to make democratic politics institutional and allow healthy transition of power'},
#  {'label': 'assumption', 'text': 'Every citizen has a right to rule'},
#  ...]

# %%
def generate_prompt_and_completion(data,isTrain,prompt_text, prompt_end = "####", completion_end = "<|endoftext|>"):    
    ret_dict = {}
    ret_dict['prompt'] = data['text']  ## 
    #if isTrain:
    completion_list = ''
    completion_list=f'''{data['label']}'''  #{sentence['sentence']}
    #print(completion_list)
    # f'''<{sentence['sentiment']}> {sentence['sentence']}'''
    ret_dict['completion'] = completion_list

    return ret_dict

# %%
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
le = preprocessing.LabelEncoder()
#df_main["label"]=le.fit_transform(df_main["label"])
X=df_main["text"]
y=df_main["label"]
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.20, random_state=42,stratify=y)
Train=pd.concat([X_train,y_train],axis=1)
Test=pd.concat([X_test,y_test],axis=1)
trn=getJsonFromFrame(Train)
tst=getJsonFromFrame(Test)
tst
# Out:
# [{'label': 'title',
#   'text': '2015: Beyond Obama, new Congress, we need a revival of the American spirit.'},
#  {'label': 'anecdote',
#   'text': 'In the film, "Girl Interrupted," Winona Ryder plays an 18-year-old who enters a mental institution for what is diagnosed as borderline personality disorder'},
#  {'label': 'anecdote', 'text': 'The year is 1967'},
#  {'label': 'no-unit', 'text': 'and'},
#  {'label': 'anecdote',
#   'text': 'the country is in turmoil over Vietnam and civil rights'},
#  {'label': 'anecdote',
#   'text': 'While lying on her bed one night and watching TV, she sees a news report about a demonstration'},
#  {'label': 'anecdote',
#   'text': 'The narrator says something that might apply to today\'s turmoil:"We live in a time of doubt. The institutions we once trusted no longer seem reliable."'},
#  {'label': 'no-unit', 'text': 'As 2014 ends,'},
#  {'label': 'statistics', 'text': 'the stock market is at record highs'},
#  {'label': 'no-unit', 'text': 'but'},
#  {'label': 'assumption',
#   'text': 'our traditional institutions and self-confidence are in decline'},
#  {'label': 'testimony',
#   'text': 'A Pew Research Center study confirms one trend that has been obvious over several years'},
#  {'label': 'assumption',
#   'text': 'The "typical" American family is no longer typical'},
#  {'label': 'statistics',
#   'text': 'Just 46 percent of American children now live in homes with their married, heterosexual parents'},
#  {'label': 'statistics', 'text': 'Five percent have no parents at home'},
#  {'label': 'testimony',
#   'text': 'They most likely are living with grandparents, says the study'},
#  {'label': 'assumption',
#   'text': 'These startling figures about the decline of the American family contrast with the year 1960'},
#  {'label': 'statistics',
#   'text': 'when 73 percent of American children lived in traditional families'},
#  {'label': 'assumption',
#   'text': 'A major contributor to this trend has been the assault on marriage and other institutions by the Baby Boom generation'},
#  {'label': 'assumption',
#   'text': 'It was that generation that promoted cohabitation, no-fault divorce, hatred of the police(they called them "pigs" then, too) and disdain for the military and America, spawned not just by the Vietnam War but a life of relative ease unknown to their parents'},
#  {'label': 'assumption',
#   'text': 'The culture bomb dropped by the boomers created fallout still being felt today'},
#  {'label': 'assumption',
#   'text': 'The two-plus generations born since the Sixties have been infused with the notion of entitlement, victimhood, envy and greed'},
#  {'label': 'assumption',
#   'text': 'Since the elimination of the draft, young people are no longer expected to serve in the military and so most of them pursue whatever goals they wish with no expectation they should give something back to their country'},
#  {'label': 'assumption',
#   'text': "It's one possible explanation for why we can no longer seem to win wars"},
#  {'label': 'common-ground',
#   'text': 'History warns us what happens when empires refuse to teach known values that strengthen societies and help protect them from enemies intent on their destruction'},
#  {'label': 'anecdote',
#   'text': 'The late British diplomat Sir John Glubb wrote a book called "The Fate of Empires and Search For Survival."'},
#  {'label': 'testimony',
#   'text': 'Glubb noted the average age of empires since the time of ancient Assyria (859-612 B.C ) is 250 years'},
#  {'label': 'testimony',
#   'text': 'Only the Mameluke Empire in Egypt and the Levant (1250-1517) made it as far as 267 years'},
#  {'label': 'assumption',
#   'text': 'America is 238 years old and is exhibiting signs of decline'},
#  {'label': 'testimony',
#   'text': 'All empires begin, writes Glubb, with the age of pioneers, followed by ages of conquest, commerce, affluence, intellect and decadence'},
#  {'label': 'assumption',
#   'text': 'America appears to have reached the age of decadence'},
#  {'label': 'testimony',
#   'text': 'which Glubb defines as marked by "defensiveness, pessimism, materialism, frivolity, an influx of foreigners, the welfare state, (and) a weakening of religion."'},
#  {'label': 'testimony',
#   'text': 'Decadence, he writes,"is due to: Too long a period of wealth and power, selfishness, love of money (and) the loss of a sense of duty."'},
#  {'label': 'assumption',
#   'text': 'Do these not define America at the end of 2014?'},
#  {'label': 'testimony',
#   'text': 'Glubb says the 250-year average of empires has not varied in 3,000 years'},
#  {'label': 'no-unit', 'text': 'but'},
#  {'label': 'testimony',
#   'text': 'we don\' t learn from history because"our studies are brief and prejudiced."'},
#  {'label': 'assumption',
#   'text': "He means they are mostly about one's own country"},
#  {'label': 'assumption',
#   'text': 'It will take more than a new Congress in 2015 and a new president in 2017 to save us from the fate of other empires'},
#  {'label': 'assumption',
#   'text': 'It will take a revival of the American spirit'},
#  {'label': 'no-unit', 'text': 'and'},
#  {'label': 'assumption',
#   'text': 'that can only come through changed attitudes towards our institutions and each other'},
#  {'label': 'title',
#   'text': '2015: Will America continue its slow march toward destruction of liberty?'},
#  {'label': 'anecdote',
#   'text': 'A British author, residing in the United States for the past 30 years, created a small firestorm earlier this week with his candid observations that modern- day Americans have been duped by the government into accepting a European- style march toward socialism'},
#  {'label': 'testimony',
#   'text': "because we fail to appreciate the rich legacy of personal liberty that is everyone's birthright and is expressly articulated in the Declaration of Independence and guaranteed by the U.S  Constitution"},
#  {'label': 'testimony',
#   'text': 'Os Guinness, the author of more than a dozen books defending traditional Judeo-Christian values and Jeffersonian personal liberty, argued that we should embrace individual liberty and personal dignity and reject the "no givens, no rules, no limits" government we now have'},
#  {'label': 'testimony',
#   'text': 'He went on to opine that the government today is not the constitutionally restrained protector of personal freedoms the Framers left us'},
#  {'label': 'testimony',
#   'text': 'but rather has become the wealth-distributing protector of collective interests the Founding Fathers never could have imagined'},
#  {'label': 'assumption', 'text': 'Yet the problem is a deep one'},
#  {'label': 'common-ground',
#   'text': 'The Framers believed in the presumption of liberty'},
#  {'label': 'common-ground',
#   'text': 'which declares that we are free to make personal choices, and the government cannot interfere with our liberties unless we violate the rights of others'},
#  {'label': 'no-unit', 'text': 'Stated differently'},
#  {'label': 'assumption',
#   'text': 'the federal government cannot interfere with our personal choices by writing any law it wants'},
#  {'label': 'assumption',
#   'text': 'it can only regulate behavior or spend money when the Constitution authorizes it to do so'},
#  {'label': 'assumption',
#   'text': 'But for the past 100 years, the federal government has rejected the Madisonian concept that it is limited to the 16 discrete powers the Constitution delegates to it, and has claimed its powers are unlimited, subject only to the express prohibitions in the Constitution'},
#  {'label': 'assumption',
#   'text': 'Even those prohibitions can be gotten around'},
#  {'label': 'assumption',
#   'text': 'since government lawyers have persuaded federal courts to rule that Congress can spend tax dollars or borrowed money on any projects it wishes, whether authorized by the Constitution or not'},
#  {'label': 'assumption',
#   'text': 'The courts even have authorized Congress to use federal tax dollars to bribe the states into enacting laws that Congress is powerless to enact'},
#  {'label': 'no-unit', 'text': 'and'},
#  {'label': 'assumption', 'text': 'Congress has done so'},
#  {'label': 'common-ground',
#   'text': 'The Declaration of Independence defines our personal liberties as inalienable aspects of our humanity'},
#  {'label': 'no-unit', 'text': 'and'},
#  {'label': 'common-ground',
#   'text': 'the Constitution prohibits the government from interfering with those liberties-- like thought, speech, press, association, worship, self-defense, travel, privacy, due process, use of money and private property'},
#  {'label': 'no-unit', 'text': 'to name a few'},
#  {'label': 'common-ground',
#   'text': 'The teaching of these founding documents is that our liberties are natural-- their source is not the government'},
#  {'label': 'no-unit', 'text': '-- and'},
#  {'label': 'common-ground', 'text': 'they are personal, not collective'},
#  {'label': 'common-ground',
#   'text': "We don't need a government permission slip to exercise them"},
#  {'label': 'common-ground',
#   'text': "we don't need to belong to a group to enjoy them"},
#  {'label': 'common-ground',
#   'text': 'they cannot be taken away by a congressional vote or a presidential signature'},
#  {'label': 'common-ground',
#   'text': 'Even though everyone who works for the government takes an oath to uphold the Declaration and the Constitution'},
#  {'label': 'assumption',
#   'text': 'very few are consistent with what they have sworn to do'},
#  {'label': 'assumption',
#   'text': 'We know that because on the transcendental issues of our day -- life, liberty, war and debt -- the leadership of both political parties and the behavior of all modern presidents have revealed a steadfast willingness to write any law and regulate any behavior or permit any evil'},
#  {'label': 'no-unit',
#   'text': ', whether authorized by the Constitution or not.'},
#  {'label': 'other', 'text': 'Take life'},
#  {'label': 'assumption',
#   'text': 'Abortion is the most deadly force in America today'},
#  {'label': 'assumption', 'text': 'Abortions lawfully kill a baby a minute '},
#  {'label': 'no-unit', 'text': '--'},
#  {'label': 'assumption',
#   'text': "that's 1.1 million babies a year and 45,000,000 killed since the Supreme Court issued its Roe v  Wade decision in 1973"},
#  {'label': 'assumption',
#   'text': 'A simple one-line statute --"The fetus in the womb is a legal person"-- could have been enacted by a simple majority vote in Congress and signed into law by any of our so-called pro-life presidents, thus stopping the slaughter'},
#  {'label': 'common-ground', 'text': 'It never happened'},
#  {'label': 'other', 'text': 'Take liberty'},
#  {'label': 'assumption',
#   'text': 'Both parties support the Patriot Act and the secret FISA apparatus'},
#  {'label': 'assumption',
#   'text': 'which together invade privacy, infringe upon free speech, permit federal agents to write their own search warrants and allow domestic spying on all of us all the time'},
#  {'label': 'assumption',
#   'text': 'This demonstrates that our political leaders do not believe that our rights are inalienable, but can be interfered with and regulated by them'},
#  {'label': 'assumption',
#   'text': 'They have written laws that literally permit federal agents to do the very acts the Constitution was written to prohibit'},
#  {'label': 'other', 'text': 'Take the lethal combination of war and debt'},
#  {'label': 'assumption',
#   'text': 'Both parties support perpetual war and perpetual debt'},
#  {'label': 'assumption',
#   'text': 'The leadership of both parties has permitted every modern president to kill whomever he pleases in foreign countries without lawful declarations of war and to do so by going into a $17 trillion hole of debt, with no end in sight'},
#  {'label': 'assumption',
#   'text': 'Today, 20 cents of every tax dollar collected goes to interest on pre-existing government debt'},
#  {'label': 'assumption',
#   'text': "Today's taxpayers are still paying interest on the $30 billion Woodrow Wilson borrowed to finance World War I in 1917"},
#  {'label': 'assumption', 'text': 'The British author is correct'},
#  {'label': 'assumption',
#   'text': 'Unless we have a radical change in the direction of government -- its size, cost, focus, intrusiveness and rejection of first principles -- and unless we elect people to the government who truly believe the Declaration and the Constitution mean what they say, we will continue our march toward the federal destruction of the presumption of liberty'},
#  {'label': 'assumption', 'text': 'It is a slow march, but a steady one'},
#  {'label': 'title',
#   'text': '2015: Will new Congress get serious about Putin, Russia?'},
#  {'label': 'testimony',
#   'text': '"The bear never asks permission," remarked Vladmir Putin on a TV promo for his annual news conference'},
#  {'label': 'other', 'text': 'Yes, we know'},
#  {'label': 'assumption',
#   'text': "The Russians haven't stopped their aggressive posturing after annexing Crimea--not by a long-shot"},
#  {'label': 'anecdote',
#   'text': 'In early December there was another near miss between a Russian military jet with its transponders turned off and a commercial airliner just south of Sweden'},
#  {'label': 'testimony',
#   'text': 'This adds to the list of over 40 serious incidents involving Russia and NATO countries in the last 8 months, as detailed in a report by a British think tank called the European Leadership Network'},
#  {'label': 'assumption',
#   'text': 'President Obama has so far remained unwilling to do little more than levy pin- prick sanctions against specific Russian individuals'},
#  {'label': 'no-unit', 'text': 'but'},
#  {'label': 'assumption',
#   'text': "that doesn't mean Congress is sitting still"},
#  {'label': 'assumption',
#   'text': 'Republicans have continued to show a willingness to get tough with Russia to actually deter it'},
#  {'label': 'anecdote',
#   'text': 'And now the New Year ushers in a Republican majority in the Senate, and a freshly motivated Republican House'},
#  {'label': 'anecdote',
#   'text': 'Several Senators have argued the U.S  should impose much tougher sanctions on whole sectors of the Russian economy, provide significant arms to Ukraine and NATO allies in the region, and should go back to an emphasis on building out missile defense in Europe'},
#  {'label': 'common-ground',
#   'text': 'Moscow has long opposed U.S  missile defense in countries that were once forcibly a part of the Soviet Union'},
#  {'label': 'anecdote',
#   'text': 'Recall the now infamous abandonment by President Obama of the Bush plan to deploy 10 large interceptors in Poland in an effort to appease Russia'},
#  {'label': 'assumption',
#   'text': 'Those same interceptors might not be deployed'},
#  {'label': 'no-unit', 'text': 'but'},
#  {'label': 'assumption',
#   'text': 'the current and more modest plans to build up defenses, could be adapted'},
#  {'label': 'testimony',
#   'text': 'Congressman Mike Tuner, R-Ohio, said in a statement released on December 18, "Given Russia\'s increased aggression toward the West and Iran\\\'s stubbornness toward its nuclear program, we must ensure a robust BMD capability in Europe'},
#  {'label': 'testimony',
#   'text': 'Russia is clearly now a threat to the West."'},
#  {'label': 'common-ground',
#   'text': 'For years the U.S  has insisted that homeland missile defense systems will not be targeted at Russian assets in order to maintain a "strategic balance" between the former Cold War foes'},
#  {'label': 'testimony',
#   'text': 'This remains the position of the U.S as laid out in a 2010 policy document called the Ballistic Missile Defense Review (BMDR)'},
#  {'label': 'common-ground', 'text': 'It is not, however, codified in law'},
#  {'label': 'no-unit', 'text': 'And'},
#  {'label': 'anecdote',
#   'text': 'since the U.S  began deploying more missile defense systems abroad to protect allies and U.S  troops from Iranian missiles, officials have made the case that they were not defending against the shorter range Russian systems'},
#  {'label': 'no-unit', 'text': 'But'},
#  {'label': 'assumption', 'text': 'this may change'},
#  {'label': 'no-unit', 'text': 'and'},
#  {'label': 'assumption',
#   'text': 'if it does, it will be the fault of the Russian government, and to the credit of American officials who are paying close attention'},
#  {'label': 'no-unit', 'text': 'Unconvinced'},
#  {'label': 'no-unit', 'text': 'that the U.S  is not threatening its military'},
#  {'label': 'assumption',
#   'text': 'Russia has moved forward with an aggressive plan to improve in quality and quantity its offensive missile forces and continues to threaten its neighbors (U.S  allies) with them, even threatening to use--preemptively--nuclear weapons'},
#  {'label': 'assumption',
#   'text': 'The revelations that Russia has been in violation of the INF Treaty has also ushered in some bipartisan agreement that perhaps the U.S  should rethink its position regarding missile defense and Russia'},
#  {'label': 'anecdote',
#   'text': 'Democratic Senator Joe Donnelly, R-Ind , raised the issue of speeding up and strengthening U.S  missile defense in Europe in the context of Russian aggression during an April 2, 2014 Senate hearing'},
#  {'label': 'anecdote',
#   'text': 'In the recent omnibus bill Congress approved $20 million to do just that -- speed up the deployment of the European Phased Adaptive Approach-- a missile defense plan to deploy missile defense assets in Europe to protect against the regional Iranian threats'},
#  {'label': 'assumption',
#   'text': 'Between the failure of the infamous "Iran deal" to curb Iranian missile development and Russia\'s continued aggression in the region, this makes perfect sense and is good policy'},
#  {'label': 'testimony',
#   'text': 'In a recent trip to Eastern Europe, the Chairman of the House Strategic Forces Subcommittee, Congressman Mike Rogers, R-Ala , stated that the interceptors in Europe could be made to defend against some Russian threats'},
#  {'label': 'no-unit', 'text': 'As'},
#  {'label': 'no-unit', 'text': 'one can imagine'},
#  {'label': 'assumption',
#   'text': "this didn't thrill the Russians--but short of American decline, what does?"},
#  {'label': 'testimony',
#   'text': 'Russian Foreign Ministry spokesman Alexander Lukashevich said in a statement,"Hence, the U.S  lawmaker confirmed the justifiability of concerns having been aired by Moscow for a long time that the missile shield being developed by the U.S  is intended solely for the purposes officially declared by Washington."'},
#  {'label': 'assumption',
#   'text': 'If the U.S  does configure systems to protect its allies against Russian missiles, it is because it will be because Uncle Sam finally stopped "asking permission" and decided to get serious about deterring "the bear."'},
#  {'label': 'title',
#   'text': '? 300 for a job reference is the latest outrage in the exploitation of interns.'},
#  {'label': 'no-unit', 'text': 'If'},
#  {'label': 'assumption',
#   'text': 'there were an award for scummiest business practice'},
#  {'label': 'assumption',
#   'text': 'refusing to pay interns would get many a vote'},
#  {'label': 'anecdote',
#   'text': 'But Jan Mortier, who until a year ago ran a "junior associates" programme through his thinktank Civitatis International, has upped the stakes by charging former interns(or trainees, as he prefers to think of them) a ? 300 fee for an employment reference'},
#  {'label': 'assumption',
#   'text': 'Is charging someone for a reference after refusing to pay them as scummy as it gets? Sadly not'},
#  {'label': 'assumption', 'text': 'Young people are lucky'},
#  {'label': 'no-unit', 'text': 'if'},
#  {'label': 'assumption',
#   'text': 'unpaid work is the worst deal they are offered'},
#  {'label': 'assumption',
#   'text': 'although the "junior associates" programme was advertised on Internwise, the three-month programme cost more than? 1,600'},
#  {'label': 'testimony',
#   'text': '(Mortier insists it was a training course, not an internship.)'},
#  {'label': 'no-unit', 'text': 'And the winner is '},
#  {'label': 'no-unit', 'text': '...'},
#  {'label': 'assumption',
#   'text': 'But how on Earth did Mortier think he could get away with charging for references, never mind the extortionate fee of? 300?'},
#  {'label': 'assumption',
#   'text': 'His market is ambitious but terrified young people who are overqualified and unemployed'},
#  {'label': 'no-unit', 'text': '- and'},
#  {'label': 'assumption',
#   'text': 'there is easy money to be made from them, for three reasons'},
#  {'label': 'assumption',
#   'text': "First, they've been sent the message that they're of little value to the economy"},
#  {'label': 'assumption',
#   'text': 'Government and businesses have spent the entire economic crisis suggesting that young people lack employable skills'},
#  {'label': 'assumption',
#   'text': 'Repeated references to these elusive skills rarely lead to any kind of specific mention of what they are- or an investigation into why schools and universities stopped teaching them just as the economy collapsed'},
#  {'label': 'no-unit', 'text': 'If'},
#  {'label': 'assumption',
#   'text': "you've spent your life in education only to be called unemployable"},
#  {'label': 'assumption',
#   'text': "the idea that you'd have to pay someone to say nice things about you doesn't seem so far-fetched"},
#  {'label': 'no-unit', 'text': 'Second'},
#  {'label': 'assumption',
#   'text': 'while young people as a group tend not to have much money sloshing around'},
#  {'label': 'assumption',
#   'text': 'their parents and grandparents are supposedly doing OK'},
#  {'label': 'assumption',
#   'text': "People wanting what's best for their kids leads easily to the coughing-up of cash"},
#  {'label': 'no-unit', 'text': 'Third'},
#  {'label': 'assumption',
#   'text': "when it comes to looking for a job, young people are so used to mounting hindrances that you can stick on another like an extra bottle on a drunk's bar tab"},
#  {'label': 'assumption',
#   'text': 'Legend has it that people used to get a job by seeing one they wanted, and applying'},
#  {'label': 'assumption',
#   'text': 'then came the time when they needed qualifications to get the same job'},
#  {'label': 'assumption', 'text': 'then they needed better qualifications'},
#  {'label': 'assumption',
#   'text': 'then they would have to do an unpaid internship'},
#  {'label': 'assumption',
#   'text': "then to prove it wasn't all a fluke they'd have to get qualifications and do an internship"},
#  {'label': 'testimony',
#   'text': 'Now, Civitatis would have you believe that if you attend its summer school you "will gain the advantage over others for internship (sic)"'},
#  {'label': 'no-unit', 'text': 'So,'},
#  {'label': 'anecdote', 'text': '300 for a reference?'},
#  {'label': 'other', 'text': 'Stick it on the bill'},
#  {'label': 'assumption',
#   'text': "But the damage caused by charging for references isn't limited to the spineless gouging of money from naive young people trying to get their first job"},
#  {'label': 'assumption',
#   'text': 'A reference is immediately invalid once money changes hands'},
#  {'label': 'common-ground',
#   'text': "The value of a reference lies in the assumption that it's an honest comment on a person's job performance or character"},
#  {'label': 'assumption',
#   'text': 'The price tag Mortier has attached isn\'t, as he claims, a "fair administrative fee"'},
#  {'label': 'assumption',
#   'text': "It's enough to make a pocket bulge, and certainly enough to be considered a bribe"},
#  {'label': 'assumption',
#   'text': 'no one pays? 300 to be damned with faint praise'},
#  {'label': 'assumption',
#   'text': "Anyone reading a reference signed by Mortier knows he's been paid hundreds for whatever he's written"},
#  {'label': 'no-unit', 'text': 'so'},
#  {'label': 'assumption', 'text': 'it will ring hollow'},
#  {'label': 'assumption',
#   'text': 'Getting a job with worthless education and months-long application processes is already hard enough'},
#  {'label': 'no-unit', 'text': 'If'},
#  {'label': 'assumption', 'text': 'this idea catches on'},
#  {'label': 'assumption',
#   'text': 'references as a measure of a potential candidate will be as devalued as our degrees'},
#  {'label': 'title', 'text': 'Afghanistan at crucial juncture.'},
#  {'label': 'anecdote',
#   'text': 'On Thursday, the so-called London Conference on Afghanistan will convene'},
#  {'label': 'assumption',
#   'text': 'Of all the high-profile international conferences that have been held on Afghanistan over the years- in Bonn, Tokyo, and Istanbul - this comes at a crucial juncture'},
#  {'label': 'anecdote',
#   'text': 'At the end of October, British forces lowered the flag at Camp Bastion - from where they had engaged in the most intense fighting the British army had seen since the Falklands War- and handed over the base to Afghan forces'},
#  {'label': 'anecdote',
#   'text': 'Just over a month later, the Taliban mounted a 14-hour attack on the very same site, killing six Afghan soldiers'},
#  {'label': 'anecdote',
#   'text': 'To the north, in the capital Kabul, insurgents have pulled off a dozen attacks in the space of the last few weeks, striking at diplomats, NGOs, and US contractors'},
#  {'label': 'assumption',
#   'text': 'What explains this spate of violence, and is it a portent for the future of Afghanistan?'},
#  {'label': 'anecdote',
#   'text': "The International Security Assistance Force (ISAF), a US-led group that includes NATO members and others, winds up its mission on New Year's Eve"},
#  {'label': 'anecdote',
#   'text': 'A slimmed-down force of 12,000 foreign troops - mostly American - will stay behind'},
#  {'label': 'no-unit', 'text': 'and'},
#  {'label': 'anecdote',
#   'text': 'US President Barack Obama has authorised the US contingent to continue supporting Afghan National Security Forces (ANSF) throughout 2015, with all of these forces scheduled to leave by the end of 2016'},
#  {'label': 'assumption',
#   'text': 'The US is not, therefore, leaving Afghanistan in the abrupt manner than it left Iraq in 2011'},
#  {'label': 'assumption', 'text': 'But this is a time of dramatic change'},
#  {'label': 'no-unit', 'text': 'Drastic effects on casualties'},
#  {'label': 'assumption',
#   'text': 'For one thing, the ANSF are doing much of the fighting themselves, with drastic effects on casualties'},
#  {'label': 'statistics',
#   'text': 'over 9,000 Afghan troops have died since 2013, four times greater than the entire American death toll since 2001'},
#  {'label': 'statistics',
#   'text': 'Afghan police officers are suffering especially badly, with thousands being killed every month'},
#  {'label': 'anecdote',
#   'text': "At the political level, a new government of national unity, led by President Ashraf Ghani and Chief Executive Abdullah Abdullah, has taken charge after Hamid Karzai's departure"},
#  {'label': 'anecdote',
#   'text': "Ghani is already reported to have opened backchannel talks with the Taliban, visiting both Pakistan and Beijing to seek their help in this effort, cancelling an earlier arms request from India, and even making a highly unorthodox visit to Pakistan's army headquarters, in recognition of Pakistan's long-standing support for the insurgents"},
#  {'label': 'assumption',
#   'text': 'On the ground, the overall picture is mixed'},
#  {'label': 'statistics',
#   'text': 'This year, Taliban-initiated attacks are reported to have fallen by 25 percent'},
#  {'label': 'no-unit', 'text': 'and'},
#  {'label': 'statistics',
#   'text': 'ANSF mounted offensives four to five times more frequently than last year'},
#  {'label': 'no-unit', 'text': 'At the same time'},
#  {'label': 'testimony',
#   'text': 'as political scientist Jason Lyall observed, the recently-concluded fighting season - from April to October - "witnessed the appearance of large Taliban units on the battlefield" for the first time, with a tenth of all Afghan districts seeing "at least one major Taliban offensive"'},
#  {'label': 'testimony',
#   'text': 'Lyall also notes reports of over 1,000 insurgents on the battlefield,"numbers not seen since the Taliban\'s original push to capture Kabul during the 1992-96 civil war"'},
#  {'label': 'assumption',
#   'text': 'While we should take these reports with a pinch of salt'},
#  {'label': 'testimony',
#   'text': 'NATO commanders accuse their Afghan counterparts of exaggerating'},
#  {'label': 'assumption', 'text': 'they do point to a simple, stark fact'},
#  {'label': 'assumption', 'text': 'The insurgency is far from broken'},
#  {'label': 'no-unit', 'text': 'and'},
#  {'label': 'assumption',
#   'text': 'it will be able to pressure the Afghan state for years to come'},
#  {'label': 'assumption',
#   'text': 'In this context, the wave of insurgent attacks might be explained in several ways'},
#  {'label': 'no-unit', 'text': 'First'},
#  {'label': 'assumption',
#   'text': ', these attacks might be intended to drive a wedge between the Afghan government and its foreign patrons, encouraging the latter to abandon their allies more quickly'},
#  {'label': 'testimony',
#   'text': 'As a Taliban spokesman put it bluntly:"Our objective is to force the foreigners to flee Kabul. Before, the foreigners were visible in the provinces. Now that they have limited more of their activities to Kabul, we have also gone to Kabul to target them there."'},
#  {'label': 'assumption', 'text': 'To some extent, this has worked'},
#  {'label': 'anecdote',
#   'text': 'Many aid agencies have pulled out their staff, and restricted their movements'},
#  {'label': 'no-unit', 'text': 'Tarnished credibility'},
#  {'label': 'no-unit', 'text': 'Second'},
#  {'label': 'assumption',
#   'text': " the insurgents failed to seriously disrupt either round of this year's Afghan elections, as they had vowed to do, leaving their credibility somewhat tarnished"},
#  {'label': 'assumption',
#   'text': 'Prominent attacks - publicised with videos - redress this issue, and project strength at the end of a fighting season'},
#  {'label': 'assumption',
#   'text': "They might also be ways of strengthening the insurgency's bargaining position in advance of any peace talks that gain momentum over the next year"},
#  {'label': 'no-unit', 'text': 'Third'},
#  {'label': 'assumption', 'text': 'the insurgency is not a monolith'},
#  {'label': 'no-unit', 'text': 'and'},
#  {'label': 'assumption',
#   'text': 'different parts of the Taliban might be responsible for different attacks'},
#  {'label': 'assumption',
#   'text': 'The Haqqani Network, a semi- autonomous group with close ties to Pakistani intelligence, has proven most effective at projecting suicide bombings into Kabul'},
#  {'label': 'anecdote',
#   'text': 'The Haqqanis were blamed for the most deadly atrocity of the past month, the bombing of a volleyball game in which over 50 Afghans were killed'},
#  {'label': 'assumption',
#   'text': 'In the past, moves towards dialogue between the Afghan government and the Taliban have been met with carefully targeted attacks intended less to strengthen bargaining positions than to disrupt such talks altogether'},
#  {'label': 'no-unit', 'text': 'Whatever'},
#  {'label': 'no-unit', 'text': 'the explanation'},
#  {'label': 'assumption', 'text': 'Afghanistan faces an extremely test period'},
#  {'label': 'assumption',
#   'text': 'Although the presence of US forces provides a safety net throughout next year'},
#  {'label': 'assumption', 'text': 'things look more precarious after that'},
#  {'label': 'common-ground',
#   'text': 'International funding commitments for Afghanistan currently run to 2017'},
#  {'label': 'assumption',
#   'text': 'but that timeline had assumed the insurgency would lose steam by then, allowing ANSF to slim down'},
#  {'label': 'no-unit', 'text': 'If'},
#  {'label': 'assumption', 'text': "that isn't possible"},
#  {'label': 'assumption',
#   'text': 'the annual $4-6bn bill for the security forces is simply unsustainable'},
#  {'label': 'assumption',
#   'text': "This week's London Conference is an opportunity to secure much greater contributions from regional powers"},
#  {'label': 'assumption',
#   'text': 'who have the most at stake if Afghanistan does fall apart once more'},
#  {'label': 'anecdote',
#   'text': "China is, for instance, one of the world's largest economies, a direct neighbour of Afghanistan, and a significant investor there"},
#  {'label': 'no-unit', 'text': 'But'},
#  {'label': 'no-unit', 'text': 'if'},
#  {'label': 'assumption',
#   'text': 'Beijing is unwilling to offer more than a meagre $327m - nearly half the amount Iran pledged in 2012, and far less than Japan or the EU'},
#  {'label': 'no-unit', 'text': '- then'},
#  {'label': 'assumption',
#   'text': 'how are western governments, with their attention directed to threats from Russia and ISIL, supposed to persuade their own public that, after a decade of war, Afghanistan must stay on financial life-support?'},
#  {'label': 'title', 'text': "Afghanistan conference won't rock the boat."},
#  {'label': 'testimony',
#   'text': '"The London Conference on Afghanistan will provide an opportunity for the government of Afghanistan to set out its commitment to reform," states the UK government\'s official webpage of the upcoming meeting between the new Afghan government and its international donors'},
#  {'label': 'testimony',
#   'text': 'The conference is also an opportunity for the international community "to reaffirm its long-term commitment to supporting Afghanistan\'s peaceful development"'},
#  {'label': 'assumption',
#   'text': 'Despite the media hype, the London Conference is nothing more than a routine reunion, set by the 2012 Tokyo Mutual Accountability Framework (TMAF)'},
#  {'label': 'anecdote',
#   'text': 'As part of the agreement, donors pledged support and the Afghan government promised to implement reforms and curb corruption'},
#  {'label': 'anecdote',
#   'text': "The upcoming meeting in the British capital, therefore, is the first in a series of exchanges that will be held every two years, at the ministerial level, between the Afghan and donor governments to assess progress and check TMAF's benchmarks"},
#  {'label': 'no-unit', 'text': 'Still'},
#  {'label': 'assumption',
#   'text': ' the December 4 conference has the potential to ease Afghanistan into a stable and increasingly self-sufficient future and render it a reliable global partner for ensuring peace and stability in the region and beyond'},
#  {'label': 'assumption',
#   'text': 'To utilise this opportunity as more than a routine progress assessment requires a fundamental shift of attitude on both sides'},
#  {'label': 'assumption',
#   'text': 'Lack of concrete success in the military, economic development and governance efforts in post- Taliban Afghanistan needs to be sincerely examined'},
#  {'label': 'no-unit', 'text': 'and'},
#  {'label': 'assumption', 'text': 'adjustments need to be made'},
#  {'label': 'assumption',
#   'text': "There is multitude of examples in the international community's flawed, if not disingenuous, aid programmes and their monitoring in Afghanistan"},
#  {'label': 'anecdote',
#   'text': 'I was hired by a US consultancy firm to map out the field and offer recommendations for the design of a multimillion dollar governance project'},
#  {'label': 'anecdote',
#   'text': 'My report and recommendations, it turned out, were too radical'},
#  {'label': 'anecdote',
#   'text': '"We expected recommendations for cosmetic changes to the ongoing programmes," I was told'},
#  {'label': 'anecdote',
#   'text': '"The donor agency does not want to rock the boat."'},
#  {'label': 'anecdote',
#   'text': 'On another occasion, I was interviewed by a European consultant for his assessment of the first phase of a programme that had consistently been showcased as a "success story" by donors and the Afghan government'},
#  {'label': 'anecdote',
#   'text': 'In his three-day field trip to Kabul, he had held meetings with three embassies, the UN, the Afghan head of the implementing agency and me'},
#  {'label': 'anecdote',
#   'text': 'Eagerly, I began to point to the flaws of the programme and offered suggestions for improvement'},
#  {'label': 'anecdote', 'text': 'I also offered assistance for site visits'},
#  {'label': 'anecdote',
#   'text': '"Do n\'t waste your time and mine," the septuagenarian consultant told me'},
#  {'label': 'anecdote',
#   'text': '"The donor agency expects a rosy report highlighting only the positive."'},
#  {'label': 'anecdote',
#   'text': 'He further clarified that the decision to fund the second phase had already been made and it had more to do with international aid politics, than development logic'},
#  {'label': 'common-ground',
#   'text': 'Numbers provide an easy way to illustrate success'},
#  {'label': 'assumption',
#   'text': 'especially when seeking international aid budget approval from legislative bodies'},
#  {'label': 'assumption',
#   'text': "While figures indicating Afghanistan's progress towards development are impressive and could not have been achieved without generous international assistance"},
#  {'label': 'assumption',
#   'text': 'they conceal a lack of attention to quality'},
#  {'label': 'statistics',
#   'text': 'About 8 million Afghan children - including over 2.5 million girls - are now in school'},
#  {'label': 'anecdote',
#   'text': 'This is a figure cited regularly as an indication that the programmes are yielding tangible results'},
#  {'label': 'assumption',
#   'text': 'The fact that most of them graduate only half-literate is never revealed'},
#  {'label': 'assumption', 'text': "Here's another feel-good figure"},
#  {'label': 'statistics',
#   'text': 'More than 60 percent of the Afghan population now has access to healthcare facilities'},
#  {'label': 'assumption',
#   'text': 'The fact that some of those facilities have only received a checkmark because merely a building was constructed and many are staffed only with a nurse, have no diagnostic technology and have terribly anaemic pharmaceutical offerings is often ignored'},
#  {'label': 'assumption',
#   'text': "Much has been written about the fact that a hefty portion of the aid money goes back to donor countries because of the donors' insistence to award contracts to their own citizens"},
#  {'label': 'anecdote', 'text': 'The contracts move hand to hand'},
#  {'label': 'no-unit', 'text': 'and'},
#  {'label': 'anecdote',
#   'text': 'finally local non-governmental agencies are hired to implement projects'},
#  {'label': 'no-unit', 'text': 'At this point'},
#  {'label': 'assumption',
#   'text': 'while at best one-quarter of the original funds remains to be spent on the actual project, quality is grossly compromised'},
#  {'label': 'no-unit', 'text': 'and'},
#  {'label': 'assumption',
#   'text': 'monitoring becomes either too complex or irrelevant'},
#  {'label': 'assumption',
#   'text': 'The international community has also created an indigenous vehicle for channelling portions of its assistance'},
#  {'label': 'assumption',
#   'text': 'Under the guise of "civil society", hundreds of Afghan NGOs have been established since 2002'},
#  {'label': 'assumption',
#   'text': "This artificial civil society's lifeline is the donor community in Kabul"},
#  {'label': 'assumption',
#   'text': "Projects and funds are handed to them for implementation and as the closing of fiscal year in donor capitals approaches, generosity in disbursing funds, irrespective of the projects' logic, utility and cost increases"},
#  {'label': 'no-unit', 'text': 'Where'},
#  {'label': 'no-unit', 'text': 'the funds go'},
#  {'label': 'assumption',
#   'text': 'Granted that when international aid began to pour in, the Afghan state had very small, if any, capacity to absorb and spend it'},
#  {'label': 'no-unit', 'text': 'However'},
#  {'label': 'assumption',
#   'text': ' after 13 years and millions of dollars spent on public sector capacity building, the bulk of the funds continue to be spent directly by donors'},
#  {'label': 'no-unit', 'text': 'and'},
#  {'label': 'statistics',
#   'text': 'only a little over 20 percent is given to the Afghan government'},
#  {'label': 'assumption',
#   'text': 'The parallel system and structures offering higher salaries paid in US dollars have lured much of the skilled Afghan human resources'},
#  {'label': 'assumption',
#   'text': 'The Afghan administration, thus, has to be grateful to donors for funding training workshops, while in the end, loses its best trained personnel to international organisations, consulting firms and embassies'},
#  {'label': 'anecdote',
#   'text': "It is often said that rampant Afghan corruption and lack of capacity would result in misuse and waste of donors' funds"},
#  {'label': 'statistics',
#   'text': 'A mere review of reports published by the US oversight agency, Special Inspector General for Afghanistan Reconstruction (SIGAR), reveals the depth and extent of waste, fraud and abuse of the direct US aid to Afghanistan just in reconstruction projects'},
#  {'label': 'assumption',
#   'text': "Similar monitoring of most donors' direct aid will, no doubt, highlight comparable corruption and waste"},
#  {'label': 'assumption',
#   'text': 'The government of former President Hamid Karzai admittedly failed to launch a genuine fight against corruption'},
#  {'label': 'assumption',
#   'text': 'Lack of capacity for a governance vision that would make optimum use of international aid was also a defect of the previous leadership'},
#  {'label': 'assumption',
#   'text': 'High-level appointments were based not on competence and commitment of individuals, but rather on political affiliations and compromises on the one hand, and submissiveness of a handful of "yes sir" entities on the other'},
#  {'label': 'no-unit', 'text': 'Thus'},
#  {'label': 'assumption',
#   'text': ' both sides - donors and the Afghan government - went on for a decade playing a futile blame game'},
#  {'label': 'assumption',
#   'text': 'each accusing the other of corruption and insincerity'},
#  {'label': 'no-unit', 'text': 'Now'},
#  {'label': 'assumption',
#   'text': " on the eve of the London Conference, a new page has turned in Afghanistan's leadership and governance"},
#  {'label': 'assumption',
#   'text': 'The level of optimism among ordinary Afghans is only comparable to the euphoria of the first weeks following the fall of the Taliban regime'},
#  {'label': 'assumption',
#   'text': 'This renewed domestic hope and confidence in the new leadership must not be let to deflate'},
#  {'label': 'anecdote',
#   'text': 'Although the new administration has not yet launched its overhauling programme'},
#  {'label': 'assumption',
#   'text': "President Ashraf Ghani's vision and capacity is well known"},
#  {'label': 'assumption',
#   'text': 'Donors at the London Conference must seize the chance and afford him confidence'},
#  {'label': 'assumption',
#   'text': 'They must also adapt a fundamentally new approach to dispensing their generous assistance to Afghanistan'},
#  {'label': 'assumption',
#   'text': 'A significant funnelling of international aid through the Afghan government (with oversight and accountability benchmarks), a shift of emphasis from quantity to quality, with particular focus on raising the quality of education and finally, a sincere commitment from both sides to the establishment of rule of law will ensure the stability and eventual self-reliance of Afghanistan'},
#  {'label': 'title', 'text': 'Is Afghanistan ready for the drawdown?'},
#  {'label': 'anecdote',
#   'text': 'After 13 years of the International Security Assistance Force (ISAF), the United States and a number of its NATO partners will start the Resolute Support Mission in Afghanistan'},
#  {'label': 'anecdote',
#   'text': 'The number of NATO and US forces is reduced from 140,000 to 13,500 - most of them American- starting January 1'},
#  {'label': 'anecdote',
#   'text': 'How will the new national unity government in Kabul weather the NATO drawdown, despite a resilient insurgency and intensified fighting?'},
#  {'label': 'assumption',
#   'text': 'There has been much speculation about the security transition in 2014 in Afghanistan'},
#  {'label': 'anecdote',
#   'text': 'In 2012, I wrote an Oped for the New York Times, warning that "Kabul risks political meltdown"'},
#  {'label': 'testimony',
#   'text': 'Many other analysts have also predicted a sombre year, particularly after the refusal of former President Hamid Karzai to sign the Bilateral Security Agreement (BSA) with the US'},
#  {'label': 'no-unit', 'text': 'However'},
#  {'label': 'assumption',
#   'text': ' for the time being, we were all proved wrong as the democratic process that began at the Bonn Conference in 2001, survived'},
#  {'label': 'no-unit', 'text': 'and'},
#  {'label': 'assumption',
#   'text': 'the country was saved from the brink of a new civil war'},
#  {'label': 'assumption',
#   'text': "Indeed we have achieved important strategic gains in the last few months, starting with the landmark peaceful transfer of political power from one democratically elected leader to another, for the first time in Afghanistan's history"},
#  {'label': 'assumption',
#   'text': 'This milestone was made possible by the will of ordinary Afghan people'},
#  {'label': 'anecdote',
#   'text': 'who twice braved the threat of violence imposed by the Taliban and came out en masse, voting for their candidates of choice'},
#  {'label': 'assumption',
#   'text': 'Meanwhile, the Taliban has tried hard to undermine the electoral process'},
#  {'label': 'assumption',
#   'text': 'By confronting Afghan security forces in 16 different provinces, they wanted to gain significant territory'},
#  {'label': 'assumption',
#   'text': 'thus declaring themselves as an alternative governing force in the country'},
#  {'label': 'no-unit', 'text': 'Nevertheless'},
#  {'label': 'assumption',
#   'text': ' the Afghan security forces have been able to hold ground and push back the insurgent offensives in almost all fronts'},
#  {'label': 'assumption',
#   'text': 'which has became a source of pride for the Afghan government and people'},
#  {'label': 'assumption',
#   'text': 'This proved wrong skeptics who doubted the capacity of the Afghan security forces to defend their country'},
#  {'label': 'anecdote',
#   'text': 'which has taken responsibility for security in many provinces since the start of the security transition in 2012'},
#  {'label': 'anecdote',
#   'text': 'Following the inauguration of President Ashraf Ghani and Chief Executive Officer (CEO) Abdullah Abdullah, the BSA was immediately signed, approved by an overwhelming majority of Afghan Members of Parliament'},
#  {'label': 'assumption',
#   'text': 'In addition to the BSA, the signing of the Status of Force Agreement (SOFA) between NATO and the new Afghan government has created a new momentum in the country, while ensuring continued military and financial assistance for the new government'},
#  {'label': 'assumption',
#   'text': 'This has inherited an economic crisis, characterised by a fiscal gap resulting from the failures of the previous government'},
#  {'label': 'assumption',
#   'text': "Afghanistan's strategic gains are still contingent upon two important factors"},
#  {'label': 'assumption',
#   'text': 'Firstly, there must be continued NATO support for the Afghan security forces'},
#  {'label': 'assumption',
#   'text': 'This is done by building the capacity of the forces; providing adequate resources such as fire power and particularly air power; assisting in intelligence gathering; and logistics support'},
#  {'label': 'assumption',
#   'text': 'Without the technical and financial support from the US and NATO countries, the Afghan security forces will not be able to sustain a high rate of casualties against the Taliban'},
#  {'label': 'statistics',
#   'text': 'For instance in 2014, an additional 5,000 members of the Afghan security forces were killed either in direct fighting against the Taliban or because of terrorist attacks such as suicide and road side bombings'},
#  {'label': 'assumption',
#   'text': 'Secondly, the government has the capacity to reform the security intuitions in order to reduce the level of corruption and eliminate political influence exercised by important power brokers'},
#  {'label': 'assumption',
#   'text': "The financing of the Afghan security forces are beyond the Afghan government's resources and is totally dependent on donors' contribution"},
#  {'label': 'assumption',
#   'text': 'The government could make significant contributions by reducing costs'},
#  {'label': 'assumption',
#   'text': 'This could be done through reducing corruption and improving management'},
#  {'label': 'no-unit', 'text': 'Meanwhile'},
# ...
#  {'label': 'testimony',
#   'text': 'while civil society organisations question the use of agricultural land to produce grains to feed machines rather than people'},
#  {'label': 'no-unit', 'text': 'Still'},
#  {'label': 'assumption', 'text': ' there are signs of hope'},
#  {'label': 'anecdote',
#   'text': 'On December 3, the Argentinean Senate approved tax incentives for the generation of electricity from renewable energy sources'},
#  {'label': 'assumption',
#   'text': 'The Chamber of Deputies is likely to make it law next year'},
#  {'label': 'assumption',
#   'text': "But in light of Argentina's environmental record, there is clearly a lot of work yet to be done and many more laws and policies to be implemented"},
#  {'label': 'title', 'text': "Armenia can't count on Russia any more."},
#  {'label': 'assumption',
#   'text': 'For Armenia, its role as a reliable partner and ally of Russia has never faced any real challenge'},
#  {'label': 'assumption',
#   'text': 'Much of this reliance on Russia stems from essential security and economic concerns'},
#  {'label': 'assumption',
#   'text': 'Armenia\'s security reliance on Russia is driven by a virtual state of war with neighbouring Azerbaijan, rooted in the Nagorno-Karabakh conflict, only exacerbated by the absence of "normal" diplomatic relations and closed border with Turkey'},
#  {'label': 'assumption',
#   'text': 'And with the Turkish refusal to recognise the Armenian genocide, this threat perception is only magnified'},
#  {'label': 'assumption',
#   'text': 'For small, landlocked Armenia, a strategic alliance with Russia is generally accepted as essential in the face of such inherent insecurity'},
#  {'label': 'assumption',
#   'text': 'And beyond an imperative of security, Armenia also depends on Russia as a crucial source of remittances, or money sent home by large numbers of Armenians living and working in Russia'},
#  {'label': 'no-unit', 'text': 'Yet'},
#  {'label': 'assumption',
#   'text': ' there is a surprisingly intense debate now under way within Armenia that seriously questions these fundamental pillars of the Armenian-Russian relationship'},
#  {'label': 'no-unit', 'text': 'New challenge'},
#  {'label': 'assumption',
#   'text': "More specifically, this new challenge to Armenia's traditional reliance on Russia is driven by two significant factors: tragedy and timing"},
#  {'label': 'assumption', 'text': 'A tragedy first triggered this turnabout'},
#  {'label': 'anecdote',
#   'text': 'when a rogue Russian soldier killed an entire Armenian family, save for a six-month-old infant'},
#  {'label': 'anecdote',
#   'text': 'who later died of his stab wounds, in Gyumri, Armenia'},
#  {'label': 'common-ground',
#   'text': "Gyumri is the country's second-largest city and the host of the Russian military base"},
#  {'label': 'anecdote',
#   'text': 'That senseless act of random violence in the early morning hours of January 12, sparked an immediate and spontaneous outpouring of grief and mourning'},
#  {'label': 'assumption',
#   'text': 'But the initial shock and grief quickly turned to outrage'},
#  {'label': 'no-unit', 'text': 'as'},
#  {'label': 'assumption',
#   'text': 'Russian military officials seemed to take charge of the case with a heavy-handed disdain and disregard for local sensitivities'},
#  {'label': 'assumption',
#   'text': 'That perception was only deepened when Armenian officials were slow to respond or react'},
#  {'label': 'assumption',
#   'text': 'It was this mishandling of the tragedy, even more than the murder itself, that then triggered a series of demonstrations and protests by local Armenians in Gyumri'},
#  {'label': 'anecdote',
#   'text': 'Fearing that the Russian conscript would be moved from his detention within the Russian base and likely returned to Moscow, local residents demanded that the self-confessed soldier be turned over to Armenian authorities'},
#  {'label': 'no-unit', 'text': 'Calming tensions'},
#  {'label': 'anecdote',
#   'text': 'For its part, local Armenian officials and the prosecutor general scurried to calm tensions by first announcing that Armenian investigators were actively participating in the interrogation of the soldier, and then, once that did little to appease the protesters, vowed that the soldier would be tried in Armenia'},
#  {'label': 'assumption',
#   'text': "Amid the Armenian officials' wrangling over the legal process of the case, the absence of any higher level Armenian officials, and the failure of the Armenian president to declare a day of mourning or even make a statement, only escalated the tension"},
#  {'label': 'anecdote',
#   'text': 'And days later, no Armenian official attended the funeral of the murdered family'},
#  {'label': 'anecdote',
#   'text': 'thereby triggering a fresh wave of indignant protests in the city, that later spread to the capital, Yerevan'},
#  {'label': 'anecdote',
#   'text': 'The protests soon moved to the Russian consulate in Gyumri before culminating in a march on the Russian base'},
#  {'label': 'anecdote',
#   'text': 'as protesters broke through a police cordon to enter the base itself'},
#  {'label': 'no-unit', 'text': 'Yet'},
#  {'label': 'assumption',
#   'text': ' there is a deeper context to this public anger'},
#  {'label': 'no-unit', 'text': 'In fact'},
#  {'label': 'assumption',
#   'text': ' that family is only the latest victim in murders and shootings by Russian servicemen stationed at the Russian military base'},
#  {'label': 'anecdote',
#   'text': 'In 1999, two drunk Russian soldiers opened fire on a local market in the city, killing two and injuring dozens of others'},
#  {'label': 'anecdote',
#   'text': 'And in 2013, two children were killed by unexploded ordnance on an unguarded tank firing range on the premises of the Russian base'},
#  {'label': 'no-unit', 'text': 'Bad timing'},
#  {'label': 'assumption',
#   'text': 'Against this backdrop, the tragedy has also raised renewed questions of base security, with outrage that the armed soldier who reportedly deserted his post triggered no notice or alarm by Russian military personnel at the base'},
#  {'label': 'assumption',
#   'text': 'Although this tragedy has prompted a new challenge to Armenian-Russian relations'},
#  {'label': 'assumption',
#   'text': 'it is also exacerbated by a second factor, timing'},
#  {'label': 'assumption',
#   'text': 'The timing of this tragedy could not be much worse, for several reasons'},
#  {'label': 'no-unit', 'text': 'First'},
#  {'label': 'anecdote',
#   'text': ' in 2013, in what many perceived as Russian pressure on its so-called "strategic partner", Armenia was forced to scrap its planned free trade deal with the European Union in favour of joining the Russian-led Eurasian Union'},
#  {'label': 'no-unit', 'text': 'Second'},
#  {'label': 'assumption',
#   'text': ' a steady supply of arms and advanced weapons systems to Azerbaijan from Russia has sowed further distrust'},
#  {'label': 'assumption',
#   'text': 'And most recently, the negative impact on the Armenian economy from western sanctions imposed on Russia, evident in a sudden depreciation of the Armenian currency and reflected in a steep decline in remittances, has only revealed the asymmetry and lack of parity in Armenia\'s "partnership" with Russia'},
#  {'label': 'assumption',
#   'text': "It seems clear that this unexpected challenge to Armenia's reliance on Russia will not dissipate any time soon"},
#  {'label': 'title', 'text': 'The asphyxiated politics of the Muslim world.'},
#  {'label': 'no-unit', 'text': 'With'},
#  {'label': 'assumption',
#   'text': 'ISIL spurring negative media for the past six months and other violent groups competing not far behind in evil acts'},
#  {'label': 'assumption',
#   'text': 'Muslims everywhere have been licking their wounds in recent times'},
#  {'label': 'assumption', 'text': '2014 has been worse'},
#  {'label': 'no-unit', 'text': 'and'},
#  {'label': 'assumption', 'text': 'the crises are worsening'},
#  {'label': 'assumption',
#   'text': 'Will the Muslim world be able to pull itself up from this low or enter into long-term anarchy?'},
#  {'label': 'assumption',
#   'text': 'The fundamental reason behind this shameful situation in many Muslim countries is clearly the failure of political leadership, exacerbated by the sheepish role of the religious scholars and an absence of a strong civil society'},
#  {'label': 'assumption', 'text': 'Islam is still central to Muslim life'},
#  {'label': 'assumption',
#   'text': 'it once shaped Muslims into a successful global community - an "ummah" of purpose - with a few core beliefs, values and deeds for the good of all'},
#  {'label': 'assumption',
#   'text': 'In spite of many pitfalls, sometimes big, Muslims succeeded in building a civilisation that upheld universal human values, blended with the Islamic principles of pluralism'},
#  {'label': 'no-unit', 'text': 'Unpleasant state of affairs'},
#  {'label': 'no-unit', 'text': 'But'},
#  {'label': 'assumption',
#   'text': ' with an increasing knowledge deficit over centuries, the Muslim social and spiritual capitals were dwindling'},
#  {'label': 'assumption',
#   'text': 'As their individual life was losing the spark of faith and positive action, their public life or political leadership was taken over by people of lower moral clarity and spiritual strength'},
#  {'label': 'assumption',
#   'text': 'Much of the world of Islam is now riddled with political strangulation, economic mismanagement and social division'},
#  {'label': 'assumption',
#   'text': 'The post-colonial breed of corrupt, incompetent and often repressive rulers - having little regard for the ordinary people and their human rights or respect for the rule of law - have made their countries ungovernable'},
#  {'label': 'assumption',
#   'text': 'Some are no better than the Soviet-era communist rulers'},
#  {'label': 'assumption',
#   'text': 'Failed politics has widened the rift between political camps, particularly between secularists and Islamists, in some countries'},
#  {'label': 'assumption',
#   'text': 'This has worsened the social divide, with increased intolerance and violence'},
#  {'label': 'assumption',
#   'text': 'All this is impacting negatively on the nascent Muslim minority communities in the West'},
#  {'label': 'assumption',
#   'text': 'The collapse of politics in Iraq and Syria in recent years set off a ruthless proxy war in these historic lands, with the destruction of infrastructure and an unprecedented refugee crisis'},
#  {'label': 'assumption',
#   'text': 'The rise of ISIL and its alluring attraction of young recruits from around the world, including from Muslim minority countries, has raised global Islamophobia to a new level'},
#  {'label': 'common-ground',
#   'text': 'Politicians are meant to act in the interests of their people'},
#  {'label': 'assumption',
#   'text': 'It is not only their civic duty but for a Muslim politician it is their Islamic obligation as well'},
#  {'label': 'assumption',
#   'text': 'No matter what their background is, they should work with fellow politicians with grace and a team ethos - as co-citizens and co-religionists, not as enemies to one another'},
#  {'label': 'assumption',
#   'text': 'This is not too big of a demand in the 21st century'},
#  {'label': 'assumption',
#   'text': 'The overwhelming majority of Muslims across the world are ordinary hardworking people, with love for their land and religion'},
#  {'label': 'assumption',
#   'text': 'They hate extremism and violence, whether political or religious'},
#  {'label': 'assumption',
#   'text': 'They expect some competency and humility from their social and political leaders'},
#  {'label': 'no-unit', 'text': 'A call for a truce between'},
#  {'label': 'no-unit', 'text': 'opposing political forces'},
#  {'label': 'assumption',
#   'text': 'But in much of the Muslim world this is not the case presently'},
#  {'label': 'assumption', 'text': "politics has become an Achilles' heel"},
#  {'label': 'assumption',
#   'text': 'This legacy may go back to their dark days under colonial "divide and rule"'},
#  {'label': 'no-unit', 'text': 'but'},
#  {'label': 'assumption', 'text': 'this can no longer be an excuse'},
#  {'label': 'assumption',
#   'text': 'It is shocking that some Arab countries have degenerated into bloodletting between people of the same history and religion that made them great'},
#  {'label': 'assumption',
#   'text': 'They are on the verge of regressing to the days of pre-Islamic "jahiliya" (ignorance)'},
#  {'label': 'assumption',
#   'text': 'Aside from the influence of unhelpful global politics, the root cause lies in the failure of their own political and religious leaders'},
#  {'label': 'no-unit', 'text': 'Unless'},
#  {'label': 'assumption',
#   'text': "Muslim politicians and civic leaders come to their senses and adopt people-oriented principled politics, improve their accountability and regard themselves as people's servants"},
#  {'label': 'assumption', 'text': 'the situation is going to get worse'},
#  {'label': 'assumption', 'text': 'The current blame game is meaningless'},
#  {'label': 'assumption',
#   'text': 'Politicians do have a higher degree of responsibility to bring a nation out of the political mess'},
#  {'label': 'no-unit', 'text': 'but'},
#  {'label': 'assumption',
#   'text': 'one should not forget that they originate from the society and carry its values, norms and culture'},
#  {'label': 'assumption',
#   'text': 'The whole society must now come to its senses and stand up against this self-annihilation'},
#  {'label': 'assumption',
#   'text': 'The bloodletting between diehard secularists and inexperienced hard-line Islamists in some countries is a boon to entrenched dictators to dig their heels and hegemonic powers to milk national wealth'},
#  {'label': 'assumption',
#   'text': 'Islam is indeed very broad and has the ability to accommodate anyone and everyone'},
#  {'label': 'assumption',
#   'text': 'So, the difference between a Muslim secularist and an Islamist is a matter of degree'},
#  {'label': 'assumption',
#   'text': 'This is being blown up by people of ulterior motives and must be challenged'},
#  {'label': 'assumption',
#   'text': 'Secularists have been in power in much of the Muslim world for decades'},
#  {'label': 'no-unit', 'text': 'and'},
#  {'label': 'assumption',
#   'text': 'they do not want to bow out without a fight'},
#  {'label': 'assumption', 'text': 'Islamists want to unseat them'},
#  {'label': 'assumption',
#   'text': 'but lack the political experience in running the affairs of modern statecraft'},
#  {'label': 'assumption',
#   'text': 'Behind the furore, a democratic deficit and lack of confidence are big issues for many politicians'},
#  {'label': 'assumption', 'text': 'The demons must be slain'},
#  {'label': 'assumption',
#   'text': 'Wise individuals, senior citizens and authoritative institutions should raise their voice of sanity and help set the national conversation among politicians'},
#  {'label': 'assumption',
#   'text': 'Secularists should accept the social reality that there are Islamists in their midst'},
#  {'label': 'no-unit', 'text': 'on the other hand'},
#  {'label': 'assumption', 'text': ' Islamists will also do better'},
#  {'label': 'no-unit', 'text': 'if'},
#  {'label': 'assumption',
#   'text': 'they recognise that secularism is part of modern reality'},
#  {'label': 'common-ground',
#   'text': 'Both groups consist of human beings and cannot be exterminated'},
#  {'label': 'no-unit', 'text': "'Live and let live'"},
#  {'label': 'assumption',
#   'text': 'There is no short-cut to end the chronic and acute political crisis in the Muslim world'},
#  {'label': 'assumption',
#   'text': 'But it is vital all political groups work on the basis of existing socio-political realities and find ways to reconcile with the principle of"live and let live"'},
#  {'label': 'assumption',
#   'text': 'Sensible and moderate people from various political camps should sit together, informally and formally, and find a pragmatic political framework to make democratic politics institutional and allow healthy transition of power'},
#  {'label': 'assumption', 'text': 'Every citizen has a right to rule'},
#  ...]

# %%
training_list = []
to_predict_list = []
fixed_propmt=""#" This is "
trn=getJsonFromFrame(Train)
tst=getJsonFromFrame(Test)
for item in trn:
    training_list.append(generate_prompt_and_completion(item,True,fixed_propmt))
for item in tst:
    to_predict_list.append(generate_prompt_and_completion(item,False,fixed_propmt))

# %%
def parse_completion(completion):
    compensation_sentences = re.findall(r'<(.*?)> ', completion) ## Our regular expression here is simple because we designed it conveniently!

    completion_dict = {
        'sentences' : compensation_sentences,
        'num_title' : 0,
        'num_anecdote' : 0,
        'num_assumption' : 0,
        'num_nounit' : 0,
        'num_statistics' : 0,
        'num_testimony' : 0,
        'num_commonground' : 0,
        'num_other' : 0
        #'num_assumption' : len(compensation_sentences)
    }

    for sen in compensation_sentences:
        print(sen)
        if sen == 'title':
            completion_dict['num_title'] += 1
        elif sen == 'anecdote':
            completion_dict['num_anecdote'] += 1
        elif sen == 'assumption':
            completion_dict['num_assumption']  += 1
        elif sen == 'no-unit':
            completion_dict['num_nounit']  += 1
        elif sen == 'statistics':
            completion_dict['num_statistics']  += 1 
        elif sen == 'testimony':
            completion_dict['num_testimony']  += 1 
        elif sen == 'common-ground':
            completion_dict['num_commonground']  += 1 
        elif sen == 'other':
            completion_dict['num_other']  += 1                    

    return completion_dict

# %%
trnList=[]
for training_item in training_list[:100]:
    trnList.append((training_item['prompt'],training_item['completion']))
#print(few_shot_prompt)
trnList
# Out:
# [('2015: Beyond Obama, new Congress, we need a revival of the American spirit.',
#   'title'),
#  ('In the film, "Girl Interrupted," Winona Ryder plays an 18-year-old who enters a mental institution for what is diagnosed as borderline personality disorder',
#   'anecdote'),
#  ('The year is 1967', 'anecdote'),
#  ('and', 'no-unit'),
#  ('the country is in turmoil over Vietnam and civil rights', 'anecdote'),
#  ('While lying on her bed one night and watching TV, she sees a news report about a demonstration',
#   'anecdote'),
#  ('The narrator says something that might apply to today\'s turmoil:"We live in a time of doubt. The institutions we once trusted no longer seem reliable."',
#   'anecdote'),
#  ('As 2014 ends,', 'no-unit'),
#  ('the stock market is at record highs', 'statistics'),
#  ('but', 'no-unit'),
#  ('our traditional institutions and self-confidence are in decline',
#   'assumption'),
#  ('A Pew Research Center study confirms one trend that has been obvious over several years',
#   'testimony'),
#  ('The "typical" American family is no longer typical', 'assumption'),
#  ('Just 46 percent of American children now live in homes with their married, heterosexual parents',
#   'statistics'),
#  ('Five percent have no parents at home', 'statistics'),
#  ('They most likely are living with grandparents, says the study',
#   'testimony'),
#  ('These startling figures about the decline of the American family contrast with the year 1960',
#   'assumption'),
#  ('when 73 percent of American children lived in traditional families',
#   'statistics'),
#  ('A major contributor to this trend has been the assault on marriage and other institutions by the Baby Boom generation',
#   'assumption'),
#  ('It was that generation that promoted cohabitation, no-fault divorce, hatred of the police(they called them "pigs" then, too) and disdain for the military and America, spawned not just by the Vietnam War but a life of relative ease unknown to their parents',
#   'assumption'),
#  ('The culture bomb dropped by the boomers created fallout still being felt today',
#   'assumption'),
#  ('The two-plus generations born since the Sixties have been infused with the notion of entitlement, victimhood, envy and greed',
#   'assumption'),
#  ('Since the elimination of the draft, young people are no longer expected to serve in the military and so most of them pursue whatever goals they wish with no expectation they should give something back to their country',
#   'assumption'),
#  ("It's one possible explanation for why we can no longer seem to win wars",
#   'assumption'),
#  ('History warns us what happens when empires refuse to teach known values that strengthen societies and help protect them from enemies intent on their destruction',
#   'common-ground'),
#  ('The late British diplomat Sir John Glubb wrote a book called "The Fate of Empires and Search For Survival."',
#   'anecdote'),
#  ('Glubb noted the average age of empires since the time of ancient Assyria (859-612 B.C ) is 250 years',
#   'testimony'),
#  ('Only the Mameluke Empire in Egypt and the Levant (1250-1517) made it as far as 267 years',
#   'testimony'),
#  ('America is 238 years old and is exhibiting signs of decline', 'assumption'),
#  ('All empires begin, writes Glubb, with the age of pioneers, followed by ages of conquest, commerce, affluence, intellect and decadence',
#   'testimony'),
#  ('America appears to have reached the age of decadence', 'assumption'),
#  ('which Glubb defines as marked by "defensiveness, pessimism, materialism, frivolity, an influx of foreigners, the welfare state, (and) a weakening of religion."',
#   'testimony'),
#  ('Decadence, he writes,"is due to: Too long a period of wealth and power, selfishness, love of money (and) the loss of a sense of duty."',
#   'testimony'),
#  ('Do these not define America at the end of 2014?', 'assumption'),
#  ('Glubb says the 250-year average of empires has not varied in 3,000 years',
#   'testimony'),
#  ('but', 'no-unit'),
#  ('we don\' t learn from history because"our studies are brief and prejudiced."',
#   'testimony'),
#  ("He means they are mostly about one's own country", 'assumption'),
#  ('It will take more than a new Congress in 2015 and a new president in 2017 to save us from the fate of other empires',
#   'assumption'),
#  ('It will take a revival of the American spirit', 'assumption'),
#  ('and', 'no-unit'),
#  ('that can only come through changed attitudes towards our institutions and each other',
#   'assumption'),
#  ('2015: Will America continue its slow march toward destruction of liberty?',
#   'title'),
#  ('A British author, residing in the United States for the past 30 years, created a small firestorm earlier this week with his candid observations that modern- day Americans have been duped by the government into accepting a European- style march toward socialism',
#   'anecdote'),
#  ("because we fail to appreciate the rich legacy of personal liberty that is everyone's birthright and is expressly articulated in the Declaration of Independence and guaranteed by the U.S  Constitution",
#   'testimony'),
#  ('Os Guinness, the author of more than a dozen books defending traditional Judeo-Christian values and Jeffersonian personal liberty, argued that we should embrace individual liberty and personal dignity and reject the "no givens, no rules, no limits" government we now have',
#   'testimony'),
#  ('He went on to opine that the government today is not the constitutionally restrained protector of personal freedoms the Framers left us',
#   'testimony'),
#  ('but rather has become the wealth-distributing protector of collective interests the Founding Fathers never could have imagined',
#   'testimony'),
#  ('Yet the problem is a deep one', 'assumption'),
#  ('The Framers believed in the presumption of liberty', 'common-ground'),
#  ('which declares that we are free to make personal choices, and the government cannot interfere with our liberties unless we violate the rights of others',
#   'common-ground'),
#  ('Stated differently', 'no-unit'),
#  ('the federal government cannot interfere with our personal choices by writing any law it wants',
#   'assumption'),
#  ('it can only regulate behavior or spend money when the Constitution authorizes it to do so',
#   'assumption'),
#  ('But for the past 100 years, the federal government has rejected the Madisonian concept that it is limited to the 16 discrete powers the Constitution delegates to it, and has claimed its powers are unlimited, subject only to the express prohibitions in the Constitution',
#   'assumption'),
#  ('Even those prohibitions can be gotten around', 'assumption'),
#  ('since government lawyers have persuaded federal courts to rule that Congress can spend tax dollars or borrowed money on any projects it wishes, whether authorized by the Constitution or not',
#   'assumption'),
#  ('The courts even have authorized Congress to use federal tax dollars to bribe the states into enacting laws that Congress is powerless to enact',
#   'assumption'),
#  ('and', 'no-unit'),
#  ('Congress has done so', 'assumption'),
#  ('The Declaration of Independence defines our personal liberties as inalienable aspects of our humanity',
#   'common-ground'),
#  ('and', 'no-unit'),
#  ('the Constitution prohibits the government from interfering with those liberties-- like thought, speech, press, association, worship, self-defense, travel, privacy, due process, use of money and private property',
#   'common-ground'),
#  ('to name a few', 'no-unit'),
#  ('The teaching of these founding documents is that our liberties are natural-- their source is not the government',
#   'common-ground'),
#  ('-- and', 'no-unit'),
#  ('they are personal, not collective', 'common-ground'),
#  ("We don't need a government permission slip to exercise them",
#   'common-ground'),
#  ("we don't need to belong to a group to enjoy them", 'common-ground'),
#  ('they cannot be taken away by a congressional vote or a presidential signature',
#   'common-ground'),
#  ('Even though everyone who works for the government takes an oath to uphold the Declaration and the Constitution',
#   'common-ground'),
#  ('very few are consistent with what they have sworn to do', 'assumption'),
#  ('We know that because on the transcendental issues of our day -- life, liberty, war and debt -- the leadership of both political parties and the behavior of all modern presidents have revealed a steadfast willingness to write any law and regulate any behavior or permit any evil',
#   'assumption'),
#  (', whether authorized by the Constitution or not.', 'no-unit'),
#  ('Take life', 'other'),
#  ('Abortion is the most deadly force in America today', 'assumption'),
#  ('Abortions lawfully kill a baby a minute ', 'assumption'),
#  ('--', 'no-unit'),
#  ("that's 1.1 million babies a year and 45,000,000 killed since the Supreme Court issued its Roe v  Wade decision in 1973",
#   'assumption'),
#  ('A simple one-line statute --"The fetus in the womb is a legal person"-- could have been enacted by a simple majority vote in Congress and signed into law by any of our so-called pro-life presidents, thus stopping the slaughter',
#   'assumption'),
#  ('It never happened', 'common-ground'),
#  ('Take liberty', 'other'),
#  ('Both parties support the Patriot Act and the secret FISA apparatus',
#   'assumption'),
#  ('which together invade privacy, infringe upon free speech, permit federal agents to write their own search warrants and allow domestic spying on all of us all the time',
#   'assumption'),
#  ('This demonstrates that our political leaders do not believe that our rights are inalienable, but can be interfered with and regulated by them',
#   'assumption'),
#  ('They have written laws that literally permit federal agents to do the very acts the Constitution was written to prohibit',
#   'assumption'),
#  ('Take the lethal combination of war and debt', 'other'),
#  ('Both parties support perpetual war and perpetual debt', 'assumption'),
#  ('The leadership of both parties has permitted every modern president to kill whomever he pleases in foreign countries without lawful declarations of war and to do so by going into a $17 trillion hole of debt, with no end in sight',
#   'assumption'),
#  ('Today, 20 cents of every tax dollar collected goes to interest on pre-existing government debt',
#   'assumption'),
#  ("Today's taxpayers are still paying interest on the $30 billion Woodrow Wilson borrowed to finance World War I in 1917",
#   'assumption'),
#  ('The British author is correct', 'assumption'),
#  ('Unless we have a radical change in the direction of government -- its size, cost, focus, intrusiveness and rejection of first principles -- and unless we elect people to the government who truly believe the Declaration and the Constitution mean what they say, we will continue our march toward the federal destruction of the presumption of liberty',
#   'assumption'),
#  ('It is a slow march, but a steady one', 'assumption'),
#  ('2015: Will new Congress get serious about Putin, Russia?', 'title'),
#  ('"The bear never asks permission," remarked Vladmir Putin on a TV promo for his annual news conference',
#   'testimony'),
#  ('Yes, we know', 'other'),
#  ("The Russians haven't stopped their aggressive posturing after annexing Crimea--not by a long-shot",
#   'assumption'),
#  ('In early December there was another near miss between a Russian military jet with its transponders turned off and a commercial airliner just south of Sweden',
#   'anecdote'),
#  ('This adds to the list of over 40 serious incidents involving Russia and NATO countries in the last 8 months, as detailed in a report by a British think tank called the European Leadership Network',
#   'testimony')]

# %%
to_predict_list
# Out:
# [{'completion': 'title',
#   'prompt': '2015: Beyond Obama, new Congress, we need a revival of the American spirit.'},
#  {'completion': 'anecdote',
#   'prompt': 'In the film, "Girl Interrupted," Winona Ryder plays an 18-year-old who enters a mental institution for what is diagnosed as borderline personality disorder'},
#  {'completion': 'anecdote', 'prompt': 'The year is 1967'},
#  {'completion': 'no-unit', 'prompt': 'and'},
#  {'completion': 'anecdote',
#   'prompt': 'the country is in turmoil over Vietnam and civil rights'},
#  {'completion': 'anecdote',
#   'prompt': 'While lying on her bed one night and watching TV, she sees a news report about a demonstration'},
#  {'completion': 'anecdote',
#   'prompt': 'The narrator says something that might apply to today\'s turmoil:"We live in a time of doubt. The institutions we once trusted no longer seem reliable."'},
#  {'completion': 'no-unit', 'prompt': 'As 2014 ends,'},
#  {'completion': 'statistics', 'prompt': 'the stock market is at record highs'},
#  {'completion': 'no-unit', 'prompt': 'but'},
#  {'completion': 'assumption',
#   'prompt': 'our traditional institutions and self-confidence are in decline'},
#  {'completion': 'testimony',
#   'prompt': 'A Pew Research Center study confirms one trend that has been obvious over several years'},
#  {'completion': 'assumption',
#   'prompt': 'The "typical" American family is no longer typical'},
#  {'completion': 'statistics',
#   'prompt': 'Just 46 percent of American children now live in homes with their married, heterosexual parents'},
#  {'completion': 'statistics',
#   'prompt': 'Five percent have no parents at home'},
#  {'completion': 'testimony',
#   'prompt': 'They most likely are living with grandparents, says the study'},
#  {'completion': 'assumption',
#   'prompt': 'These startling figures about the decline of the American family contrast with the year 1960'},
#  {'completion': 'statistics',
#   'prompt': 'when 73 percent of American children lived in traditional families'},
#  {'completion': 'assumption',
#   'prompt': 'A major contributor to this trend has been the assault on marriage and other institutions by the Baby Boom generation'},
#  {'completion': 'assumption',
#   'prompt': 'It was that generation that promoted cohabitation, no-fault divorce, hatred of the police(they called them "pigs" then, too) and disdain for the military and America, spawned not just by the Vietnam War but a life of relative ease unknown to their parents'},
#  {'completion': 'assumption',
#   'prompt': 'The culture bomb dropped by the boomers created fallout still being felt today'},
#  {'completion': 'assumption',
#   'prompt': 'The two-plus generations born since the Sixties have been infused with the notion of entitlement, victimhood, envy and greed'},
#  {'completion': 'assumption',
#   'prompt': 'Since the elimination of the draft, young people are no longer expected to serve in the military and so most of them pursue whatever goals they wish with no expectation they should give something back to their country'},
#  {'completion': 'assumption',
#   'prompt': "It's one possible explanation for why we can no longer seem to win wars"},
#  {'completion': 'common-ground',
#   'prompt': 'History warns us what happens when empires refuse to teach known values that strengthen societies and help protect them from enemies intent on their destruction'},
#  {'completion': 'anecdote',
#   'prompt': 'The late British diplomat Sir John Glubb wrote a book called "The Fate of Empires and Search For Survival."'},
#  {'completion': 'testimony',
#   'prompt': 'Glubb noted the average age of empires since the time of ancient Assyria (859-612 B.C ) is 250 years'},
#  {'completion': 'testimony',
#   'prompt': 'Only the Mameluke Empire in Egypt and the Levant (1250-1517) made it as far as 267 years'},
#  {'completion': 'assumption',
#   'prompt': 'America is 238 years old and is exhibiting signs of decline'},
#  {'completion': 'testimony',
#   'prompt': 'All empires begin, writes Glubb, with the age of pioneers, followed by ages of conquest, commerce, affluence, intellect and decadence'},
#  {'completion': 'assumption',
#   'prompt': 'America appears to have reached the age of decadence'},
#  {'completion': 'testimony',
#   'prompt': 'which Glubb defines as marked by "defensiveness, pessimism, materialism, frivolity, an influx of foreigners, the welfare state, (and) a weakening of religion."'},
#  {'completion': 'testimony',
#   'prompt': 'Decadence, he writes,"is due to: Too long a period of wealth and power, selfishness, love of money (and) the loss of a sense of duty."'},
#  {'completion': 'assumption',
#   'prompt': 'Do these not define America at the end of 2014?'},
#  {'completion': 'testimony',
#   'prompt': 'Glubb says the 250-year average of empires has not varied in 3,000 years'},
#  {'completion': 'no-unit', 'prompt': 'but'},
#  {'completion': 'testimony',
#   'prompt': 'we don\' t learn from history because"our studies are brief and prejudiced."'},
#  {'completion': 'assumption',
#   'prompt': "He means they are mostly about one's own country"},
#  {'completion': 'assumption',
#   'prompt': 'It will take more than a new Congress in 2015 and a new president in 2017 to save us from the fate of other empires'},
#  {'completion': 'assumption',
#   'prompt': 'It will take a revival of the American spirit'},
#  {'completion': 'no-unit', 'prompt': 'and'},
#  {'completion': 'assumption',
#   'prompt': 'that can only come through changed attitudes towards our institutions and each other'},
#  {'completion': 'title',
#   'prompt': '2015: Will America continue its slow march toward destruction of liberty?'},
#  {'completion': 'anecdote',
#   'prompt': 'A British author, residing in the United States for the past 30 years, created a small firestorm earlier this week with his candid observations that modern- day Americans have been duped by the government into accepting a European- style march toward socialism'},
#  {'completion': 'testimony',
#   'prompt': "because we fail to appreciate the rich legacy of personal liberty that is everyone's birthright and is expressly articulated in the Declaration of Independence and guaranteed by the U.S  Constitution"},
#  {'completion': 'testimony',
#   'prompt': 'Os Guinness, the author of more than a dozen books defending traditional Judeo-Christian values and Jeffersonian personal liberty, argued that we should embrace individual liberty and personal dignity and reject the "no givens, no rules, no limits" government we now have'},
#  {'completion': 'testimony',
#   'prompt': 'He went on to opine that the government today is not the constitutionally restrained protector of personal freedoms the Framers left us'},
#  {'completion': 'testimony',
#   'prompt': 'but rather has become the wealth-distributing protector of collective interests the Founding Fathers never could have imagined'},
#  {'completion': 'assumption', 'prompt': 'Yet the problem is a deep one'},
#  {'completion': 'common-ground',
#   'prompt': 'The Framers believed in the presumption of liberty'},
#  {'completion': 'common-ground',
#   'prompt': 'which declares that we are free to make personal choices, and the government cannot interfere with our liberties unless we violate the rights of others'},
#  {'completion': 'no-unit', 'prompt': 'Stated differently'},
#  {'completion': 'assumption',
#   'prompt': 'the federal government cannot interfere with our personal choices by writing any law it wants'},
#  {'completion': 'assumption',
#   'prompt': 'it can only regulate behavior or spend money when the Constitution authorizes it to do so'},
#  {'completion': 'assumption',
#   'prompt': 'But for the past 100 years, the federal government has rejected the Madisonian concept that it is limited to the 16 discrete powers the Constitution delegates to it, and has claimed its powers are unlimited, subject only to the express prohibitions in the Constitution'},
#  {'completion': 'assumption',
#   'prompt': 'Even those prohibitions can be gotten around'},
#  {'completion': 'assumption',
#   'prompt': 'since government lawyers have persuaded federal courts to rule that Congress can spend tax dollars or borrowed money on any projects it wishes, whether authorized by the Constitution or not'},
#  {'completion': 'assumption',
#   'prompt': 'The courts even have authorized Congress to use federal tax dollars to bribe the states into enacting laws that Congress is powerless to enact'},
#  {'completion': 'no-unit', 'prompt': 'and'},
#  {'completion': 'assumption', 'prompt': 'Congress has done so'},
#  {'completion': 'common-ground',
#   'prompt': 'The Declaration of Independence defines our personal liberties as inalienable aspects of our humanity'},
#  {'completion': 'no-unit', 'prompt': 'and'},
#  {'completion': 'common-ground',
#   'prompt': 'the Constitution prohibits the government from interfering with those liberties-- like thought, speech, press, association, worship, self-defense, travel, privacy, due process, use of money and private property'},
#  {'completion': 'no-unit', 'prompt': 'to name a few'},
#  {'completion': 'common-ground',
#   'prompt': 'The teaching of these founding documents is that our liberties are natural-- their source is not the government'},
#  {'completion': 'no-unit', 'prompt': '-- and'},
#  {'completion': 'common-ground',
#   'prompt': 'they are personal, not collective'},
#  {'completion': 'common-ground',
#   'prompt': "We don't need a government permission slip to exercise them"},
#  {'completion': 'common-ground',
#   'prompt': "we don't need to belong to a group to enjoy them"},
#  {'completion': 'common-ground',
#   'prompt': 'they cannot be taken away by a congressional vote or a presidential signature'},
#  {'completion': 'common-ground',
#   'prompt': 'Even though everyone who works for the government takes an oath to uphold the Declaration and the Constitution'},
#  {'completion': 'assumption',
#   'prompt': 'very few are consistent with what they have sworn to do'},
#  {'completion': 'assumption',
#   'prompt': 'We know that because on the transcendental issues of our day -- life, liberty, war and debt -- the leadership of both political parties and the behavior of all modern presidents have revealed a steadfast willingness to write any law and regulate any behavior or permit any evil'},
#  {'completion': 'no-unit',
#   'prompt': ', whether authorized by the Constitution or not.'},
#  {'completion': 'other', 'prompt': 'Take life'},
#  {'completion': 'assumption',
#   'prompt': 'Abortion is the most deadly force in America today'},
#  {'completion': 'assumption',
#   'prompt': 'Abortions lawfully kill a baby a minute '},
#  {'completion': 'no-unit', 'prompt': '--'},
#  {'completion': 'assumption',
#   'prompt': "that's 1.1 million babies a year and 45,000,000 killed since the Supreme Court issued its Roe v  Wade decision in 1973"},
#  {'completion': 'assumption',
#   'prompt': 'A simple one-line statute --"The fetus in the womb is a legal person"-- could have been enacted by a simple majority vote in Congress and signed into law by any of our so-called pro-life presidents, thus stopping the slaughter'},
#  {'completion': 'common-ground', 'prompt': 'It never happened'},
#  {'completion': 'other', 'prompt': 'Take liberty'},
#  {'completion': 'assumption',
#   'prompt': 'Both parties support the Patriot Act and the secret FISA apparatus'},
#  {'completion': 'assumption',
#   'prompt': 'which together invade privacy, infringe upon free speech, permit federal agents to write their own search warrants and allow domestic spying on all of us all the time'},
#  {'completion': 'assumption',
#   'prompt': 'This demonstrates that our political leaders do not believe that our rights are inalienable, but can be interfered with and regulated by them'},
#  {'completion': 'assumption',
#   'prompt': 'They have written laws that literally permit federal agents to do the very acts the Constitution was written to prohibit'},
#  {'completion': 'other',
#   'prompt': 'Take the lethal combination of war and debt'},
#  {'completion': 'assumption',
#   'prompt': 'Both parties support perpetual war and perpetual debt'},
#  {'completion': 'assumption',
#   'prompt': 'The leadership of both parties has permitted every modern president to kill whomever he pleases in foreign countries without lawful declarations of war and to do so by going into a $17 trillion hole of debt, with no end in sight'},
#  {'completion': 'assumption',
#   'prompt': 'Today, 20 cents of every tax dollar collected goes to interest on pre-existing government debt'},
#  {'completion': 'assumption',
#   'prompt': "Today's taxpayers are still paying interest on the $30 billion Woodrow Wilson borrowed to finance World War I in 1917"},
#  {'completion': 'assumption', 'prompt': 'The British author is correct'},
#  {'completion': 'assumption',
#   'prompt': 'Unless we have a radical change in the direction of government -- its size, cost, focus, intrusiveness and rejection of first principles -- and unless we elect people to the government who truly believe the Declaration and the Constitution mean what they say, we will continue our march toward the federal destruction of the presumption of liberty'},
#  {'completion': 'assumption',
#   'prompt': 'It is a slow march, but a steady one'},
#  {'completion': 'title',
#   'prompt': '2015: Will new Congress get serious about Putin, Russia?'},
#  {'completion': 'testimony',
#   'prompt': '"The bear never asks permission," remarked Vladmir Putin on a TV promo for his annual news conference'},
#  {'completion': 'other', 'prompt': 'Yes, we know'},
#  {'completion': 'assumption',
#   'prompt': "The Russians haven't stopped their aggressive posturing after annexing Crimea--not by a long-shot"},
#  {'completion': 'anecdote',
#   'prompt': 'In early December there was another near miss between a Russian military jet with its transponders turned off and a commercial airliner just south of Sweden'},
#  {'completion': 'testimony',
#   'prompt': 'This adds to the list of over 40 serious incidents involving Russia and NATO countries in the last 8 months, as detailed in a report by a British think tank called the European Leadership Network'},
#  {'completion': 'assumption',
#   'prompt': 'President Obama has so far remained unwilling to do little more than levy pin- prick sanctions against specific Russian individuals'},
#  {'completion': 'no-unit', 'prompt': 'but'},
#  {'completion': 'assumption',
#   'prompt': "that doesn't mean Congress is sitting still"},
#  {'completion': 'assumption',
#   'prompt': 'Republicans have continued to show a willingness to get tough with Russia to actually deter it'},
#  {'completion': 'anecdote',
#   'prompt': 'And now the New Year ushers in a Republican majority in the Senate, and a freshly motivated Republican House'},
#  {'completion': 'anecdote',
#   'prompt': 'Several Senators have argued the U.S  should impose much tougher sanctions on whole sectors of the Russian economy, provide significant arms to Ukraine and NATO allies in the region, and should go back to an emphasis on building out missile defense in Europe'},
#  {'completion': 'common-ground',
#   'prompt': 'Moscow has long opposed U.S  missile defense in countries that were once forcibly a part of the Soviet Union'},
#  {'completion': 'anecdote',
#   'prompt': 'Recall the now infamous abandonment by President Obama of the Bush plan to deploy 10 large interceptors in Poland in an effort to appease Russia'},
#  {'completion': 'assumption',
#   'prompt': 'Those same interceptors might not be deployed'},
#  {'completion': 'no-unit', 'prompt': 'but'},
#  {'completion': 'assumption',
#   'prompt': 'the current and more modest plans to build up defenses, could be adapted'},
#  {'completion': 'testimony',
#   'prompt': 'Congressman Mike Tuner, R-Ohio, said in a statement released on December 18, "Given Russia\'s increased aggression toward the West and Iran\\\'s stubbornness toward its nuclear program, we must ensure a robust BMD capability in Europe'},
#  {'completion': 'testimony',
#   'prompt': 'Russia is clearly now a threat to the West."'},
#  {'completion': 'common-ground',
#   'prompt': 'For years the U.S  has insisted that homeland missile defense systems will not be targeted at Russian assets in order to maintain a "strategic balance" between the former Cold War foes'},
#  {'completion': 'testimony',
#   'prompt': 'This remains the position of the U.S as laid out in a 2010 policy document called the Ballistic Missile Defense Review (BMDR)'},
#  {'completion': 'common-ground',
#   'prompt': 'It is not, however, codified in law'},
#  {'completion': 'no-unit', 'prompt': 'And'},
#  {'completion': 'anecdote',
#   'prompt': 'since the U.S  began deploying more missile defense systems abroad to protect allies and U.S  troops from Iranian missiles, officials have made the case that they were not defending against the shorter range Russian systems'},
#  {'completion': 'no-unit', 'prompt': 'But'},
#  {'completion': 'assumption', 'prompt': 'this may change'},
#  {'completion': 'no-unit', 'prompt': 'and'},
#  {'completion': 'assumption',
#   'prompt': 'if it does, it will be the fault of the Russian government, and to the credit of American officials who are paying close attention'},
#  {'completion': 'no-unit', 'prompt': 'Unconvinced'},
#  {'completion': 'no-unit',
#   'prompt': 'that the U.S  is not threatening its military'},
#  {'completion': 'assumption',
#   'prompt': 'Russia has moved forward with an aggressive plan to improve in quality and quantity its offensive missile forces and continues to threaten its neighbors (U.S  allies) with them, even threatening to use--preemptively--nuclear weapons'},
#  {'completion': 'assumption',
#   'prompt': 'The revelations that Russia has been in violation of the INF Treaty has also ushered in some bipartisan agreement that perhaps the U.S  should rethink its position regarding missile defense and Russia'},
#  {'completion': 'anecdote',
#   'prompt': 'Democratic Senator Joe Donnelly, R-Ind , raised the issue of speeding up and strengthening U.S  missile defense in Europe in the context of Russian aggression during an April 2, 2014 Senate hearing'},
#  {'completion': 'anecdote',
#   'prompt': 'In the recent omnibus bill Congress approved $20 million to do just that -- speed up the deployment of the European Phased Adaptive Approach-- a missile defense plan to deploy missile defense assets in Europe to protect against the regional Iranian threats'},
#  {'completion': 'assumption',
#   'prompt': 'Between the failure of the infamous "Iran deal" to curb Iranian missile development and Russia\'s continued aggression in the region, this makes perfect sense and is good policy'},
#  {'completion': 'testimony',
#   'prompt': 'In a recent trip to Eastern Europe, the Chairman of the House Strategic Forces Subcommittee, Congressman Mike Rogers, R-Ala , stated that the interceptors in Europe could be made to defend against some Russian threats'},
#  {'completion': 'no-unit', 'prompt': 'As'},
#  {'completion': 'no-unit', 'prompt': 'one can imagine'},
#  {'completion': 'assumption',
#   'prompt': "this didn't thrill the Russians--but short of American decline, what does?"},
#  {'completion': 'testimony',
#   'prompt': 'Russian Foreign Ministry spokesman Alexander Lukashevich said in a statement,"Hence, the U.S  lawmaker confirmed the justifiability of concerns having been aired by Moscow for a long time that the missile shield being developed by the U.S  is intended solely for the purposes officially declared by Washington."'},
#  {'completion': 'assumption',
#   'prompt': 'If the U.S  does configure systems to protect its allies against Russian missiles, it is because it will be because Uncle Sam finally stopped "asking permission" and decided to get serious about deterring "the bear."'},
#  {'completion': 'title',
#   'prompt': '? 300 for a job reference is the latest outrage in the exploitation of interns.'},
#  {'completion': 'no-unit', 'prompt': 'If'},
#  {'completion': 'assumption',
#   'prompt': 'there were an award for scummiest business practice'},
#  {'completion': 'assumption',
#   'prompt': 'refusing to pay interns would get many a vote'},
#  {'completion': 'anecdote',
#   'prompt': 'But Jan Mortier, who until a year ago ran a "junior associates" programme through his thinktank Civitatis International, has upped the stakes by charging former interns(or trainees, as he prefers to think of them) a ? 300 fee for an employment reference'},
#  {'completion': 'assumption',
#   'prompt': 'Is charging someone for a reference after refusing to pay them as scummy as it gets? Sadly not'},
#  {'completion': 'assumption', 'prompt': 'Young people are lucky'},
#  {'completion': 'no-unit', 'prompt': 'if'},
#  {'completion': 'assumption',
#   'prompt': 'unpaid work is the worst deal they are offered'},
#  {'completion': 'assumption',
#   'prompt': 'although the "junior associates" programme was advertised on Internwise, the three-month programme cost more than? 1,600'},
#  {'completion': 'testimony',
#   'prompt': '(Mortier insists it was a training course, not an internship.)'},
#  {'completion': 'no-unit', 'prompt': 'And the winner is '},
#  {'completion': 'no-unit', 'prompt': '...'},
#  {'completion': 'assumption',
#   'prompt': 'But how on Earth did Mortier think he could get away with charging for references, never mind the extortionate fee of? 300?'},
#  {'completion': 'assumption',
#   'prompt': 'His market is ambitious but terrified young people who are overqualified and unemployed'},
#  {'completion': 'no-unit', 'prompt': '- and'},
#  {'completion': 'assumption',
#   'prompt': 'there is easy money to be made from them, for three reasons'},
#  {'completion': 'assumption',
#   'prompt': "First, they've been sent the message that they're of little value to the economy"},
#  {'completion': 'assumption',
#   'prompt': 'Government and businesses have spent the entire economic crisis suggesting that young people lack employable skills'},
#  {'completion': 'assumption',
#   'prompt': 'Repeated references to these elusive skills rarely lead to any kind of specific mention of what they are- or an investigation into why schools and universities stopped teaching them just as the economy collapsed'},
#  {'completion': 'no-unit', 'prompt': 'If'},
#  {'completion': 'assumption',
#   'prompt': "you've spent your life in education only to be called unemployable"},
#  {'completion': 'assumption',
#   'prompt': "the idea that you'd have to pay someone to say nice things about you doesn't seem so far-fetched"},
#  {'completion': 'no-unit', 'prompt': 'Second'},
#  {'completion': 'assumption',
#   'prompt': 'while young people as a group tend not to have much money sloshing around'},
#  {'completion': 'assumption',
#   'prompt': 'their parents and grandparents are supposedly doing OK'},
#  {'completion': 'assumption',
#   'prompt': "People wanting what's best for their kids leads easily to the coughing-up of cash"},
#  {'completion': 'no-unit', 'prompt': 'Third'},
#  {'completion': 'assumption',
#   'prompt': "when it comes to looking for a job, young people are so used to mounting hindrances that you can stick on another like an extra bottle on a drunk's bar tab"},
#  {'completion': 'assumption',
#   'prompt': 'Legend has it that people used to get a job by seeing one they wanted, and applying'},
#  {'completion': 'assumption',
#   'prompt': 'then came the time when they needed qualifications to get the same job'},
#  {'completion': 'assumption',
#   'prompt': 'then they needed better qualifications'},
#  {'completion': 'assumption',
#   'prompt': 'then they would have to do an unpaid internship'},
#  {'completion': 'assumption',
#   'prompt': "then to prove it wasn't all a fluke they'd have to get qualifications and do an internship"},
#  {'completion': 'testimony',
#   'prompt': 'Now, Civitatis would have you believe that if you attend its summer school you "will gain the advantage over others for internship (sic)"'},
#  {'completion': 'no-unit', 'prompt': 'So,'},
#  {'completion': 'anecdote', 'prompt': '300 for a reference?'},
#  {'completion': 'other', 'prompt': 'Stick it on the bill'},
#  {'completion': 'assumption',
#   'prompt': "But the damage caused by charging for references isn't limited to the spineless gouging of money from naive young people trying to get their first job"},
#  {'completion': 'assumption',
#   'prompt': 'A reference is immediately invalid once money changes hands'},
#  {'completion': 'common-ground',
#   'prompt': "The value of a reference lies in the assumption that it's an honest comment on a person's job performance or character"},
#  {'completion': 'assumption',
#   'prompt': 'The price tag Mortier has attached isn\'t, as he claims, a "fair administrative fee"'},
#  {'completion': 'assumption',
#   'prompt': "It's enough to make a pocket bulge, and certainly enough to be considered a bribe"},
#  {'completion': 'assumption',
#   'prompt': 'no one pays? 300 to be damned with faint praise'},
#  {'completion': 'assumption',
#   'prompt': "Anyone reading a reference signed by Mortier knows he's been paid hundreds for whatever he's written"},
#  {'completion': 'no-unit', 'prompt': 'so'},
#  {'completion': 'assumption', 'prompt': 'it will ring hollow'},
#  {'completion': 'assumption',
#   'prompt': 'Getting a job with worthless education and months-long application processes is already hard enough'},
#  {'completion': 'no-unit', 'prompt': 'If'},
#  {'completion': 'assumption', 'prompt': 'this idea catches on'},
#  {'completion': 'assumption',
#   'prompt': 'references as a measure of a potential candidate will be as devalued as our degrees'},
#  {'completion': 'title', 'prompt': 'Afghanistan at crucial juncture.'},
#  {'completion': 'anecdote',
#   'prompt': 'On Thursday, the so-called London Conference on Afghanistan will convene'},
#  {'completion': 'assumption',
#   'prompt': 'Of all the high-profile international conferences that have been held on Afghanistan over the years- in Bonn, Tokyo, and Istanbul - this comes at a crucial juncture'},
#  {'completion': 'anecdote',
#   'prompt': 'At the end of October, British forces lowered the flag at Camp Bastion - from where they had engaged in the most intense fighting the British army had seen since the Falklands War- and handed over the base to Afghan forces'},
#  {'completion': 'anecdote',
#   'prompt': 'Just over a month later, the Taliban mounted a 14-hour attack on the very same site, killing six Afghan soldiers'},
#  {'completion': 'anecdote',
#   'prompt': 'To the north, in the capital Kabul, insurgents have pulled off a dozen attacks in the space of the last few weeks, striking at diplomats, NGOs, and US contractors'},
#  {'completion': 'assumption',
#   'prompt': 'What explains this spate of violence, and is it a portent for the future of Afghanistan?'},
#  {'completion': 'anecdote',
#   'prompt': "The International Security Assistance Force (ISAF), a US-led group that includes NATO members and others, winds up its mission on New Year's Eve"},
#  {'completion': 'anecdote',
#   'prompt': 'A slimmed-down force of 12,000 foreign troops - mostly American - will stay behind'},
#  {'completion': 'no-unit', 'prompt': 'and'},
#  {'completion': 'anecdote',
#   'prompt': 'US President Barack Obama has authorised the US contingent to continue supporting Afghan National Security Forces (ANSF) throughout 2015, with all of these forces scheduled to leave by the end of 2016'},
#  {'completion': 'assumption',
#   'prompt': 'The US is not, therefore, leaving Afghanistan in the abrupt manner than it left Iraq in 2011'},
#  {'completion': 'assumption',
#   'prompt': 'But this is a time of dramatic change'},
#  {'completion': 'no-unit', 'prompt': 'Drastic effects on casualties'},
#  {'completion': 'assumption',
#   'prompt': 'For one thing, the ANSF are doing much of the fighting themselves, with drastic effects on casualties'},
#  {'completion': 'statistics',
#   'prompt': 'over 9,000 Afghan troops have died since 2013, four times greater than the entire American death toll since 2001'},
#  {'completion': 'statistics',
#   'prompt': 'Afghan police officers are suffering especially badly, with thousands being killed every month'},
#  {'completion': 'anecdote',
#   'prompt': "At the political level, a new government of national unity, led by President Ashraf Ghani and Chief Executive Abdullah Abdullah, has taken charge after Hamid Karzai's departure"},
#  {'completion': 'anecdote',
#   'prompt': "Ghani is already reported to have opened backchannel talks with the Taliban, visiting both Pakistan and Beijing to seek their help in this effort, cancelling an earlier arms request from India, and even making a highly unorthodox visit to Pakistan's army headquarters, in recognition of Pakistan's long-standing support for the insurgents"},
#  {'completion': 'assumption',
#   'prompt': 'On the ground, the overall picture is mixed'},
#  {'completion': 'statistics',
#   'prompt': 'This year, Taliban-initiated attacks are reported to have fallen by 25 percent'},
#  {'completion': 'no-unit', 'prompt': 'and'},
#  {'completion': 'statistics',
#   'prompt': 'ANSF mounted offensives four to five times more frequently than last year'},
#  {'completion': 'no-unit', 'prompt': 'At the same time'},
#  {'completion': 'testimony',
#   'prompt': 'as political scientist Jason Lyall observed, the recently-concluded fighting season - from April to October - "witnessed the appearance of large Taliban units on the battlefield" for the first time, with a tenth of all Afghan districts seeing "at least one major Taliban offensive"'},
#  {'completion': 'testimony',
#   'prompt': 'Lyall also notes reports of over 1,000 insurgents on the battlefield,"numbers not seen since the Taliban\'s original push to capture Kabul during the 1992-96 civil war"'},
#  {'completion': 'assumption',
#   'prompt': 'While we should take these reports with a pinch of salt'},
#  {'completion': 'testimony',
#   'prompt': 'NATO commanders accuse their Afghan counterparts of exaggerating'},
#  {'completion': 'assumption',
#   'prompt': 'they do point to a simple, stark fact'},
#  {'completion': 'assumption', 'prompt': 'The insurgency is far from broken'},
#  {'completion': 'no-unit', 'prompt': 'and'},
#  {'completion': 'assumption',
#   'prompt': 'it will be able to pressure the Afghan state for years to come'},
#  {'completion': 'assumption',
#   'prompt': 'In this context, the wave of insurgent attacks might be explained in several ways'},
#  {'completion': 'no-unit', 'prompt': 'First'},
#  {'completion': 'assumption',
#   'prompt': ', these attacks might be intended to drive a wedge between the Afghan government and its foreign patrons, encouraging the latter to abandon their allies more quickly'},
#  {'completion': 'testimony',
#   'prompt': 'As a Taliban spokesman put it bluntly:"Our objective is to force the foreigners to flee Kabul. Before, the foreigners were visible in the provinces. Now that they have limited more of their activities to Kabul, we have also gone to Kabul to target them there."'},
#  {'completion': 'assumption', 'prompt': 'To some extent, this has worked'},
#  {'completion': 'anecdote',
#   'prompt': 'Many aid agencies have pulled out their staff, and restricted their movements'},
#  {'completion': 'no-unit', 'prompt': 'Tarnished credibility'},
#  {'completion': 'no-unit', 'prompt': 'Second'},
#  {'completion': 'assumption',
#   'prompt': " the insurgents failed to seriously disrupt either round of this year's Afghan elections, as they had vowed to do, leaving their credibility somewhat tarnished"},
#  {'completion': 'assumption',
#   'prompt': 'Prominent attacks - publicised with videos - redress this issue, and project strength at the end of a fighting season'},
#  {'completion': 'assumption',
#   'prompt': "They might also be ways of strengthening the insurgency's bargaining position in advance of any peace talks that gain momentum over the next year"},
#  {'completion': 'no-unit', 'prompt': 'Third'},
#  {'completion': 'assumption', 'prompt': 'the insurgency is not a monolith'},
#  {'completion': 'no-unit', 'prompt': 'and'},
#  {'completion': 'assumption',
#   'prompt': 'different parts of the Taliban might be responsible for different attacks'},
#  {'completion': 'assumption',
#   'prompt': 'The Haqqani Network, a semi- autonomous group with close ties to Pakistani intelligence, has proven most effective at projecting suicide bombings into Kabul'},
#  {'completion': 'anecdote',
#   'prompt': 'The Haqqanis were blamed for the most deadly atrocity of the past month, the bombing of a volleyball game in which over 50 Afghans were killed'},
#  {'completion': 'assumption',
#   'prompt': 'In the past, moves towards dialogue between the Afghan government and the Taliban have been met with carefully targeted attacks intended less to strengthen bargaining positions than to disrupt such talks altogether'},
#  {'completion': 'no-unit', 'prompt': 'Whatever'},
#  {'completion': 'no-unit', 'prompt': 'the explanation'},
#  {'completion': 'assumption',
#   'prompt': 'Afghanistan faces an extremely test period'},
#  {'completion': 'assumption',
#   'prompt': 'Although the presence of US forces provides a safety net throughout next year'},
#  {'completion': 'assumption',
#   'prompt': 'things look more precarious after that'},
#  {'completion': 'common-ground',
#   'prompt': 'International funding commitments for Afghanistan currently run to 2017'},
#  {'completion': 'assumption',
#   'prompt': 'but that timeline had assumed the insurgency would lose steam by then, allowing ANSF to slim down'},
#  {'completion': 'no-unit', 'prompt': 'If'},
#  {'completion': 'assumption', 'prompt': "that isn't possible"},
#  {'completion': 'assumption',
#   'prompt': 'the annual $4-6bn bill for the security forces is simply unsustainable'},
#  {'completion': 'assumption',
#   'prompt': "This week's London Conference is an opportunity to secure much greater contributions from regional powers"},
#  {'completion': 'assumption',
#   'prompt': 'who have the most at stake if Afghanistan does fall apart once more'},
#  {'completion': 'anecdote',
#   'prompt': "China is, for instance, one of the world's largest economies, a direct neighbour of Afghanistan, and a significant investor there"},
#  {'completion': 'no-unit', 'prompt': 'But'},
#  {'completion': 'no-unit', 'prompt': 'if'},
#  {'completion': 'assumption',
#   'prompt': 'Beijing is unwilling to offer more than a meagre $327m - nearly half the amount Iran pledged in 2012, and far less than Japan or the EU'},
#  {'completion': 'no-unit', 'prompt': '- then'},
#  {'completion': 'assumption',
#   'prompt': 'how are western governments, with their attention directed to threats from Russia and ISIL, supposed to persuade their own public that, after a decade of war, Afghanistan must stay on financial life-support?'},
#  {'completion': 'title',
#   'prompt': "Afghanistan conference won't rock the boat."},
#  {'completion': 'testimony',
#   'prompt': '"The London Conference on Afghanistan will provide an opportunity for the government of Afghanistan to set out its commitment to reform," states the UK government\'s official webpage of the upcoming meeting between the new Afghan government and its international donors'},
#  {'completion': 'testimony',
#   'prompt': 'The conference is also an opportunity for the international community "to reaffirm its long-term commitment to supporting Afghanistan\'s peaceful development"'},
#  {'completion': 'assumption',
#   'prompt': 'Despite the media hype, the London Conference is nothing more than a routine reunion, set by the 2012 Tokyo Mutual Accountability Framework (TMAF)'},
#  {'completion': 'anecdote',
#   'prompt': 'As part of the agreement, donors pledged support and the Afghan government promised to implement reforms and curb corruption'},
#  {'completion': 'anecdote',
#   'prompt': "The upcoming meeting in the British capital, therefore, is the first in a series of exchanges that will be held every two years, at the ministerial level, between the Afghan and donor governments to assess progress and check TMAF's benchmarks"},
#  {'completion': 'no-unit', 'prompt': 'Still'},
#  {'completion': 'assumption',
#   'prompt': ' the December 4 conference has the potential to ease Afghanistan into a stable and increasingly self-sufficient future and render it a reliable global partner for ensuring peace and stability in the region and beyond'},
#  {'completion': 'assumption',
#   'prompt': 'To utilise this opportunity as more than a routine progress assessment requires a fundamental shift of attitude on both sides'},
#  {'completion': 'assumption',
#   'prompt': 'Lack of concrete success in the military, economic development and governance efforts in post- Taliban Afghanistan needs to be sincerely examined'},
#  {'completion': 'no-unit', 'prompt': 'and'},
#  {'completion': 'assumption', 'prompt': 'adjustments need to be made'},
#  {'completion': 'assumption',
#   'prompt': "There is multitude of examples in the international community's flawed, if not disingenuous, aid programmes and their monitoring in Afghanistan"},
#  {'completion': 'anecdote',
#   'prompt': 'I was hired by a US consultancy firm to map out the field and offer recommendations for the design of a multimillion dollar governance project'},
#  {'completion': 'anecdote',
#   'prompt': 'My report and recommendations, it turned out, were too radical'},
#  {'completion': 'anecdote',
#   'prompt': '"We expected recommendations for cosmetic changes to the ongoing programmes," I was told'},
#  {'completion': 'anecdote',
#   'prompt': '"The donor agency does not want to rock the boat."'},
#  {'completion': 'anecdote',
#   'prompt': 'On another occasion, I was interviewed by a European consultant for his assessment of the first phase of a programme that had consistently been showcased as a "success story" by donors and the Afghan government'},
#  {'completion': 'anecdote',
#   'prompt': 'In his three-day field trip to Kabul, he had held meetings with three embassies, the UN, the Afghan head of the implementing agency and me'},
#  {'completion': 'anecdote',
#   'prompt': 'Eagerly, I began to point to the flaws of the programme and offered suggestions for improvement'},
#  {'completion': 'anecdote',
#   'prompt': 'I also offered assistance for site visits'},
#  {'completion': 'anecdote',
#   'prompt': '"Do n\'t waste your time and mine," the septuagenarian consultant told me'},
#  {'completion': 'anecdote',
#   'prompt': '"The donor agency expects a rosy report highlighting only the positive."'},
#  {'completion': 'anecdote',
#   'prompt': 'He further clarified that the decision to fund the second phase had already been made and it had more to do with international aid politics, than development logic'},
#  {'completion': 'common-ground',
#   'prompt': 'Numbers provide an easy way to illustrate success'},
#  {'completion': 'assumption',
#   'prompt': 'especially when seeking international aid budget approval from legislative bodies'},
#  {'completion': 'assumption',
#   'prompt': "While figures indicating Afghanistan's progress towards development are impressive and could not have been achieved without generous international assistance"},
#  {'completion': 'assumption',
#   'prompt': 'they conceal a lack of attention to quality'},
#  {'completion': 'statistics',
#   'prompt': 'About 8 million Afghan children - including over 2.5 million girls - are now in school'},
#  {'completion': 'anecdote',
#   'prompt': 'This is a figure cited regularly as an indication that the programmes are yielding tangible results'},
#  {'completion': 'assumption',
#   'prompt': 'The fact that most of them graduate only half-literate is never revealed'},
#  {'completion': 'assumption', 'prompt': "Here's another feel-good figure"},
#  {'completion': 'statistics',
#   'prompt': 'More than 60 percent of the Afghan population now has access to healthcare facilities'},
#  {'completion': 'assumption',
#   'prompt': 'The fact that some of those facilities have only received a checkmark because merely a building was constructed and many are staffed only with a nurse, have no diagnostic technology and have terribly anaemic pharmaceutical offerings is often ignored'},
#  {'completion': 'assumption',
#   'prompt': "Much has been written about the fact that a hefty portion of the aid money goes back to donor countries because of the donors' insistence to award contracts to their own citizens"},
#  {'completion': 'anecdote', 'prompt': 'The contracts move hand to hand'},
#  {'completion': 'no-unit', 'prompt': 'and'},
#  {'completion': 'anecdote',
#   'prompt': 'finally local non-governmental agencies are hired to implement projects'},
#  {'completion': 'no-unit', 'prompt': 'At this point'},
#  {'completion': 'assumption',
#   'prompt': 'while at best one-quarter of the original funds remains to be spent on the actual project, quality is grossly compromised'},
#  {'completion': 'no-unit', 'prompt': 'and'},
#  {'completion': 'assumption',
#   'prompt': 'monitoring becomes either too complex or irrelevant'},
#  {'completion': 'assumption',
#   'prompt': 'The international community has also created an indigenous vehicle for channelling portions of its assistance'},
#  {'completion': 'assumption',
#   'prompt': 'Under the guise of "civil society", hundreds of Afghan NGOs have been established since 2002'},
#  {'completion': 'assumption',
#   'prompt': "This artificial civil society's lifeline is the donor community in Kabul"},
#  {'completion': 'assumption',
#   'prompt': "Projects and funds are handed to them for implementation and as the closing of fiscal year in donor capitals approaches, generosity in disbursing funds, irrespective of the projects' logic, utility and cost increases"},
#  {'completion': 'no-unit', 'prompt': 'Where'},
#  {'completion': 'no-unit', 'prompt': 'the funds go'},
#  {'completion': 'assumption',
#   'prompt': 'Granted that when international aid began to pour in, the Afghan state had very small, if any, capacity to absorb and spend it'},
#  {'completion': 'no-unit', 'prompt': 'However'},
#  {'completion': 'assumption',
#   'prompt': ' after 13 years and millions of dollars spent on public sector capacity building, the bulk of the funds continue to be spent directly by donors'},
#  {'completion': 'no-unit', 'prompt': 'and'},
#  {'completion': 'statistics',
#   'prompt': 'only a little over 20 percent is given to the Afghan government'},
#  {'completion': 'assumption',
#   'prompt': 'The parallel system and structures offering higher salaries paid in US dollars have lured much of the skilled Afghan human resources'},
#  {'completion': 'assumption',
#   'prompt': 'The Afghan administration, thus, has to be grateful to donors for funding training workshops, while in the end, loses its best trained personnel to international organisations, consulting firms and embassies'},
#  {'completion': 'anecdote',
#   'prompt': "It is often said that rampant Afghan corruption and lack of capacity would result in misuse and waste of donors' funds"},
#  {'completion': 'statistics',
#   'prompt': 'A mere review of reports published by the US oversight agency, Special Inspector General for Afghanistan Reconstruction (SIGAR), reveals the depth and extent of waste, fraud and abuse of the direct US aid to Afghanistan just in reconstruction projects'},
#  {'completion': 'assumption',
#   'prompt': "Similar monitoring of most donors' direct aid will, no doubt, highlight comparable corruption and waste"},
#  {'completion': 'assumption',
#   'prompt': 'The government of former President Hamid Karzai admittedly failed to launch a genuine fight against corruption'},
#  {'completion': 'assumption',
#   'prompt': 'Lack of capacity for a governance vision that would make optimum use of international aid was also a defect of the previous leadership'},
#  {'completion': 'assumption',
#   'prompt': 'High-level appointments were based not on competence and commitment of individuals, but rather on political affiliations and compromises on the one hand, and submissiveness of a handful of "yes sir" entities on the other'},
#  {'completion': 'no-unit', 'prompt': 'Thus'},
#  {'completion': 'assumption',
#   'prompt': ' both sides - donors and the Afghan government - went on for a decade playing a futile blame game'},
#  {'completion': 'assumption',
#   'prompt': 'each accusing the other of corruption and insincerity'},
#  {'completion': 'no-unit', 'prompt': 'Now'},
#  {'completion': 'assumption',
#   'prompt': " on the eve of the London Conference, a new page has turned in Afghanistan's leadership and governance"},
#  {'completion': 'assumption',
#   'prompt': 'The level of optimism among ordinary Afghans is only comparable to the euphoria of the first weeks following the fall of the Taliban regime'},
#  {'completion': 'assumption',
#   'prompt': 'This renewed domestic hope and confidence in the new leadership must not be let to deflate'},
#  {'completion': 'anecdote',
#   'prompt': 'Although the new administration has not yet launched its overhauling programme'},
#  {'completion': 'assumption',
#   'prompt': "President Ashraf Ghani's vision and capacity is well known"},
#  {'completion': 'assumption',
#   'prompt': 'Donors at the London Conference must seize the chance and afford him confidence'},
#  {'completion': 'assumption',
#   'prompt': 'They must also adapt a fundamentally new approach to dispensing their generous assistance to Afghanistan'},
#  {'completion': 'assumption',
#   'prompt': 'A significant funnelling of international aid through the Afghan government (with oversight and accountability benchmarks), a shift of emphasis from quantity to quality, with particular focus on raising the quality of education and finally, a sincere commitment from both sides to the establishment of rule of law will ensure the stability and eventual self-reliance of Afghanistan'},
#  {'completion': 'title', 'prompt': 'Is Afghanistan ready for the drawdown?'},
#  {'completion': 'anecdote',
#   'prompt': 'After 13 years of the International Security Assistance Force (ISAF), the United States and a number of its NATO partners will start the Resolute Support Mission in Afghanistan'},
#  {'completion': 'anecdote',
#   'prompt': 'The number of NATO and US forces is reduced from 140,000 to 13,500 - most of them American- starting January 1'},
#  {'completion': 'anecdote',
#   'prompt': 'How will the new national unity government in Kabul weather the NATO drawdown, despite a resilient insurgency and intensified fighting?'},
#  {'completion': 'assumption',
#   'prompt': 'There has been much speculation about the security transition in 2014 in Afghanistan'},
#  {'completion': 'anecdote',
#   'prompt': 'In 2012, I wrote an Oped for the New York Times, warning that "Kabul risks political meltdown"'},
#  {'completion': 'testimony',
#   'prompt': 'Many other analysts have also predicted a sombre year, particularly after the refusal of former President Hamid Karzai to sign the Bilateral Security Agreement (BSA) with the US'},
#  {'completion': 'no-unit', 'prompt': 'However'},
#  {'completion': 'assumption',
#   'prompt': ' for the time being, we were all proved wrong as the democratic process that began at the Bonn Conference in 2001, survived'},
#  {'completion': 'no-unit', 'prompt': 'and'},
#  {'completion': 'assumption',
#   'prompt': 'the country was saved from the brink of a new civil war'},
#  {'completion': 'assumption',
#   'prompt': "Indeed we have achieved important strategic gains in the last few months, starting with the landmark peaceful transfer of political power from one democratically elected leader to another, for the first time in Afghanistan's history"},
#  {'completion': 'assumption',
#   'prompt': 'This milestone was made possible by the will of ordinary Afghan people'},
#  {'completion': 'anecdote',
#   'prompt': 'who twice braved the threat of violence imposed by the Taliban and came out en masse, voting for their candidates of choice'},
#  {'completion': 'assumption',
#   'prompt': 'Meanwhile, the Taliban has tried hard to undermine the electoral process'},
#  {'completion': 'assumption',
#   'prompt': 'By confronting Afghan security forces in 16 different provinces, they wanted to gain significant territory'},
#  {'completion': 'assumption',
#   'prompt': 'thus declaring themselves as an alternative governing force in the country'},
#  {'completion': 'no-unit', 'prompt': 'Nevertheless'},
#  {'completion': 'assumption',
#   'prompt': ' the Afghan security forces have been able to hold ground and push back the insurgent offensives in almost all fronts'},
#  {'completion': 'assumption',
#   'prompt': 'which has became a source of pride for the Afghan government and people'},
#  {'completion': 'assumption',
# ...
#  {'completion': 'assumption',
#   'prompt': 'For Armenia, its role as a reliable partner and ally of Russia has never faced any real challenge'},
#  {'completion': 'assumption',
#   'prompt': 'Much of this reliance on Russia stems from essential security and economic concerns'},
#  {'completion': 'assumption',
#   'prompt': 'Armenia\'s security reliance on Russia is driven by a virtual state of war with neighbouring Azerbaijan, rooted in the Nagorno-Karabakh conflict, only exacerbated by the absence of "normal" diplomatic relations and closed border with Turkey'},
#  {'completion': 'assumption',
#   'prompt': 'And with the Turkish refusal to recognise the Armenian genocide, this threat perception is only magnified'},
#  {'completion': 'assumption',
#   'prompt': 'For small, landlocked Armenia, a strategic alliance with Russia is generally accepted as essential in the face of such inherent insecurity'},
#  {'completion': 'assumption',
#   'prompt': 'And beyond an imperative of security, Armenia also depends on Russia as a crucial source of remittances, or money sent home by large numbers of Armenians living and working in Russia'},
#  {'completion': 'no-unit', 'prompt': 'Yet'},
#  {'completion': 'assumption',
#   'prompt': ' there is a surprisingly intense debate now under way within Armenia that seriously questions these fundamental pillars of the Armenian-Russian relationship'},
#  {'completion': 'no-unit', 'prompt': 'New challenge'},
#  {'completion': 'assumption',
#   'prompt': "More specifically, this new challenge to Armenia's traditional reliance on Russia is driven by two significant factors: tragedy and timing"},
#  {'completion': 'assumption',
#   'prompt': 'A tragedy first triggered this turnabout'},
#  {'completion': 'anecdote',
#   'prompt': 'when a rogue Russian soldier killed an entire Armenian family, save for a six-month-old infant'},
#  {'completion': 'anecdote',
#   'prompt': 'who later died of his stab wounds, in Gyumri, Armenia'},
#  {'completion': 'common-ground',
#   'prompt': "Gyumri is the country's second-largest city and the host of the Russian military base"},
#  {'completion': 'anecdote',
#   'prompt': 'That senseless act of random violence in the early morning hours of January 12, sparked an immediate and spontaneous outpouring of grief and mourning'},
#  {'completion': 'assumption',
#   'prompt': 'But the initial shock and grief quickly turned to outrage'},
#  {'completion': 'no-unit', 'prompt': 'as'},
#  {'completion': 'assumption',
#   'prompt': 'Russian military officials seemed to take charge of the case with a heavy-handed disdain and disregard for local sensitivities'},
#  {'completion': 'assumption',
#   'prompt': 'That perception was only deepened when Armenian officials were slow to respond or react'},
#  {'completion': 'assumption',
#   'prompt': 'It was this mishandling of the tragedy, even more than the murder itself, that then triggered a series of demonstrations and protests by local Armenians in Gyumri'},
#  {'completion': 'anecdote',
#   'prompt': 'Fearing that the Russian conscript would be moved from his detention within the Russian base and likely returned to Moscow, local residents demanded that the self-confessed soldier be turned over to Armenian authorities'},
#  {'completion': 'no-unit', 'prompt': 'Calming tensions'},
#  {'completion': 'anecdote',
#   'prompt': 'For its part, local Armenian officials and the prosecutor general scurried to calm tensions by first announcing that Armenian investigators were actively participating in the interrogation of the soldier, and then, once that did little to appease the protesters, vowed that the soldier would be tried in Armenia'},
#  {'completion': 'assumption',
#   'prompt': "Amid the Armenian officials' wrangling over the legal process of the case, the absence of any higher level Armenian officials, and the failure of the Armenian president to declare a day of mourning or even make a statement, only escalated the tension"},
#  {'completion': 'anecdote',
#   'prompt': 'And days later, no Armenian official attended the funeral of the murdered family'},
#  {'completion': 'anecdote',
#   'prompt': 'thereby triggering a fresh wave of indignant protests in the city, that later spread to the capital, Yerevan'},
#  {'completion': 'anecdote',
#   'prompt': 'The protests soon moved to the Russian consulate in Gyumri before culminating in a march on the Russian base'},
#  {'completion': 'anecdote',
#   'prompt': 'as protesters broke through a police cordon to enter the base itself'},
#  {'completion': 'no-unit', 'prompt': 'Yet'},
#  {'completion': 'assumption',
#   'prompt': ' there is a deeper context to this public anger'},
#  {'completion': 'no-unit', 'prompt': 'In fact'},
#  {'completion': 'assumption',
#   'prompt': ' that family is only the latest victim in murders and shootings by Russian servicemen stationed at the Russian military base'},
#  {'completion': 'anecdote',
#   'prompt': 'In 1999, two drunk Russian soldiers opened fire on a local market in the city, killing two and injuring dozens of others'},
#  {'completion': 'anecdote',
#   'prompt': 'And in 2013, two children were killed by unexploded ordnance on an unguarded tank firing range on the premises of the Russian base'},
#  {'completion': 'no-unit', 'prompt': 'Bad timing'},
#  {'completion': 'assumption',
#   'prompt': 'Against this backdrop, the tragedy has also raised renewed questions of base security, with outrage that the armed soldier who reportedly deserted his post triggered no notice or alarm by Russian military personnel at the base'},
#  {'completion': 'assumption',
#   'prompt': 'Although this tragedy has prompted a new challenge to Armenian-Russian relations'},
#  {'completion': 'assumption',
#   'prompt': 'it is also exacerbated by a second factor, timing'},
#  {'completion': 'assumption',
#   'prompt': 'The timing of this tragedy could not be much worse, for several reasons'},
#  {'completion': 'no-unit', 'prompt': 'First'},
#  {'completion': 'anecdote',
#   'prompt': ' in 2013, in what many perceived as Russian pressure on its so-called "strategic partner", Armenia was forced to scrap its planned free trade deal with the European Union in favour of joining the Russian-led Eurasian Union'},
#  {'completion': 'no-unit', 'prompt': 'Second'},
#  {'completion': 'assumption',
#   'prompt': ' a steady supply of arms and advanced weapons systems to Azerbaijan from Russia has sowed further distrust'},
#  {'completion': 'assumption',
#   'prompt': 'And most recently, the negative impact on the Armenian economy from western sanctions imposed on Russia, evident in a sudden depreciation of the Armenian currency and reflected in a steep decline in remittances, has only revealed the asymmetry and lack of parity in Armenia\'s "partnership" with Russia'},
#  {'completion': 'assumption',
#   'prompt': "It seems clear that this unexpected challenge to Armenia's reliance on Russia will not dissipate any time soon"},
#  {'completion': 'title',
#   'prompt': 'The asphyxiated politics of the Muslim world.'},
#  {'completion': 'no-unit', 'prompt': 'With'},
#  {'completion': 'assumption',
#   'prompt': 'ISIL spurring negative media for the past six months and other violent groups competing not far behind in evil acts'},
#  {'completion': 'assumption',
#   'prompt': 'Muslims everywhere have been licking their wounds in recent times'},
#  {'completion': 'assumption', 'prompt': '2014 has been worse'},
#  {'completion': 'no-unit', 'prompt': 'and'},
#  {'completion': 'assumption', 'prompt': 'the crises are worsening'},
#  {'completion': 'assumption',
#   'prompt': 'Will the Muslim world be able to pull itself up from this low or enter into long-term anarchy?'},
#  {'completion': 'assumption',
#   'prompt': 'The fundamental reason behind this shameful situation in many Muslim countries is clearly the failure of political leadership, exacerbated by the sheepish role of the religious scholars and an absence of a strong civil society'},
#  {'completion': 'assumption',
#   'prompt': 'Islam is still central to Muslim life'},
#  {'completion': 'assumption',
#   'prompt': 'it once shaped Muslims into a successful global community - an "ummah" of purpose - with a few core beliefs, values and deeds for the good of all'},
#  {'completion': 'assumption',
#   'prompt': 'In spite of many pitfalls, sometimes big, Muslims succeeded in building a civilisation that upheld universal human values, blended with the Islamic principles of pluralism'},
#  {'completion': 'no-unit', 'prompt': 'Unpleasant state of affairs'},
#  {'completion': 'no-unit', 'prompt': 'But'},
#  {'completion': 'assumption',
#   'prompt': ' with an increasing knowledge deficit over centuries, the Muslim social and spiritual capitals were dwindling'},
#  {'completion': 'assumption',
#   'prompt': 'As their individual life was losing the spark of faith and positive action, their public life or political leadership was taken over by people of lower moral clarity and spiritual strength'},
#  {'completion': 'assumption',
#   'prompt': 'Much of the world of Islam is now riddled with political strangulation, economic mismanagement and social division'},
#  {'completion': 'assumption',
#   'prompt': 'The post-colonial breed of corrupt, incompetent and often repressive rulers - having little regard for the ordinary people and their human rights or respect for the rule of law - have made their countries ungovernable'},
#  {'completion': 'assumption',
#   'prompt': 'Some are no better than the Soviet-era communist rulers'},
#  {'completion': 'assumption',
#   'prompt': 'Failed politics has widened the rift between political camps, particularly between secularists and Islamists, in some countries'},
#  {'completion': 'assumption',
#   'prompt': 'This has worsened the social divide, with increased intolerance and violence'},
#  {'completion': 'assumption',
#   'prompt': 'All this is impacting negatively on the nascent Muslim minority communities in the West'},
#  {'completion': 'assumption',
#   'prompt': 'The collapse of politics in Iraq and Syria in recent years set off a ruthless proxy war in these historic lands, with the destruction of infrastructure and an unprecedented refugee crisis'},
#  {'completion': 'assumption',
#   'prompt': 'The rise of ISIL and its alluring attraction of young recruits from around the world, including from Muslim minority countries, has raised global Islamophobia to a new level'},
#  {'completion': 'common-ground',
#   'prompt': 'Politicians are meant to act in the interests of their people'},
#  {'completion': 'assumption',
#   'prompt': 'It is not only their civic duty but for a Muslim politician it is their Islamic obligation as well'},
#  {'completion': 'assumption',
#   'prompt': 'No matter what their background is, they should work with fellow politicians with grace and a team ethos - as co-citizens and co-religionists, not as enemies to one another'},
#  {'completion': 'assumption',
#   'prompt': 'This is not too big of a demand in the 21st century'},
#  {'completion': 'assumption',
#   'prompt': 'The overwhelming majority of Muslims across the world are ordinary hardworking people, with love for their land and religion'},
#  {'completion': 'assumption',
#   'prompt': 'They hate extremism and violence, whether political or religious'},
#  {'completion': 'assumption',
#   'prompt': 'They expect some competency and humility from their social and political leaders'},
#  {'completion': 'no-unit', 'prompt': 'A call for a truce between'},
#  {'completion': 'no-unit', 'prompt': 'opposing political forces'},
#  {'completion': 'assumption',
#   'prompt': 'But in much of the Muslim world this is not the case presently'},
#  {'completion': 'assumption',
#   'prompt': "politics has become an Achilles' heel"},
#  {'completion': 'assumption',
#   'prompt': 'This legacy may go back to their dark days under colonial "divide and rule"'},
#  {'completion': 'no-unit', 'prompt': 'but'},
#  {'completion': 'assumption', 'prompt': 'this can no longer be an excuse'},
#  {'completion': 'assumption',
#   'prompt': 'It is shocking that some Arab countries have degenerated into bloodletting between people of the same history and religion that made them great'},
#  {'completion': 'assumption',
#   'prompt': 'They are on the verge of regressing to the days of pre-Islamic "jahiliya" (ignorance)'},
#  {'completion': 'assumption',
#   'prompt': 'Aside from the influence of unhelpful global politics, the root cause lies in the failure of their own political and religious leaders'},
#  {'completion': 'no-unit', 'prompt': 'Unless'},
#  {'completion': 'assumption',
#   'prompt': "Muslim politicians and civic leaders come to their senses and adopt people-oriented principled politics, improve their accountability and regard themselves as people's servants"},
#  {'completion': 'assumption', 'prompt': 'the situation is going to get worse'},
#  {'completion': 'assumption',
#   'prompt': 'The current blame game is meaningless'},
#  {'completion': 'assumption',
#   'prompt': 'Politicians do have a higher degree of responsibility to bring a nation out of the political mess'},
#  {'completion': 'no-unit', 'prompt': 'but'},
#  {'completion': 'assumption',
#   'prompt': 'one should not forget that they originate from the society and carry its values, norms and culture'},
#  {'completion': 'assumption',
#   'prompt': 'The whole society must now come to its senses and stand up against this self-annihilation'},
#  {'completion': 'assumption',
#   'prompt': 'The bloodletting between diehard secularists and inexperienced hard-line Islamists in some countries is a boon to entrenched dictators to dig their heels and hegemonic powers to milk national wealth'},
#  {'completion': 'assumption',
#   'prompt': 'Islam is indeed very broad and has the ability to accommodate anyone and everyone'},
#  {'completion': 'assumption',
#   'prompt': 'So, the difference between a Muslim secularist and an Islamist is a matter of degree'},
#  {'completion': 'assumption',
#   'prompt': 'This is being blown up by people of ulterior motives and must be challenged'},
#  {'completion': 'assumption',
#   'prompt': 'Secularists have been in power in much of the Muslim world for decades'},
#  {'completion': 'no-unit', 'prompt': 'and'},
#  {'completion': 'assumption',
#   'prompt': 'they do not want to bow out without a fight'},
#  {'completion': 'assumption', 'prompt': 'Islamists want to unseat them'},
#  {'completion': 'assumption',
#   'prompt': 'but lack the political experience in running the affairs of modern statecraft'},
#  {'completion': 'assumption',
#   'prompt': 'Behind the furore, a democratic deficit and lack of confidence are big issues for many politicians'},
#  {'completion': 'assumption', 'prompt': 'The demons must be slain'},
#  {'completion': 'assumption',
#   'prompt': 'Wise individuals, senior citizens and authoritative institutions should raise their voice of sanity and help set the national conversation among politicians'},
#  {'completion': 'assumption',
#   'prompt': 'Secularists should accept the social reality that there are Islamists in their midst'},
#  {'completion': 'no-unit', 'prompt': 'on the other hand'},
#  {'completion': 'assumption', 'prompt': ' Islamists will also do better'},
#  {'completion': 'no-unit', 'prompt': 'if'},
#  {'completion': 'assumption',
#   'prompt': 'they recognise that secularism is part of modern reality'},
#  {'completion': 'common-ground',
#   'prompt': 'Both groups consist of human beings and cannot be exterminated'},
#  {'completion': 'no-unit', 'prompt': "'Live and let live'"},
#  {'completion': 'assumption',
#   'prompt': 'There is no short-cut to end the chronic and acute political crisis in the Muslim world'},
#  {'completion': 'assumption',
#   'prompt': 'But it is vital all political groups work on the basis of existing socio-political realities and find ways to reconcile with the principle of"live and let live"'},
#  {'completion': 'assumption',
#   'prompt': 'Sensible and moderate people from various political camps should sit together, informally and formally, and find a pragmatic political framework to make democratic politics institutional and allow healthy transition of power'},
#  {'completion': 'assumption', 'prompt': 'Every citizen has a right to rule'},
#  ...]

# %%
for input,output in trnList:
  print(output)
# Out:
# title
# anecdote
# anecdote
# no-unit
# anecdote
# anecdote
# anecdote
# no-unit
# statistics
# no-unit
# assumption
# testimony
# assumption
# statistics
# statistics
# testimony
# assumption
# statistics
# assumption
# assumption
# assumption
# assumption
# assumption
# assumption
# common-ground
# anecdote
# testimony
# testimony
# assumption
# testimony
# assumption
# testimony
# testimony
# assumption
# testimony
# no-unit
# testimony
# assumption
# assumption
# assumption
# no-unit
# assumption
# title
# anecdote
# testimony
# testimony
# testimony
# testimony
# assumption
# common-ground
# common-ground
# no-unit
# assumption
# assumption
# assumption
# assumption
# assumption
# assumption
# no-unit
# assumption
# common-ground
# no-unit
# common-ground
# no-unit
# common-ground
# no-unit
# common-ground
# common-ground
# common-ground
# common-ground
# common-ground
# assumption
# assumption
# no-unit
# other
# assumption
# assumption
# no-unit
# assumption
# assumption
# common-ground
# other
# assumption
# assumption
# assumption
# assumption
# other
# assumption
# assumption
# assumption
# assumption
# assumption
# assumption
# assumption
# title
# testimony
# other
# assumption
# anecdote
# testimony

# %%
tstList=[]
for item in to_predict_list[:100]:
    tstList.append((item['prompt'],item['completion']))
#print(few_shot_prompt)
tstList
# Out:
# [('2015: Beyond Obama, new Congress, we need a revival of the American spirit.',
#   'title'),
#  ('In the film, "Girl Interrupted," Winona Ryder plays an 18-year-old who enters a mental institution for what is diagnosed as borderline personality disorder',
#   'anecdote'),
#  ('The year is 1967', 'anecdote'),
#  ('and', 'no-unit'),
#  ('the country is in turmoil over Vietnam and civil rights', 'anecdote'),
#  ('While lying on her bed one night and watching TV, she sees a news report about a demonstration',
#   'anecdote'),
#  ('The narrator says something that might apply to today\'s turmoil:"We live in a time of doubt. The institutions we once trusted no longer seem reliable."',
#   'anecdote'),
#  ('As 2014 ends,', 'no-unit'),
#  ('the stock market is at record highs', 'statistics'),
#  ('but', 'no-unit'),
#  ('our traditional institutions and self-confidence are in decline',
#   'assumption'),
#  ('A Pew Research Center study confirms one trend that has been obvious over several years',
#   'testimony'),
#  ('The "typical" American family is no longer typical', 'assumption'),
#  ('Just 46 percent of American children now live in homes with their married, heterosexual parents',
#   'statistics'),
#  ('Five percent have no parents at home', 'statistics'),
#  ('They most likely are living with grandparents, says the study',
#   'testimony'),
#  ('These startling figures about the decline of the American family contrast with the year 1960',
#   'assumption'),
#  ('when 73 percent of American children lived in traditional families',
#   'statistics'),
#  ('A major contributor to this trend has been the assault on marriage and other institutions by the Baby Boom generation',
#   'assumption'),
#  ('It was that generation that promoted cohabitation, no-fault divorce, hatred of the police(they called them "pigs" then, too) and disdain for the military and America, spawned not just by the Vietnam War but a life of relative ease unknown to their parents',
#   'assumption'),
#  ('The culture bomb dropped by the boomers created fallout still being felt today',
#   'assumption'),
#  ('The two-plus generations born since the Sixties have been infused with the notion of entitlement, victimhood, envy and greed',
#   'assumption'),
#  ('Since the elimination of the draft, young people are no longer expected to serve in the military and so most of them pursue whatever goals they wish with no expectation they should give something back to their country',
#   'assumption'),
#  ("It's one possible explanation for why we can no longer seem to win wars",
#   'assumption'),
#  ('History warns us what happens when empires refuse to teach known values that strengthen societies and help protect them from enemies intent on their destruction',
#   'common-ground'),
#  ('The late British diplomat Sir John Glubb wrote a book called "The Fate of Empires and Search For Survival."',
#   'anecdote'),
#  ('Glubb noted the average age of empires since the time of ancient Assyria (859-612 B.C ) is 250 years',
#   'testimony'),
#  ('Only the Mameluke Empire in Egypt and the Levant (1250-1517) made it as far as 267 years',
#   'testimony'),
#  ('America is 238 years old and is exhibiting signs of decline', 'assumption'),
#  ('All empires begin, writes Glubb, with the age of pioneers, followed by ages of conquest, commerce, affluence, intellect and decadence',
#   'testimony'),
#  ('America appears to have reached the age of decadence', 'assumption'),
#  ('which Glubb defines as marked by "defensiveness, pessimism, materialism, frivolity, an influx of foreigners, the welfare state, (and) a weakening of religion."',
#   'testimony'),
#  ('Decadence, he writes,"is due to: Too long a period of wealth and power, selfishness, love of money (and) the loss of a sense of duty."',
#   'testimony'),
#  ('Do these not define America at the end of 2014?', 'assumption'),
#  ('Glubb says the 250-year average of empires has not varied in 3,000 years',
#   'testimony'),
#  ('but', 'no-unit'),
#  ('we don\' t learn from history because"our studies are brief and prejudiced."',
#   'testimony'),
#  ("He means they are mostly about one's own country", 'assumption'),
#  ('It will take more than a new Congress in 2015 and a new president in 2017 to save us from the fate of other empires',
#   'assumption'),
#  ('It will take a revival of the American spirit', 'assumption'),
#  ('and', 'no-unit'),
#  ('that can only come through changed attitudes towards our institutions and each other',
#   'assumption'),
#  ('2015: Will America continue its slow march toward destruction of liberty?',
#   'title'),
#  ('A British author, residing in the United States for the past 30 years, created a small firestorm earlier this week with his candid observations that modern- day Americans have been duped by the government into accepting a European- style march toward socialism',
#   'anecdote'),
#  ("because we fail to appreciate the rich legacy of personal liberty that is everyone's birthright and is expressly articulated in the Declaration of Independence and guaranteed by the U.S  Constitution",
#   'testimony'),
#  ('Os Guinness, the author of more than a dozen books defending traditional Judeo-Christian values and Jeffersonian personal liberty, argued that we should embrace individual liberty and personal dignity and reject the "no givens, no rules, no limits" government we now have',
#   'testimony'),
#  ('He went on to opine that the government today is not the constitutionally restrained protector of personal freedoms the Framers left us',
#   'testimony'),
#  ('but rather has become the wealth-distributing protector of collective interests the Founding Fathers never could have imagined',
#   'testimony'),
#  ('Yet the problem is a deep one', 'assumption'),
#  ('The Framers believed in the presumption of liberty', 'common-ground'),
#  ('which declares that we are free to make personal choices, and the government cannot interfere with our liberties unless we violate the rights of others',
#   'common-ground'),
#  ('Stated differently', 'no-unit'),
#  ('the federal government cannot interfere with our personal choices by writing any law it wants',
#   'assumption'),
#  ('it can only regulate behavior or spend money when the Constitution authorizes it to do so',
#   'assumption'),
#  ('But for the past 100 years, the federal government has rejected the Madisonian concept that it is limited to the 16 discrete powers the Constitution delegates to it, and has claimed its powers are unlimited, subject only to the express prohibitions in the Constitution',
#   'assumption'),
#  ('Even those prohibitions can be gotten around', 'assumption'),
#  ('since government lawyers have persuaded federal courts to rule that Congress can spend tax dollars or borrowed money on any projects it wishes, whether authorized by the Constitution or not',
#   'assumption'),
#  ('The courts even have authorized Congress to use federal tax dollars to bribe the states into enacting laws that Congress is powerless to enact',
#   'assumption'),
#  ('and', 'no-unit'),
#  ('Congress has done so', 'assumption'),
#  ('The Declaration of Independence defines our personal liberties as inalienable aspects of our humanity',
#   'common-ground'),
#  ('and', 'no-unit'),
#  ('the Constitution prohibits the government from interfering with those liberties-- like thought, speech, press, association, worship, self-defense, travel, privacy, due process, use of money and private property',
#   'common-ground'),
#  ('to name a few', 'no-unit'),
#  ('The teaching of these founding documents is that our liberties are natural-- their source is not the government',
#   'common-ground'),
#  ('-- and', 'no-unit'),
#  ('they are personal, not collective', 'common-ground'),
#  ("We don't need a government permission slip to exercise them",
#   'common-ground'),
#  ("we don't need to belong to a group to enjoy them", 'common-ground'),
#  ('they cannot be taken away by a congressional vote or a presidential signature',
#   'common-ground'),
#  ('Even though everyone who works for the government takes an oath to uphold the Declaration and the Constitution',
#   'common-ground'),
#  ('very few are consistent with what they have sworn to do', 'assumption'),
#  ('We know that because on the transcendental issues of our day -- life, liberty, war and debt -- the leadership of both political parties and the behavior of all modern presidents have revealed a steadfast willingness to write any law and regulate any behavior or permit any evil',
#   'assumption'),
#  (', whether authorized by the Constitution or not.', 'no-unit'),
#  ('Take life', 'other'),
#  ('Abortion is the most deadly force in America today', 'assumption'),
#  ('Abortions lawfully kill a baby a minute ', 'assumption'),
#  ('--', 'no-unit'),
#  ("that's 1.1 million babies a year and 45,000,000 killed since the Supreme Court issued its Roe v  Wade decision in 1973",
#   'assumption'),
#  ('A simple one-line statute --"The fetus in the womb is a legal person"-- could have been enacted by a simple majority vote in Congress and signed into law by any of our so-called pro-life presidents, thus stopping the slaughter',
#   'assumption'),
#  ('It never happened', 'common-ground'),
#  ('Take liberty', 'other'),
#  ('Both parties support the Patriot Act and the secret FISA apparatus',
#   'assumption'),
#  ('which together invade privacy, infringe upon free speech, permit federal agents to write their own search warrants and allow domestic spying on all of us all the time',
#   'assumption'),
#  ('This demonstrates that our political leaders do not believe that our rights are inalienable, but can be interfered with and regulated by them',
#   'assumption'),
#  ('They have written laws that literally permit federal agents to do the very acts the Constitution was written to prohibit',
#   'assumption'),
#  ('Take the lethal combination of war and debt', 'other'),
#  ('Both parties support perpetual war and perpetual debt', 'assumption'),
#  ('The leadership of both parties has permitted every modern president to kill whomever he pleases in foreign countries without lawful declarations of war and to do so by going into a $17 trillion hole of debt, with no end in sight',
#   'assumption'),
#  ('Today, 20 cents of every tax dollar collected goes to interest on pre-existing government debt',
#   'assumption'),
#  ("Today's taxpayers are still paying interest on the $30 billion Woodrow Wilson borrowed to finance World War I in 1917",
#   'assumption'),
#  ('The British author is correct', 'assumption'),
#  ('Unless we have a radical change in the direction of government -- its size, cost, focus, intrusiveness and rejection of first principles -- and unless we elect people to the government who truly believe the Declaration and the Constitution mean what they say, we will continue our march toward the federal destruction of the presumption of liberty',
#   'assumption'),
#  ('It is a slow march, but a steady one', 'assumption'),
#  ('2015: Will new Congress get serious about Putin, Russia?', 'title'),
#  ('"The bear never asks permission," remarked Vladmir Putin on a TV promo for his annual news conference',
#   'testimony'),
#  ('Yes, we know', 'other'),
#  ("The Russians haven't stopped their aggressive posturing after annexing Crimea--not by a long-shot",
#   'assumption'),
#  ('In early December there was another near miss between a Russian military jet with its transponders turned off and a commercial airliner just south of Sweden',
#   'anecdote'),
#  ('This adds to the list of over 40 serious incidents involving Russia and NATO countries in the last 8 months, as detailed in a report by a British think tank called the European Leadership Network',
#   'testimony')]

# %% [markdown]
# ## 3. Train Loop

# %%
t5_model.train()

epochs = 2

for epoch in range(epochs):
  print ("epoch ",epoch)
  for input,output in trnList:
    input_sent = input+ " </s>"
    ouput_sent = output+" </s>"
    print(input_sent)
    tokenized_inp = tokenizer.encode_plus(input_sent,  max_length=96, pad_to_max_length=True,return_tensors="pt")
    tokenized_output = tokenizer.encode_plus(ouput_sent, max_length=96, pad_to_max_length=True,return_tensors="pt")


    input_ids  = tokenized_inp["input_ids"]
    attention_mask = tokenized_inp["attention_mask"]

    lm_labels= tokenized_output["input_ids"]
    decoder_attention_mask=  tokenized_output["attention_mask"]


    # the forward function automatically creates the correct decoder_input_ids
    output = t5_model(input_ids=input_ids, lm_labels=lm_labels,decoder_attention_mask=decoder_attention_mask,attention_mask=attention_mask)
    loss = output[0]

    loss.backward()
    optimizer.step()
    optimizer.zero_grad()
# Out:
# epoch  0
# 2015: Beyond Obama, new Congress, we need a revival of the American spirit. </s>
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:155: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha) (Triggered internally at  ../torch/csrc/utils/python_arg_parser.cpp:1055.)
#   exp_avg.mul_(beta1).add_(1.0 - beta1, grad)
# In the film, "Girl Interrupted," Winona Ryder plays an 18-year-old who enters a mental institution for what is diagnosed as borderline personality disorder </s>
# The year is 1967 </s>
# and </s>
# the country is in turmoil over Vietnam and civil rights </s>
# While lying on her bed one night and watching TV, she sees a news report about a demonstration </s>
# The narrator says something that might apply to today's turmoil:"We live in a time of doubt. The institutions we once trusted no longer seem reliable." </s>
# As 2014 ends, </s>
# the stock market is at record highs </s>
# but </s>
# our traditional institutions and self-confidence are in decline </s>
# A Pew Research Center study confirms one trend that has been obvious over several years </s>
# The "typical" American family is no longer typical </s>
# Just 46 percent of American children now live in homes with their married, heterosexual parents </s>
# Five percent have no parents at home </s>
# They most likely are living with grandparents, says the study </s>
# These startling figures about the decline of the American family contrast with the year 1960 </s>
# when 73 percent of American children lived in traditional families </s>
# A major contributor to this trend has been the assault on marriage and other institutions by the Baby Boom generation </s>
# It was that generation that promoted cohabitation, no-fault divorce, hatred of the police(they called them "pigs" then, too) and disdain for the military and America, spawned not just by the Vietnam War but a life of relative ease unknown to their parents </s>
# The culture bomb dropped by the boomers created fallout still being felt today </s>
# The two-plus generations born since the Sixties have been infused with the notion of entitlement, victimhood, envy and greed </s>
# Since the elimination of the draft, young people are no longer expected to serve in the military and so most of them pursue whatever goals they wish with no expectation they should give something back to their country </s>
# It's one possible explanation for why we can no longer seem to win wars </s>
# History warns us what happens when empires refuse to teach known values that strengthen societies and help protect them from enemies intent on their destruction </s>
# The late British diplomat Sir John Glubb wrote a book called "The Fate of Empires and Search For Survival." </s>
# Glubb noted the average age of empires since the time of ancient Assyria (859-612 B.C ) is 250 years </s>
# Only the Mameluke Empire in Egypt and the Levant (1250-1517) made it as far as 267 years </s>
# America is 238 years old and is exhibiting signs of decline </s>
# All empires begin, writes Glubb, with the age of pioneers, followed by ages of conquest, commerce, affluence, intellect and decadence </s>
# America appears to have reached the age of decadence </s>
# which Glubb defines as marked by "defensiveness, pessimism, materialism, frivolity, an influx of foreigners, the welfare state, (and) a weakening of religion." </s>
# Decadence, he writes,"is due to: Too long a period of wealth and power, selfishness, love of money (and) the loss of a sense of duty." </s>
# Do these not define America at the end of 2014? </s>
# Glubb says the 250-year average of empires has not varied in 3,000 years </s>
# but </s>
# we don' t learn from history because"our studies are brief and prejudiced." </s>
# He means they are mostly about one's own country </s>
# It will take more than a new Congress in 2015 and a new president in 2017 to save us from the fate of other empires </s>
# It will take a revival of the American spirit </s>
# and </s>
# that can only come through changed attitudes towards our institutions and each other </s>
# 2015: Will America continue its slow march toward destruction of liberty? </s>
# A British author, residing in the United States for the past 30 years, created a small firestorm earlier this week with his candid observations that modern- day Americans have been duped by the government into accepting a European- style march toward socialism </s>
# because we fail to appreciate the rich legacy of personal liberty that is everyone's birthright and is expressly articulated in the Declaration of Independence and guaranteed by the U.S  Constitution </s>
# Os Guinness, the author of more than a dozen books defending traditional Judeo-Christian values and Jeffersonian personal liberty, argued that we should embrace individual liberty and personal dignity and reject the "no givens, no rules, no limits" government we now have </s>
# He went on to opine that the government today is not the constitutionally restrained protector of personal freedoms the Framers left us </s>
# but rather has become the wealth-distributing protector of collective interests the Founding Fathers never could have imagined </s>
# Yet the problem is a deep one </s>
# The Framers believed in the presumption of liberty </s>
# which declares that we are free to make personal choices, and the government cannot interfere with our liberties unless we violate the rights of others </s>
# Stated differently </s>
# the federal government cannot interfere with our personal choices by writing any law it wants </s>
# it can only regulate behavior or spend money when the Constitution authorizes it to do so </s>
# But for the past 100 years, the federal government has rejected the Madisonian concept that it is limited to the 16 discrete powers the Constitution delegates to it, and has claimed its powers are unlimited, subject only to the express prohibitions in the Constitution </s>
# Even those prohibitions can be gotten around </s>
# since government lawyers have persuaded federal courts to rule that Congress can spend tax dollars or borrowed money on any projects it wishes, whether authorized by the Constitution or not </s>
# The courts even have authorized Congress to use federal tax dollars to bribe the states into enacting laws that Congress is powerless to enact </s>
# and </s>
# Congress has done so </s>
# The Declaration of Independence defines our personal liberties as inalienable aspects of our humanity </s>
# and </s>
# the Constitution prohibits the government from interfering with those liberties-- like thought, speech, press, association, worship, self-defense, travel, privacy, due process, use of money and private property </s>
# to name a few </s>
# The teaching of these founding documents is that our liberties are natural-- their source is not the government </s>
# -- and </s>
# they are personal, not collective </s>
# We don't need a government permission slip to exercise them </s>
# we don't need to belong to a group to enjoy them </s>
# they cannot be taken away by a congressional vote or a presidential signature </s>
# Even though everyone who works for the government takes an oath to uphold the Declaration and the Constitution </s>
# very few are consistent with what they have sworn to do </s>
# We know that because on the transcendental issues of our day -- life, liberty, war and debt -- the leadership of both political parties and the behavior of all modern presidents have revealed a steadfast willingness to write any law and regulate any behavior or permit any evil </s>
# , whether authorized by the Constitution or not. </s>
# Take life </s>
# Abortion is the most deadly force in America today </s>
# Abortions lawfully kill a baby a minute  </s>
# -- </s>
# that's 1.1 million babies a year and 45,000,000 killed since the Supreme Court issued its Roe v  Wade decision in 1973 </s>
# A simple one-line statute --"The fetus in the womb is a legal person"-- could have been enacted by a simple majority vote in Congress and signed into law by any of our so-called pro-life presidents, thus stopping the slaughter </s>
# It never happened </s>
# Take liberty </s>
# Both parties support the Patriot Act and the secret FISA apparatus </s>
# which together invade privacy, infringe upon free speech, permit federal agents to write their own search warrants and allow domestic spying on all of us all the time </s>
# This demonstrates that our political leaders do not believe that our rights are inalienable, but can be interfered with and regulated by them </s>
# They have written laws that literally permit federal agents to do the very acts the Constitution was written to prohibit </s>
# Take the lethal combination of war and debt </s>
# Both parties support perpetual war and perpetual debt </s>
# The leadership of both parties has permitted every modern president to kill whomever he pleases in foreign countries without lawful declarations of war and to do so by going into a $17 trillion hole of debt, with no end in sight </s>
# Today, 20 cents of every tax dollar collected goes to interest on pre-existing government debt </s>
# Today's taxpayers are still paying interest on the $30 billion Woodrow Wilson borrowed to finance World War I in 1917 </s>
# The British author is correct </s>
# Unless we have a radical change in the direction of government -- its size, cost, focus, intrusiveness and rejection of first principles -- and unless we elect people to the government who truly believe the Declaration and the Constitution mean what they say, we will continue our march toward the federal destruction of the presumption of liberty </s>
# It is a slow march, but a steady one </s>
# 2015: Will new Congress get serious about Putin, Russia? </s>
# "The bear never asks permission," remarked Vladmir Putin on a TV promo for his annual news conference </s>
# Yes, we know </s>
# The Russians haven't stopped their aggressive posturing after annexing Crimea--not by a long-shot </s>
# In early December there was another near miss between a Russian military jet with its transponders turned off and a commercial airliner just south of Sweden </s>
# This adds to the list of over 40 serious incidents involving Russia and NATO countries in the last 8 months, as detailed in a report by a British think tank called the European Leadership Network </s>
# epoch  1
# 2015: Beyond Obama, new Congress, we need a revival of the American spirit. </s>
# In the film, "Girl Interrupted," Winona Ryder plays an 18-year-old who enters a mental institution for what is diagnosed as borderline personality disorder </s>
# The year is 1967 </s>
# and </s>
# the country is in turmoil over Vietnam and civil rights </s>
# While lying on her bed one night and watching TV, she sees a news report about a demonstration </s>
# The narrator says something that might apply to today's turmoil:"We live in a time of doubt. The institutions we once trusted no longer seem reliable." </s>
# As 2014 ends, </s>
# the stock market is at record highs </s>
# but </s>
# our traditional institutions and self-confidence are in decline </s>
# A Pew Research Center study confirms one trend that has been obvious over several years </s>
# The "typical" American family is no longer typical </s>
# Just 46 percent of American children now live in homes with their married, heterosexual parents </s>
# Five percent have no parents at home </s>
# They most likely are living with grandparents, says the study </s>
# These startling figures about the decline of the American family contrast with the year 1960 </s>
# when 73 percent of American children lived in traditional families </s>
# A major contributor to this trend has been the assault on marriage and other institutions by the Baby Boom generation </s>
# It was that generation that promoted cohabitation, no-fault divorce, hatred of the police(they called them "pigs" then, too) and disdain for the military and America, spawned not just by the Vietnam War but a life of relative ease unknown to their parents </s>
# The culture bomb dropped by the boomers created fallout still being felt today </s>
# The two-plus generations born since the Sixties have been infused with the notion of entitlement, victimhood, envy and greed </s>
# Since the elimination of the draft, young people are no longer expected to serve in the military and so most of them pursue whatever goals they wish with no expectation they should give something back to their country </s>
# It's one possible explanation for why we can no longer seem to win wars </s>
# History warns us what happens when empires refuse to teach known values that strengthen societies and help protect them from enemies intent on their destruction </s>
# The late British diplomat Sir John Glubb wrote a book called "The Fate of Empires and Search For Survival." </s>
# Glubb noted the average age of empires since the time of ancient Assyria (859-612 B.C ) is 250 years </s>
# Only the Mameluke Empire in Egypt and the Levant (1250-1517) made it as far as 267 years </s>
# America is 238 years old and is exhibiting signs of decline </s>
# All empires begin, writes Glubb, with the age of pioneers, followed by ages of conquest, commerce, affluence, intellect and decadence </s>
# America appears to have reached the age of decadence </s>
# which Glubb defines as marked by "defensiveness, pessimism, materialism, frivolity, an influx of foreigners, the welfare state, (and) a weakening of religion." </s>
# Decadence, he writes,"is due to: Too long a period of wealth and power, selfishness, love of money (and) the loss of a sense of duty." </s>
# Do these not define America at the end of 2014? </s>
# Glubb says the 250-year average of empires has not varied in 3,000 years </s>
# but </s>
# we don' t learn from history because"our studies are brief and prejudiced." </s>
# He means they are mostly about one's own country </s>
# It will take more than a new Congress in 2015 and a new president in 2017 to save us from the fate of other empires </s>
# It will take a revival of the American spirit </s>
# and </s>
# that can only come through changed attitudes towards our institutions and each other </s>
# 2015: Will America continue its slow march toward destruction of liberty? </s>
# A British author, residing in the United States for the past 30 years, created a small firestorm earlier this week with his candid observations that modern- day Americans have been duped by the government into accepting a European- style march toward socialism </s>
# because we fail to appreciate the rich legacy of personal liberty that is everyone's birthright and is expressly articulated in the Declaration of Independence and guaranteed by the U.S  Constitution </s>
# Os Guinness, the author of more than a dozen books defending traditional Judeo-Christian values and Jeffersonian personal liberty, argued that we should embrace individual liberty and personal dignity and reject the "no givens, no rules, no limits" government we now have </s>
# He went on to opine that the government today is not the constitutionally restrained protector of personal freedoms the Framers left us </s>
# but rather has become the wealth-distributing protector of collective interests the Founding Fathers never could have imagined </s>
# Yet the problem is a deep one </s>
# The Framers believed in the presumption of liberty </s>
# which declares that we are free to make personal choices, and the government cannot interfere with our liberties unless we violate the rights of others </s>
# Stated differently </s>
# the federal government cannot interfere with our personal choices by writing any law it wants </s>
# it can only regulate behavior or spend money when the Constitution authorizes it to do so </s>
# But for the past 100 years, the federal government has rejected the Madisonian concept that it is limited to the 16 discrete powers the Constitution delegates to it, and has claimed its powers are unlimited, subject only to the express prohibitions in the Constitution </s>
# Even those prohibitions can be gotten around </s>
# since government lawyers have persuaded federal courts to rule that Congress can spend tax dollars or borrowed money on any projects it wishes, whether authorized by the Constitution or not </s>
# The courts even have authorized Congress to use federal tax dollars to bribe the states into enacting laws that Congress is powerless to enact </s>
# and </s>
# Congress has done so </s>
# The Declaration of Independence defines our personal liberties as inalienable aspects of our humanity </s>
# and </s>
# the Constitution prohibits the government from interfering with those liberties-- like thought, speech, press, association, worship, self-defense, travel, privacy, due process, use of money and private property </s>
# to name a few </s>
# The teaching of these founding documents is that our liberties are natural-- their source is not the government </s>
# -- and </s>
# they are personal, not collective </s>
# We don't need a government permission slip to exercise them </s>
# we don't need to belong to a group to enjoy them </s>
# they cannot be taken away by a congressional vote or a presidential signature </s>
# Even though everyone who works for the government takes an oath to uphold the Declaration and the Constitution </s>
# very few are consistent with what they have sworn to do </s>
# We know that because on the transcendental issues of our day -- life, liberty, war and debt -- the leadership of both political parties and the behavior of all modern presidents have revealed a steadfast willingness to write any law and regulate any behavior or permit any evil </s>
# , whether authorized by the Constitution or not. </s>
# Take life </s>
# Abortion is the most deadly force in America today </s>
# Abortions lawfully kill a baby a minute  </s>
# -- </s>
# that's 1.1 million babies a year and 45,000,000 killed since the Supreme Court issued its Roe v  Wade decision in 1973 </s>
# A simple one-line statute --"The fetus in the womb is a legal person"-- could have been enacted by a simple majority vote in Congress and signed into law by any of our so-called pro-life presidents, thus stopping the slaughter </s>
# It never happened </s>
# Take liberty </s>
# Both parties support the Patriot Act and the secret FISA apparatus </s>
# which together invade privacy, infringe upon free speech, permit federal agents to write their own search warrants and allow domestic spying on all of us all the time </s>
# This demonstrates that our political leaders do not believe that our rights are inalienable, but can be interfered with and regulated by them </s>
# They have written laws that literally permit federal agents to do the very acts the Constitution was written to prohibit </s>
# Take the lethal combination of war and debt </s>
# Both parties support perpetual war and perpetual debt </s>
# The leadership of both parties has permitted every modern president to kill whomever he pleases in foreign countries without lawful declarations of war and to do so by going into a $17 trillion hole of debt, with no end in sight </s>
# Today, 20 cents of every tax dollar collected goes to interest on pre-existing government debt </s>
# Today's taxpayers are still paying interest on the $30 billion Woodrow Wilson borrowed to finance World War I in 1917 </s>
# The British author is correct </s>
# Unless we have a radical change in the direction of government -- its size, cost, focus, intrusiveness and rejection of first principles -- and unless we elect people to the government who truly believe the Declaration and the Constitution mean what they say, we will continue our march toward the federal destruction of the presumption of liberty </s>
# It is a slow march, but a steady one </s>
# 2015: Will new Congress get serious about Putin, Russia? </s>
# "The bear never asks permission," remarked Vladmir Putin on a TV promo for his annual news conference </s>
# Yes, we know </s>
# The Russians haven't stopped their aggressive posturing after annexing Crimea--not by a long-shot </s>
# In early December there was another near miss between a Russian military jet with its transponders turned off and a commercial airliner just south of Sweden </s>
# This adds to the list of over 40 serious incidents involving Russia and NATO countries in the last 8 months, as detailed in a report by a British think tank called the European Leadership Network </s>

# %%
tstt=tstList[:25]
tstt
# Out:
# [('2015: Beyond Obama, new Congress, we need a revival of the American spirit.',
#   'title'),
#  ('In the film, "Girl Interrupted," Winona Ryder plays an 18-year-old who enters a mental institution for what is diagnosed as borderline personality disorder',
#   'anecdote'),
#  ('The year is 1967', 'anecdote'),
#  ('and', 'no-unit'),
#  ('the country is in turmoil over Vietnam and civil rights', 'anecdote'),
#  ('While lying on her bed one night and watching TV, she sees a news report about a demonstration',
#   'anecdote'),
#  ('The narrator says something that might apply to today\'s turmoil:"We live in a time of doubt. The institutions we once trusted no longer seem reliable."',
#   'anecdote'),
#  ('As 2014 ends,', 'no-unit'),
#  ('the stock market is at record highs', 'statistics'),
#  ('but', 'no-unit'),
#  ('our traditional institutions and self-confidence are in decline',
#   'assumption'),
#  ('A Pew Research Center study confirms one trend that has been obvious over several years',
#   'testimony'),
#  ('The "typical" American family is no longer typical', 'assumption'),
#  ('Just 46 percent of American children now live in homes with their married, heterosexual parents',
#   'statistics'),
#  ('Five percent have no parents at home', 'statistics'),
#  ('They most likely are living with grandparents, says the study',
#   'testimony'),
#  ('These startling figures about the decline of the American family contrast with the year 1960',
#   'assumption'),
#  ('when 73 percent of American children lived in traditional families',
#   'statistics'),
#  ('A major contributor to this trend has been the assault on marriage and other institutions by the Baby Boom generation',
#   'assumption'),
#  ('It was that generation that promoted cohabitation, no-fault divorce, hatred of the police(they called them "pigs" then, too) and disdain for the military and America, spawned not just by the Vietnam War but a life of relative ease unknown to their parents',
#   'assumption'),
#  ('The culture bomb dropped by the boomers created fallout still being felt today',
#   'assumption'),
#  ('The two-plus generations born since the Sixties have been infused with the notion of entitlement, victimhood, envy and greed',
#   'assumption'),
#  ('Since the elimination of the draft, young people are no longer expected to serve in the military and so most of them pursue whatever goals they wish with no expectation they should give something back to their country',
#   'assumption'),
#  ("It's one possible explanation for why we can no longer seem to win wars",
#   'assumption'),
#  ('History warns us what happens when empires refuse to teach known values that strengthen societies and help protect them from enemies intent on their destruction',
#   'common-ground')]

# %%
actual=[completion for prompt,completion in tstList[:25]]
actual
# Out:
# ['title',
#  'anecdote',
#  'anecdote',
#  'no-unit',
#  'anecdote',
#  'anecdote',
#  'anecdote',
#  'no-unit',
#  'statistics',
#  'no-unit',
#  'assumption',
#  'testimony',
#  'assumption',
#  'statistics',
#  'statistics',
#  'testimony',
#  'assumption',
#  'statistics',
#  'assumption',
#  'assumption',
#  'assumption',
#  'assumption',
#  'assumption',
#  'assumption',
#  'common-ground']

# %% [markdown]
# ## 4. Test model

# %%
pred=[]
actual=[completion for prompt,completion in tstList[:25]]
for prompt,completion in tstList[:25]:
  test_sent = prompt+' </s>'
  test_tokenized = tokenizer.encode_plus(test_sent, return_tensors="pt")

  test_input_ids  = test_tokenized["input_ids"]
  test_attention_mask = test_tokenized["attention_mask"]

  t5_model.eval()
  beam_outputs = t5_model.generate(
      input_ids=test_input_ids,attention_mask=test_attention_mask,
      max_length=64,
      early_stopping=True,
      num_beams=10,
      num_return_sequences=1,
      no_repeat_ngram_size=2
  )

  for beam_output in beam_outputs:
      sent = tokenizer.decode(beam_output, skip_special_tokens=True,clean_up_tokenization_spaces=True)
      print (sent)
      pred.append(sent)
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/modeling_utils.py:1432: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   beam_id = beam_token_id // vocab_size
# we need a revival of the American spirit
# <extra_id_0> In the film, "Girl Interrupted," Winona Ryder plays an 18-year-old who enters a mental institution for what is diagnosed as borderline personality disorder.
# anecdote
# l'équilibre et à votre ordinateur.
# the country is in turmoil over Vietnam and civil rights are at stake.
# anecdote
# the narrator: "we live in a time of doubt.
# anecdote
# anecdote
# <extra_id_0>
# our traditional institutions and self-confidence
# assumption
# assumption
# just 46 percent of American children now live in homes with their married, heterosexual parents.
# five percent have no parents at home.
# the study
# assumption
# 73 percent of American children lived in traditional families.
# anecdote
# it was that generation that promoted cohabitation, no-fault divorce, hatred of the police(they called them "pigs") and disdain for the military and America, spawned not just by the Vietnam War but a life of relative ease unknown to their parents.
# anecdote
# the two-plus generations born since the sixties have been infused with the notion of entitlement, victimhood, envy and greed
# since the elimination of the draft, young people are no longer expected to serve in the military and so most pursue whatever goals they wish.
# <extra_id_0> It's one possible explanation for why we cannot seem to win wars.
# assumption

# %%
nactual=[]
for item in actual:
  item.str.strip()
  item.str.replace('<','')
  item.replace(">","")
  nactual.append(item)

nactual
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b2a206b046f3> in <module>()
#       1 nactual=[]
# ----> 2 for item in actual:
#       3   item.str.strip()
#       4   item.str.replace('<','')
#       5   item.replace(">","")
#
# NameError: name 'actual' is not defined

# %%
pred
# Out:
# ['we need a revival of the American spirit',
#  '<extra_id_0> In the film, "Girl Interrupted," Winona Ryder plays an 18-year-old who enters a mental institution for what is diagnosed as borderline personality disorder.',
#  'anecdote',
#  "l'équilibre et à votre ordinateur.",
#  'the country is in turmoil over Vietnam and civil rights are at stake.',
#  'anecdote',
#  'the narrator: "we live in a time of doubt.',
#  'anecdote',
#  'anecdote',
#  '<extra_id_0>',
#  'our traditional institutions and self-confidence',
#  'assumption',
#  'assumption',
#  'just 46 percent of American children now live in homes with their married, heterosexual parents.',
#  'five percent have no parents at home.',
#  'the study',
#  'assumption',
#  '73 percent of American children lived in traditional families.',
#  'anecdote',
#  'it was that generation that promoted cohabitation, no-fault divorce, hatred of the police(they called them "pigs") and disdain for the military and America, spawned not just by the Vietnam War but a life of relative ease unknown to their parents.',
#  'anecdote',
#  'the two-plus generations born since the sixties have been infused with the notion of entitlement, victimhood, envy and greed',
#  'since the elimination of the draft, young people are no longer expected to serve in the military and so most pursue whatever goals they wish.',
#  "<extra_id_0> It's one possible explanation for why we cannot seem to win wars.",
#  'assumption']

# %%
from sklearn.metrics import classification_report
print(classification_report(actual, pred))
# Out:
#                   precision    recall  f1-score   support
#
#       <anecdote>       0.00      0.00      0.00       5.0
#     <assumption>       0.00      0.00      0.00       9.0
#  <common-ground>       0.00      0.00      0.00       1.0
#        <no-unit>       0.00      0.00      0.00       3.0
#     <statistics>       0.00      0.00      0.00       4.0
#      <testimony>       0.00      0.00      0.00       2.0
#          <title>       0.00      0.00      0.00       1.0
#        anecdote>       0.00      0.00      0.00       0.0
#      assumption>       0.00      0.00      0.00       0.0
#   common-ground>       0.00      0.00      0.00       0.0
#         no-unit>       0.00      0.00      0.00       0.0
#      statistics>       0.00      0.00      0.00       0.0
#       testimony>       0.00      0.00      0.00       0.0
#           title>       0.00      0.00      0.00       0.0
#
#         accuracy                           0.00      25.0
#        macro avg       0.00      0.00      0.00      25.0
#     weighted avg       0.00      0.00      0.00      25.0
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
